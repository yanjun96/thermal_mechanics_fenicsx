# %% [markdown]
# # 1:Mesh for a brak disc
# This part is from Jørgen S. Dokken blog: Mesh generation use gmsh API
# https://jsdokken.com/src/tutorial_gmsh.html

# %%
import gmsh
import sys
import math
import os
import numpy as np

gmsh.initialize()
# all the unit is mm

# z1, z2, z3 is the height of brake disc, rubbing elemetn, pad lining in Z direction
# rd_outer, rd_inner is for brake disc, rp_outer, rp_inner is for brake pad radiu. r_rub is for rubbing elements
# angle1 is brake pad in degree system, angle is in radians system
element_min = 3
element_max = 15

z1, z2, z3 = 20, 33, 30
rd_o, rd_i = 320, 175 
r_rub = 18.8
rp_o, rp_i = 303, 178

angle1 = 80
angle = angle1 / 360 * 2 * math.pi

# gmsh.model.occ.addCylinder
# x (double), y (double), z (double), dx (double), dy (double), dz (double),
# r (double), tag = -1 (integer), angle = 2*pi (double)

# brake disc
outer_disc  = gmsh.model.occ.addCylinder(0,0,0,  0, 0, z1,  rd_o)
inner_disc  = gmsh.model.occ.addCylinder(0,0,0,  0, 0, z1,  rd_i)
disk = gmsh.model.occ.cut([(3, outer_disc)], [(3, inner_disc)])

# rubbing elements
import sys
sys.path.append('/home/yanjun/Documents/FEniCSx/Tutorial/Mesh/')
from rub_co import get_rub_coordinate
x_co, y_co = get_rub_coordinate()
    
rub_list = []
for i, (x, y) in enumerate(zip(x_co, y_co), start=1):
    var_name = f"rub{i}"
    tag = gmsh.model.occ.addCylinder(x, y, z1, 0, 0, z2, r_rub)
    globals()[var_name] = tag
    rub_list.append(globals()[var_name])
    

# brake pad, in [(3, )],3 means dimension, cut the common place, out - inner
outer_pad  = gmsh.model.occ.addCylinder(0,0,z1+z2,  0, 0, z3,  rp_o, 50, angle)
inner_pad  = gmsh.model.occ.addCylinder(0,0,z1+z2,  0, 0, z3,  rp_i, 51, angle)
pad = gmsh.model.occ.cut([(3, outer_pad)], [(3, inner_pad)]) 

# Initialize the shell with the first rub
rub_list = [rub1, rub2, rub3, rub4, rub5, rub6, rub7, 
            rub8, rub9, rub10, rub11, rub12, rub13, rub14, rub15, rub16, rub17, rub18]
shell = gmsh.model.occ.fuse([(3, outer_pad)], [(3, rub_list[0])], 70)
#for i in range(len(rub_list) - 1):
#    shell = gmsh.model.occ.fuse([(3, 70 + i)], [(3, rub_list[i + 1])], 71 + i)
gmsh.model.occ.synchronize()

# Add physical group, this step should after synchronize to make sure success
# https://gitlab.onelab.info/gmsh/gmsh/blob/master/tutorials/python/t1.py#L115

# Volumes: 31,32 brake disc and pad.
volumes = gmsh.model.occ.getEntities(dim = 3)
#gmsh.model.addPhysicalGroup(3, volumes[0],  31)
#gmsh.model.addPhysicalGroup(3, volumes[1],  32)

# Surfaces: brake disc, 21 = friction surface
surfaces = gmsh.model.occ.getEntities(dim = 2)
gmsh.model.addPhysicalGroup(2, (2,6), 21)

# Rubbing elements, from 1 to 19, here 32 is the origin name tag of rub surface(32-49)
rublist = list(range(32,50))
for rub in rublist:
    gmsh.model.addPhysicalGroup(2, (2, rub), rub-31)

gmsh.model.occ.synchronize()


# Mesh subdivision algorithm (0: none, 1: all quadrangles, 2: all hexahedra, 3: barycentric)
gmsh.option.setNumber("Mesh.SubdivisionAlgorithm", 2)
    

# for the rubbing elements, P13 of UIC 541-3
# Sinter material, 200 cm2, 18 rubbing elemets, r = 1.88 cm
# Mesh size
gmsh.option.setNumber("Mesh.MeshSizeMin", element_min)
gmsh.option.setNumber("Mesh.MeshSizeMax", element_max)

# Mesh file save
gmsh.model.mesh.generate(3)
gmsh.write("disc.msh")

# Launch the GUI to see the results:
if '-nopopup' not in sys.argv:
    gmsh.fltk.run()
gmsh.finalize()
# Out:
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 21
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 1
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 2
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 3
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 4
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 5
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 6
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 7
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 8
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 9
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 10
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 11
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 12
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 13
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 14
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 15
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 16
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 17
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 18
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 4 (Circle)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Circle)
# Info    : [ 10%] Meshing curve 7 (Circle)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Circle)
# Info    : [ 10%] Meshing curve 13 (Circle)
# Info    : [ 10%] Meshing curve 14 (Line)
# Info    : [ 20%] Meshing curve 15 (Circle)
# Info    : [ 20%] Meshing curve 16 (Circle)
# Info    : [ 20%] Meshing curve 17 (Line)
# Info    : [ 20%] Meshing curve 18 (Circle)
# Info    : [ 20%] Meshing curve 19 (Circle)
# Info    : [ 20%] Meshing curve 20 (Line)
# Info    : [ 20%] Meshing curve 21 (Circle)
# Info    : [ 30%] Meshing curve 22 (Circle)
# Info    : [ 30%] Meshing curve 23 (Line)
# Info    : [ 30%] Meshing curve 24 (Circle)
# Info    : [ 30%] Meshing curve 25 (Circle)
# Info    : [ 30%] Meshing curve 26 (Line)
# Info    : [ 30%] Meshing curve 27 (Circle)
# Info    : [ 30%] Meshing curve 28 (Circle)
# Info    : [ 40%] Meshing curve 29 (Line)
# Info    : [ 40%] Meshing curve 30 (Circle)
# Info    : [ 40%] Meshing curve 31 (Circle)
# Info    : [ 40%] Meshing curve 32 (Line)
# Info    : [ 40%] Meshing curve 33 (Circle)
# Info    : [ 40%] Meshing curve 34 (Circle)
# Info    : [ 40%] Meshing curve 35 (Line)
# Info    : [ 50%] Meshing curve 36 (Circle)
# Info    : [ 50%] Meshing curve 37 (Circle)
# Info    : [ 50%] Meshing curve 38 (Line)
# Info    : [ 50%] Meshing curve 39 (Circle)
# Info    : [ 50%] Meshing curve 40 (Circle)
# Info    : [ 50%] Meshing curve 41 (Line)
# Info    : [ 50%] Meshing curve 42 (Circle)
# Info    : [ 50%] Meshing curve 43 (Circle)
# Info    : [ 60%] Meshing curve 44 (Line)
# Info    : [ 60%] Meshing curve 45 (Circle)
# Info    : [ 60%] Meshing curve 46 (Circle)
# Info    : [ 60%] Meshing curve 47 (Line)
# Info    : [ 60%] Meshing curve 48 (Circle)
# Info    : [ 60%] Meshing curve 49 (Circle)
# Info    : [ 60%] Meshing curve 50 (Line)
# Info    : [ 70%] Meshing curve 51 (Circle)
# Info    : [ 70%] Meshing curve 52 (Circle)
# Info    : [ 70%] Meshing curve 53 (Line)
# Info    : [ 70%] Meshing curve 54 (Circle)
# Info    : [ 70%] Meshing curve 55 (Circle)
# Info    : [ 70%] Meshing curve 56 (Line)
# Info    : [ 70%] Meshing curve 57 (Circle)
# Info    : [ 80%] Meshing curve 58 (Circle)
# Info    : [ 80%] Meshing curve 59 (Line)
# Info    : [ 80%] Meshing curve 60 (Circle)
# Info    : [ 80%] Meshing curve 61 (Circle)
# Info    : [ 80%] Meshing curve 62 (Line)
# Info    : [ 80%] Meshing curve 63 (Circle)
# Info    : [ 80%] Meshing curve 64 (Circle)
# Info    : [ 90%] Meshing curve 65 (Line)
# Info    : [ 90%] Meshing curve 66 (Circle)
# Info    : [ 90%] Meshing curve 67 (Line)
# Info    : [ 90%] Meshing curve 68 (Line)
# Info    : [ 90%] Meshing curve 69 (Circle)
# Info    : [ 90%] Meshing curve 70 (Line)
# Info    : [ 90%] Meshing curve 71 (Line)
# Info    : [100%] Meshing curve 72 (Line)
# Info    : [100%] Meshing curve 73 (Line)
# Info    : [100%] Meshing curve 74 (Circle)
# Info    : [100%] Meshing curve 75 (Circle)
# Info    : [100%] Meshing curve 76 (Line)
# Info    : [100%] Meshing curve 77 (Line)
# Info    : [100%] Meshing curve 78 (Circle)
# Info    : Done meshing 1D (Wall 0.00757219s, CPU 0.009122s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 4 (Cylinder, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 5 (Cylinder, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 7 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 11 (Cylinder, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 13 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 14 (Cylinder, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 15 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 16 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 17 (Cylinder, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 18 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 19 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 20 (Cylinder, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 21 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 22 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 23 (Cylinder, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 24 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 25 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 26 (Cylinder, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 27 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 28 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 29 (Cylinder, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 30 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 31 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 32 (Cylinder, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 33 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 34 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 35 (Cylinder, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 36 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 37 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 38 (Cylinder, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 39 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 40 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 41 (Cylinder, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 42 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 43 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 44 (Cylinder, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 45 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 46 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 47 (Cylinder, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 48 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 49 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 50 (Cylinder, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 51 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 52 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 53 (Cylinder, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 54 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 55 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 56 (Cylinder, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 57 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 58 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 59 (Cylinder, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 60 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 61 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 62 (Cylinder, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 63 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 64 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 65 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 66 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 67 (Cylinder, Frontal-Delaunay)
# Info    : [100%] Meshing surface 68 (Cylinder, Frontal-Delaunay)
# Info    : [100%] Meshing surface 69 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.112906s, CPU 0.111526s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 19 volumes with 19 connected components
# Info    : Tetrahedrizing 2875 nodes...
# Info    : Done tetrahedrizing 2883 nodes (Wall 0.0265802s, CPU 0.02182s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 10 Steiner points
# Info    : Done reconstructing mesh (Wall 0.0626582s, CPU 0.054732s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 1.54633 (nodes removed 0 0)
# Info    : 3D refinement terminated (4328 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 12 nodes could not be inserted
# Info    :  - 8280 tetrahedra created in 0.00301379 sec. (2747372 tets/s)
# Info    : 6 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.00146918s, CPU 0s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00705201s, CPU 0.000167s)
# Info    : Found volume 3
# Info    : It. 0 - 0 nodes created - worst tet radius 1.35285 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 96 tetrahedra created in 0.000654552 sec. (146665 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000355073s, CPU 0s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00118144s, CPU 0.000711s)
# Info    : Found volume 4
# Info    : It. 0 - 0 nodes created - worst tet radius 1.26311 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 96 tetrahedra created in 0.000869105 sec. (110458 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000332444s, CPU 0.000445s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00119289s, CPU 0.001313s)
# Info    : Found volume 5
# Info    : It. 0 - 0 nodes created - worst tet radius 1.35302 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 97 tetrahedra created in 0.000814349 sec. (119113 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000600635s, CPU 0s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00105544s, CPU 0s)
# Info    : Found volume 6
# Info    : It. 0 - 0 nodes created - worst tet radius 1.34669 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 96 tetrahedra created in 0.000565714 sec. (169697 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000276013s, CPU 0.000386s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.000841168s, CPU 0.000906s)
# Info    : Found volume 7
# Info    : It. 0 - 0 nodes created - worst tet radius 1.35285 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 96 tetrahedra created in 0.00052353 sec. (183370 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.00031233s, CPU 0s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.000767136s, CPU 0s)
# Info    : Found volume 8
# Info    : It. 0 - 0 nodes created - worst tet radius 1.35302 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 96 tetrahedra created in 0.000909054 sec. (105604 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000467377s, CPU 0.000611s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.000866031s, CPU 0.001033s)
# Info    : Found volume 9
# Info    : It. 0 - 0 nodes created - worst tet radius 1.35285 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 96 tetrahedra created in 0.000555937 sec. (172681 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000296965s, CPU 0.000401s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.000859607s, CPU 0.00052s)
# Info    : Found volume 10
# Info    : It. 0 - 0 nodes created - worst tet radius 1.35302 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 96 tetrahedra created in 0.000566831 sec. (169362 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000327416s, CPU 0.000491s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.000819657s, CPU 0.000857s)
# Info    : Found volume 11
# Info    : It. 0 - 0 nodes created - worst tet radius 1.33195 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 95 tetrahedra created in 0.000542527 sec. (175106 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000502578s, CPU 0.002148s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00249976s, CPU 0.00397s)
# Info    : Found volume 12
# Info    : It. 0 - 0 nodes created - worst tet radius 1.35285 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 97 tetrahedra created in 0.000522133 sec. (185776 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000574654s, CPU 0s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.000898158s, CPU 0s)
# Info    : Found volume 13
# Info    : It. 0 - 0 nodes created - worst tet radius 1.35285 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 96 tetrahedra created in 0.000487772 sec. (196813 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000209524s, CPU 0s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.000518222s, CPU 0s)
# Info    : Found volume 14
# Info    : It. 0 - 0 nodes created - worst tet radius 1.35302 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 96 tetrahedra created in 0.000464026 sec. (206884 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.00021567s, CPU 0.000227s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.000518502s, CPU 0.000546s)
# Info    : Found volume 15
# Info    : It. 0 - 0 nodes created - worst tet radius 1.35285 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 97 tetrahedra created in 0.00178961 sec. (54201 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000209803s, CPU 0.000436s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.000822451s, CPU 0.001221s)
# Info    : Found volume 16
# Info    : It. 0 - 0 nodes created - worst tet radius 1.24389 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 94 tetrahedra created in 0.000422959 sec. (222243 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000262324s, CPU 0.000328s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.000584711s, CPU 0.000697s)
# Info    : Found volume 17
# Info    : It. 0 - 0 nodes created - worst tet radius 1.24389 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 94 tetrahedra created in 0.000583034 sec. (161225 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.00027266s, CPU 0.000326s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.000603428s, CPU 0.00074s)
# Info    : Found volume 18
# Info    : It. 0 - 0 nodes created - worst tet radius 1.35302 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 96 tetrahedra created in 0.0022514 sec. (42640 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 44 nodes...
# Info    : Done tetrahedrizing 52 nodes (Wall 0.000247238s, CPU 0.000677s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00110908s, CPU 0.001534s)
# Info    : Found volume 19
# Info    : It. 0 - 0 nodes created - worst tet radius 1.32596 (nodes removed 0 0)
# Info    : 3D refinement terminated (4295 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 97 tetrahedra created in 0.00055454 sec. (174919 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 671 nodes...
# Info    : Done tetrahedrizing 679 nodes (Wall 0.00476429s, CPU 0.004197s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.0105189s, CPU 0.006664s)
# Info    : Found volume 70
# Info    : It. 0 - 0 nodes created - worst tet radius 1.40332 (nodes removed 0 0)
# Info    : 3D refinement terminated (4402 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 2501 tetrahedra created in 0.00726545 sec. (344232 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 0.376285s, CPU 0.318631s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 4.50974e+06) with worst = 0.0139261 / average = 0.723754:
# Info    : 0.00 < quality < 0.10 :        42 elements
# Info    : 0.10 < quality < 0.20 :        26 elements
# Info    : 0.20 < quality < 0.30 :        11 elements
# Info    : 0.30 < quality < 0.40 :        11 elements
# Info    : 0.40 < quality < 0.50 :        14 elements
# Info    : 0.50 < quality < 0.60 :       212 elements
# Info    : 0.60 < quality < 0.70 :      2886 elements
# Info    : 0.70 < quality < 0.80 :      4184 elements
# Info    : 0.80 < quality < 0.90 :       429 elements
# Info    : 0.90 < quality < 1.00 :       465 elements
# Info    : 79 edge swaps, 0 node relocations (volume = 4.50974e+06): worst = 0.165726 / average = 0.73006 (Wall 0.00216424s, CPU 0.001748s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         1 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        11 elements
# Info    : 0.40 < quality < 0.50 :        13 elements
# Info    : 0.50 < quality < 0.60 :       193 elements
# Info    : 0.60 < quality < 0.70 :      2882 elements
# Info    : 0.70 < quality < 0.80 :      4220 elements
# Info    : 0.80 < quality < 0.90 :       422 elements
# Info    : 0.90 < quality < 1.00 :       463 elements
# Info    : Optimizing volume 3
# Info    : Optimization starts (volume = 33883.6) with worst = 0.254011 / average = 0.78378:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        22 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 33883.6): worst = 0.476587 / average = 0.791422 (Wall 3.9111e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        23 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 4
# Info    : Optimization starts (volume = 33883.4) with worst = 0.173762 / average = 0.77818:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         1 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        17 elements
# Info    : 0.70 < quality < 0.80 :        22 elements
# Info    : 0.80 < quality < 0.90 :        45 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 33883.4): worst = 0.474555 / average = 0.785682 (Wall 3.2965e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        16 elements
# Info    : 0.70 < quality < 0.80 :        23 elements
# Info    : 0.80 < quality < 0.90 :        45 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 5
# Info    : Optimization starts (volume = 33844) with worst = 0.0126362 / average = 0.773595:
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        10 elements
# Info    : 0.70 < quality < 0.80 :        27 elements
# Info    : 0.80 < quality < 0.90 :        46 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 2 edge swaps, 0 node relocations (volume = 33844): worst = 0.476587 / average = 0.789075 (Wall 3.6876e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        10 elements
# Info    : 0.70 < quality < 0.80 :        28 elements
# Info    : 0.80 < quality < 0.90 :        46 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 6
# Info    : Optimization starts (volume = 33883.6) with worst = 0.254044 / average = 0.783284:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        10 elements
# Info    : 0.70 < quality < 0.80 :        27 elements
# Info    : 0.80 < quality < 0.90 :        48 elements
# Info    : 0.90 < quality < 1.00 :         5 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 33883.6): worst = 0.476587 / average = 0.790973 (Wall 3.1009e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        10 elements
# Info    : 0.70 < quality < 0.80 :        27 elements
# Info    : 0.80 < quality < 0.90 :        49 elements
# Info    : 0.90 < quality < 1.00 :         5 elements
# Info    : Optimizing volume 7
# Info    : Optimization starts (volume = 33883.6) with worst = 0.254011 / average = 0.78378:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        22 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 33883.6): worst = 0.476587 / average = 0.791422 (Wall 3.6038e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        23 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 8
# Info    : Optimization starts (volume = 33883.4) with worst = 0.255472 / average = 0.783571:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        22 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 33883.4): worst = 0.476587 / average = 0.791045 (Wall 4.0229e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        23 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 9
# Info    : Optimization starts (volume = 33883.6) with worst = 0.254011 / average = 0.78378:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        22 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 33883.6): worst = 0.476587 / average = 0.791422 (Wall 3.52e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        23 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 10
# Info    : Optimization starts (volume = 33883.4) with worst = 0.255472 / average = 0.783571:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        22 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 33883.4): worst = 0.476587 / average = 0.791045 (Wall 3.3523e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        23 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 11
# Info    : Optimization starts (volume = 33867.4) with worst = 0.305109 / average = 0.792377:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         1 elements
# Info    : 0.40 < quality < 0.50 :         1 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :         8 elements
# Info    : 0.70 < quality < 0.80 :        29 elements
# Info    : 0.80 < quality < 0.90 :        44 elements
# Info    : 0.90 < quality < 1.00 :        10 elements
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         1 elements
# Info    : 0.40 < quality < 0.50 :         1 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :         8 elements
# Info    : 0.70 < quality < 0.80 :        29 elements
# Info    : 0.80 < quality < 0.90 :        44 elements
# Info    : 0.90 < quality < 1.00 :        10 elements
# Info    : Optimizing volume 12
# Info    : Optimization starts (volume = 33844.3) with worst = 0.0126362 / average = 0.773802:
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        10 elements
# Info    : 0.70 < quality < 0.80 :        27 elements
# Info    : 0.80 < quality < 0.90 :        46 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 2 edge swaps, 0 node relocations (volume = 33844.3): worst = 0.476587 / average = 0.789452 (Wall 3.6318e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        10 elements
# Info    : 0.70 < quality < 0.80 :        28 elements
# Info    : 0.80 < quality < 0.90 :        46 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 13
# Info    : Optimization starts (volume = 33883.6) with worst = 0.254011 / average = 0.78378:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        22 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 33883.6): worst = 0.476587 / average = 0.791422 (Wall 3.073e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        23 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 14
# Info    : Optimization starts (volume = 33883.4) with worst = 0.255472 / average = 0.783571:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        22 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 33883.4): worst = 0.476587 / average = 0.791045 (Wall 3.2406e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        23 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 15
# Info    : Optimization starts (volume = 33844.3) with worst = 0.0126362 / average = 0.773802:
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        10 elements
# Info    : 0.70 < quality < 0.80 :        27 elements
# Info    : 0.80 < quality < 0.90 :        46 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 2 edge swaps, 0 node relocations (volume = 33844.3): worst = 0.476587 / average = 0.789452 (Wall 3.7714e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        10 elements
# Info    : 0.70 < quality < 0.80 :        28 elements
# Info    : 0.80 < quality < 0.90 :        46 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 16
# Info    : Optimization starts (volume = 33827.2) with worst = 0.476587 / average = 0.796012:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         1 elements
# Info    : 0.50 < quality < 0.60 :         1 elements
# Info    : 0.60 < quality < 0.70 :         9 elements
# Info    : 0.70 < quality < 0.80 :        26 elements
# Info    : 0.80 < quality < 0.90 :        51 elements
# Info    : 0.90 < quality < 1.00 :         6 elements
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         1 elements
# Info    : 0.50 < quality < 0.60 :         1 elements
# Info    : 0.60 < quality < 0.70 :         9 elements
# Info    : 0.70 < quality < 0.80 :        26 elements
# Info    : 0.80 < quality < 0.90 :        51 elements
# Info    : 0.90 < quality < 1.00 :         6 elements
# Info    : Optimizing volume 17
# Info    : Optimization starts (volume = 33827.2) with worst = 0.476587 / average = 0.796012:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         1 elements
# Info    : 0.50 < quality < 0.60 :         1 elements
# Info    : 0.60 < quality < 0.70 :         9 elements
# Info    : 0.70 < quality < 0.80 :        26 elements
# Info    : 0.80 < quality < 0.90 :        51 elements
# Info    : 0.90 < quality < 1.00 :         6 elements
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         1 elements
# Info    : 0.50 < quality < 0.60 :         1 elements
# Info    : 0.60 < quality < 0.70 :         9 elements
# Info    : 0.70 < quality < 0.80 :        26 elements
# Info    : 0.80 < quality < 0.90 :        51 elements
# Info    : 0.90 < quality < 1.00 :         6 elements
# Info    : Optimizing volume 18
# Info    : Optimization starts (volume = 33883.4) with worst = 0.255472 / average = 0.783571:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        22 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 1 edge swaps, 0 node relocations (volume = 33883.4): worst = 0.476587 / average = 0.791045 (Wall 4.3581e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         2 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        23 elements
# Info    : 0.80 < quality < 0.90 :        50 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 19
# Info    : Optimization starts (volume = 33844) with worst = 0.0126362 / average = 0.772732:
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         4 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        23 elements
# Info    : 0.80 < quality < 0.90 :        48 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : 2 edge swaps, 0 node relocations (volume = 33844): worst = 0.476587 / average = 0.788199 (Wall 9.3587e-05s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :         3 elements
# Info    : 0.60 < quality < 0.70 :        11 elements
# Info    : 0.70 < quality < 0.80 :        24 elements
# Info    : 0.80 < quality < 0.90 :        48 elements
# Info    : 0.90 < quality < 1.00 :         7 elements
# Info    : Optimizing volume 70
# Info    : Optimization starts (volume = 1.29309e+06) with worst = 0.0126362 / average = 0.781406:
# Info    : 0.00 < quality < 0.10 :         8 elements
# Info    : 0.10 < quality < 0.20 :        21 elements
# Info    : 0.20 < quality < 0.30 :        21 elements
# Info    : 0.30 < quality < 0.40 :        19 elements
# Info    : 0.40 < quality < 0.50 :        48 elements
# Info    : 0.50 < quality < 0.60 :       111 elements
# Info    : 0.60 < quality < 0.70 :       323 elements
# Info    : 0.70 < quality < 0.80 :       635 elements
# Info    : 0.80 < quality < 0.90 :       803 elements
# Info    : 0.90 < quality < 1.00 :       512 elements
# Info    : 50 edge swaps, 0 node relocations (volume = 1.29309e+06): worst = 0.304513 / average = 0.794016 (Wall 0.00114707s, CPU 0.000591s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        20 elements
# Info    : 0.40 < quality < 0.50 :        47 elements
# Info    : 0.50 < quality < 0.60 :       115 elements
# Info    : 0.60 < quality < 0.70 :       305 elements
# Info    : 0.70 < quality < 0.80 :       647 elements
# Info    : 0.80 < quality < 0.90 :       810 elements
# Info    : 0.90 < quality < 1.00 :       512 elements
# Info    : Done optimizing mesh (Wall 0.0121594s, CPU 0.008906s)
# Info    : Refining mesh...
# Info    : Meshing order 2 (curvilinear on)...
# Info    : [  0%] Meshing curve 4 order 2
# Info    : [ 10%] Meshing curve 5 order 2
# Info    : [ 10%] Meshing curve 6 order 2
# Info    : [ 10%] Meshing curve 7 order 2
# Info    : [ 10%] Meshing curve 8 order 2
# Info    : [ 10%] Meshing curve 9 order 2
# Info    : [ 10%] Meshing curve 13 order 2
# Info    : [ 10%] Meshing curve 14 order 2
# Info    : [ 10%] Meshing curve 15 order 2
# Info    : [ 10%] Meshing curve 16 order 2
# Info    : [ 10%] Meshing curve 17 order 2
# Info    : [ 10%] Meshing curve 18 order 2
# Info    : [ 10%] Meshing curve 19 order 2
# Info    : [ 10%] Meshing curve 20 order 2
# Info    : [ 10%] Meshing curve 21 order 2
# Info    : [ 10%] Meshing curve 22 order 2
# Info    : [ 20%] Meshing curve 23 order 2
# Info    : [ 20%] Meshing curve 24 order 2
# Info    : [ 20%] Meshing curve 25 order 2
# Info    : [ 20%] Meshing curve 26 order 2
# Info    : [ 20%] Meshing curve 27 order 2
# Info    : [ 20%] Meshing curve 28 order 2
# Info    : [ 20%] Meshing curve 29 order 2
# Info    : [ 20%] Meshing curve 30 order 2
# Info    : [ 20%] Meshing curve 31 order 2
# Info    : [ 20%] Meshing curve 32 order 2
# Info    : [ 20%] Meshing curve 33 order 2
# Info    : [ 20%] Meshing curve 34 order 2
# Info    : [ 20%] Meshing curve 35 order 2
# Info    : [ 20%] Meshing curve 36 order 2
# Info    : [ 20%] Meshing curve 37 order 2
# Info    : [ 30%] Meshing curve 38 order 2
# Info    : [ 30%] Meshing curve 39 order 2
# Info    : [ 30%] Meshing curve 40 order 2
# Info    : [ 30%] Meshing curve 41 order 2
# Info    : [ 30%] Meshing curve 42 order 2
# Info    : [ 30%] Meshing curve 43 order 2
# Info    : [ 30%] Meshing curve 44 order 2
# Info    : [ 30%] Meshing curve 45 order 2
# Info    : [ 30%] Meshing curve 46 order 2
# Info    : [ 30%] Meshing curve 47 order 2
# Info    : [ 30%] Meshing curve 48 order 2
# Info    : [ 30%] Meshing curve 49 order 2
# Info    : [ 30%] Meshing curve 50 order 2
# Info    : [ 30%] Meshing curve 51 order 2
# Info    : [ 30%] Meshing curve 52 order 2
# Info    : [ 30%] Meshing curve 53 order 2
# Info    : [ 40%] Meshing curve 54 order 2
# Info    : [ 40%] Meshing curve 55 order 2
# Info    : [ 40%] Meshing curve 56 order 2
# Info    : [ 40%] Meshing curve 57 order 2
# Info    : [ 40%] Meshing curve 58 order 2
# Info    : [ 40%] Meshing curve 59 order 2
# Info    : [ 40%] Meshing curve 60 order 2
# Info    : [ 40%] Meshing curve 61 order 2
# Info    : [ 40%] Meshing curve 62 order 2
# Info    : [ 40%] Meshing curve 63 order 2
# Info    : [ 40%] Meshing curve 64 order 2
# Info    : [ 40%] Meshing curve 65 order 2
# Info    : [ 40%] Meshing curve 66 order 2
# Info    : [ 40%] Meshing curve 67 order 2
# Info    : [ 40%] Meshing curve 68 order 2
# Info    : [ 50%] Meshing curve 69 order 2
# Info    : [ 50%] Meshing curve 70 order 2
# Info    : [ 50%] Meshing curve 71 order 2
# Info    : [ 50%] Meshing curve 72 order 2
# Info    : [ 50%] Meshing curve 73 order 2
# Info    : [ 50%] Meshing curve 74 order 2
# Info    : [ 50%] Meshing curve 75 order 2
# Info    : [ 50%] Meshing curve 76 order 2
# Info    : [ 50%] Meshing curve 77 order 2
# Info    : [ 50%] Meshing curve 78 order 2
# Info    : [ 50%] Meshing surface 4 order 2
# Info    : [ 50%] Meshing surface 5 order 2
# Info    : [ 50%] Meshing surface 6 order 2
# Info    : [ 50%] Meshing surface 7 order 2
# Info    : [ 50%] Meshing surface 11 order 2
# Info    : [ 50%] Meshing surface 12 order 2
# Info    : [ 60%] Meshing surface 13 order 2
# Info    : [ 60%] Meshing surface 14 order 2
# Info    : [ 60%] Meshing surface 15 order 2
# Info    : [ 60%] Meshing surface 16 order 2
# Info    : [ 60%] Meshing surface 17 order 2
# Info    : [ 60%] Meshing surface 18 order 2
# Info    : [ 60%] Meshing surface 19 order 2
# Info    : [ 60%] Meshing surface 20 order 2
# Info    : [ 60%] Meshing surface 21 order 2
# Info    : [ 60%] Meshing surface 22 order 2
# Info    : [ 60%] Meshing surface 23 order 2
# Info    : [ 60%] Meshing surface 24 order 2
# Info    : [ 60%] Meshing surface 25 order 2
# Info    : [ 60%] Meshing surface 26 order 2
# Info    : [ 60%] Meshing surface 27 order 2
# Info    : [ 70%] Meshing surface 28 order 2
# Info    : [ 70%] Meshing surface 29 order 2
# Info    : [ 70%] Meshing surface 30 order 2
# Info    : [ 70%] Meshing surface 31 order 2
# Info    : [ 70%] Meshing surface 32 order 2
# Info    : [ 70%] Meshing surface 33 order 2
# Info    : [ 70%] Meshing surface 34 order 2
# Info    : [ 70%] Meshing surface 35 order 2
# Info    : [ 70%] Meshing surface 36 order 2
# Info    : [ 70%] Meshing surface 37 order 2
# Info    : [ 70%] Meshing surface 38 order 2
# Info    : [ 70%] Meshing surface 39 order 2
# Info    : [ 70%] Meshing surface 40 order 2
# Info    : [ 70%] Meshing surface 41 order 2
# Info    : [ 70%] Meshing surface 42 order 2
# Info    : [ 80%] Meshing surface 43 order 2
# Info    : [ 80%] Meshing surface 44 order 2
# Info    : [ 80%] Meshing surface 45 order 2
# Info    : [ 80%] Meshing surface 46 order 2
# Info    : [ 80%] Meshing surface 47 order 2
# Info    : [ 80%] Meshing surface 48 order 2
# Info    : [ 80%] Meshing surface 49 order 2
# Info    : [ 80%] Meshing surface 50 order 2
# Info    : [ 80%] Meshing surface 51 order 2
# Info    : [ 80%] Meshing surface 52 order 2
# Info    : [ 80%] Meshing surface 53 order 2
# Info    : [ 80%] Meshing surface 54 order 2
# Info    : [ 80%] Meshing surface 55 order 2
# Info    : [ 80%] Meshing surface 56 order 2
# Info    : [ 80%] Meshing surface 57 order 2
# Info    : [ 80%] Meshing surface 58 order 2
# Info    : [ 90%] Meshing surface 59 order 2
# Info    : [ 90%] Meshing surface 60 order 2
# Info    : [ 90%] Meshing surface 61 order 2
# Info    : [ 90%] Meshing surface 62 order 2
# Info    : [ 90%] Meshing surface 63 order 2
# Info    : [ 90%] Meshing surface 64 order 2
# Info    : [ 90%] Meshing surface 65 order 2
# Info    : [ 90%] Meshing surface 66 order 2
# Info    : [ 90%] Meshing surface 67 order 2
# Info    : [ 90%] Meshing surface 68 order 2
# Info    : [ 90%] Meshing surface 69 order 2
# Info    : [ 90%] Meshing volume 1 order 2
# Info    : [ 90%] Meshing volume 3 order 2
# Info    : [ 90%] Meshing volume 4 order 2
# Info    : [ 90%] Meshing volume 5 order 2
# Info    : [100%] Meshing volume 6 order 2
# Info    : [100%] Meshing volume 7 order 2
# Info    : [100%] Meshing volume 8 order 2
# Info    : [100%] Meshing volume 9 order 2
# Info    : [100%] Meshing volume 10 order 2
# Info    : [100%] Meshing volume 11 order 2
# Info    : [100%] Meshing volume 12 order 2
# Info    : [100%] Meshing volume 13 order 2
# Info    : [100%] Meshing volume 14 order 2
# Info    : [100%] Meshing volume 15 order 2
# Info    : [100%] Meshing volume 16 order 2
# Info    : [100%] Meshing volume 17 order 2
# Info    : [100%] Meshing volume 18 order 2
# Info    : [100%] Meshing volume 19 order 2
# Info    : [100%] Meshing volume 70 order 2
# Info    : Surface mesh: worst distortion = 0.498181 (0 elements in ]0, 0.2]); worst gamma = 0.653208
# Info    : Volume mesh: worst distortion = 0.390136 (0 elements in ]0, 0.2])
# Info    : Done meshing order 2 (Wall 0.0660654s, CPU 0.063845s)
# Info    : Done refining mesh (Wall 0.115526s, CPU 0.109377s)
# Info    : 66500 nodes 76492 elements
# Info    : Writing 'disc.msh'...
# Info    : Done writing 'disc.msh'
# X_ChangeProperty: BadValue (integer parameter out of range for operation) 0x0
# -------------------------------------------------------
# Version       : 4.12.2
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 20240122
# Build host    : f6315eb856a7
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blossom Cairo DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack LinuxJoystick MathEx[contrib] Mesh Metis[contrib] Mpeg Netgen ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.3.9
# OCC version   : 7.7.2
# Packaged by   : conda
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------

# %%
print('Surfaces is', surfaces)
print('Volumes is', volumes)

# %% [markdown]
# # 2: Mesh plot
#
# THis part is from FEniCSx tutorial: Plotting the mesh using pyvista
#
# https://jsdokken.com/dolfinx-tutorial/chapter1/fundamentals_code.html

# %%
from dolfinx.io import gmshio
from mpi4py import MPI
import pyvista
from dolfinx import plot

# try a 3d mesh from gmsh, it works
domain, cell_markers, facet_markers = gmshio.read_from_msh("disc.msh", MPI.COMM_WORLD, 0, gdim=3)
gdim = 3
tdim = gdim -1 
pyvista.start_xvfb()
# below gdim change to tdim is plot for 2D
topology, cell_types, geometry = plot.vtk_mesh(domain, gdim)

grid = pyvista.UnstructuredGrid(topology, cell_types, geometry)
plotter = pyvista.Plotter()
plotter.add_mesh(grid, show_edges=True)
plotter.view_xy()

plotter.show()
