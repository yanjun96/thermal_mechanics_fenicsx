# %% [markdown]
# ## 1: time_step

# %%
from brake_libs_pdc import *
d = get_time_step_from_angular(61, 10, 1)
d = get_time_step_from_angular(112, 10, 1)
d = get_time_step_from_angular(224, 10, 1)
# Out:
# 1: Total tims is  48.31 s
# 2: Total numb steps is  2225
# 1: Total tims is  48.6 s
# 2: Total numb steps is  1213
# 1: Total tims is  49.89 s
# 2: Total numb steps is  608

# %%
from main_code_pdc import main_code_pdc

#c= [61,112,224]
c =[19]
angular = 36980
mesh_max = 10
c_contact = 1
type = 'time_step'

main_code_pdc(c, type ,angular, mesh_max, c_contact)
# Out:
# /home/yanjun/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# 1: Total tims is  48.31 s
# 2: Total numb steps is  2225
# The file 'm-3-10.msh' does not exist, start building:
# ...
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 4 (Circle)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Circle)
# Info    : [ 10%] Meshing curve 7 (Circle)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Circle)
# Info    : [ 10%] Meshing curve 10 (Circle)
# Info    : [ 10%] Meshing curve 11 (Line)
# Info    : [ 20%] Meshing curve 12 (Circle)
# Info    : [ 20%] Meshing curve 13 (Line)
# Info    : [ 20%] Meshing curve 14 (Line)
# ...

# %% [markdown]
# ## 2: mesh_size

# %%
from main_code_pdc import main_code_pdc

c= [1,2,3,5,7,10,15]

angular = 61
mesh_max = 10
c_contact = 1
type = 'mesh_size'

main_code_pdc(c, type ,angular, mesh_max, c_contact)

# %% [markdown]
# ## 3: contact_area

# %%
from main_code_pdc import main_code_pdc

c= [0.2,0.5,1]
angular = 112
mesh_max = 10
c_contact = 1
type = 'contact_area'

main_code_pdc(c, type ,angular, mesh_max, c_contact)

# %%
from brake_disc_functions import *

c= find_3_coord ('m-3-3.msh')

# %%
[94411, 114209, 8995]
