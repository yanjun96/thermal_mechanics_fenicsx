# %% [markdown]
# Author: yanjun zhang
#
# ## Concise
# ## 1: Start
#
# Source from
# book "Abali - 2017 - Computational Reality" P119
#
# import dolfinx
# print(f"DOLFINx version: {dolfinx.__version__}   \
# based on GIT commit:  \
# {dolfinx.git_commit_hash} of https://github.com/FEniCS/dolfinx/")

# %%
# import basic
import pyvista
import ufl
import dolfinx
import time
import sys
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt

# import speciail library
from dolfinx.fem.petsc import LinearProblem, assemble_vector, assemble_matrix, create_vector, apply_lifting, set_bc
from dolfinx           import fem, mesh, io, plot, default_scalar_type, nls, log
from dolfinx.fem       import Constant, dirichletbc, Function, FunctionSpace,form,locate_dofs_topological
from dolfinx.io        import XDMFFile, gmshio
from dolfinx.mesh      import locate_entities,locate_entities_boundary,meshtags
from ufl               import SpatialCoordinate, TestFunction, TrialFunction, dx, grad, inner, Measure, dot, FacetNormal
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from petsc4py          import PETSc
from mpi4py            import MPI

# import own functions
from brake_disc_functions import *

# calculate how long time the simulation it is 
start_time = time.time()

# mesh-size, contact area coefficient
mesh_min = 3
mesh_max = 10
c_contact = 1

# Each time step rotation angular, and acc during lag, 1 is full acc, 0 is no acc. 
angular_r = 75900*2
v_vehicle = 160 
c_acc = 1

# calling local functions to get all parameters
dt,P,g,num_steps,h,radiation,v_angular,Ti,Tm,S_rub_circle,t,rho,c,k,t_brake,S_total \
                = vehicle_initial (angular_r, v_vehicle, c_contact, c_acc)

print('1: Total tims is ', round(sum(dt),2), 's')
print('2: Total numb steps is ', num_steps)
plt.plot(P)
# Out:
# /home/yanjun/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# 1: Total tims is  56.67 s
# 2: Total numb steps is  3

# %% [markdown]
# ## 2: Mesh

# %%
######################################  mesh  ###################################3
mesh_name = f"{mesh_min}-{mesh_max}"
mesh_filename1 = "m-{}.msh".format(mesh_name)  
mesh_filename2 = "m-{}".format(mesh_name)  

if os.path.exists(mesh_filename1):
    # Run this command if the file exists
    print(f"The file '{mesh_filename1}' exists, start creat now:")
    domain, cell_markers, facet_markers = gmshio.read_from_msh(mesh_filename1, MPI.COMM_WORLD, 0, gdim=3)

else:
    # Run this command if the file does not exist
    print(f"The file '{mesh_filename1}' does not exist, start building:")
    mesh_brake_disc(mesh_min, mesh_max,mesh_filename2)
    domain, cell_markers, facet_markers = gmshio.read_from_msh(mesh_filename1, MPI.COMM_WORLD, 0, gdim=3)

# Define variational problem, Here Lagrange changes to CG, what is CG?
V = fem.FunctionSpace(domain, ('CG', 1))

# initialization
def project(function, space):
    u = TrialFunction(space)
    v = TestFunction(space)
    a = inner(u, v) * dx
    L = inner(function, v) * dx
    problem = LinearProblem(a, L, bcs = [])
    return problem.solve()
    
# u_n is for initial condition and uh is the solver result.
# variable, need to be projected form Q onto V
Q = FunctionSpace(domain, ("DG", 0))
T_init = Function(Q)
T_init.name = "u_n"
T_init.x.array[:] = np.full_like(1, Ti, dtype=default_scalar_type)
u_n = project(T_init,V)
u_n.name = "u_n"

fdim = domain.topology.dim - 1
## bc_disc is zero, no any dirichlete boundary condition
bc_disc = mesh.locate_entities_boundary(
    domain, fdim , lambda x:  np.isclose(x[2], 50) )
bc = fem.dirichletbc(PETSc.ScalarType(Tm), fem.locate_dofs_topological(V, fdim, bc_disc), V)
np.set_printoptions(threshold=np.inf)

import meshio
mesh1= meshio.read(mesh_filename1)
total_elements = sum( len(cells.data) for cells in mesh1.cells )
# Out:
# The file 'm-3-10.msh' exists, start creat now:
# Info    : Reading 'm-3-10.msh'...
# Info    : 168 entities
# Info    : 10751 nodes
# Info    : 43604 elements
# Info    : Done reading 'm-3-10.msh'

# %% [markdown]
# ## 3: Setup

# %%
xdmf_name = "T-s-{}-d-{}-{}-c-{}-e-{}.xdmf".format(num_steps, angular_r, mesh_filename2,c_contact,total_elements)
h5_name = "T-s-{}-d-{}-{}-c-{}-e-{}.h5".format(num_steps, angular_r, mesh_filename2,c_contact,total_elements)
xdmf = io.XDMFFile(domain.comm, xdmf_name, "w")
xdmf.write_mesh(domain)

# Create boundary condition

x_co, y_co = get_rub_coordinate()

common_indices3,facet_markers3,sorted_indices3 = target_facets(domain,x_co,y_co,S_rub_circle)
      
facet_tag = meshtags(domain, fdim, common_indices3[sorted_indices3], facet_markers3[sorted_indices3])
ds = Measure('ds', domain=domain, subdomain_data=facet_tag)

# %% [markdown]
# ## 4: Variational equation

# %%
uh = fem.Function(V)
uh.name = "uh"
uh = project(T_init,V)
t = 0
xdmf.write_function(uh, t)

#u = ufl.TrialFunction(V)
u = fem.Function(V)

v = ufl.TestFunction(V)
f = fem.Constant(domain, PETSc.ScalarType(0))
n_vector = FacetNormal(domain)

F = (rho*c)/dt[0]*inner(u,v)*dx + k*inner(grad(u),grad(v))*dx+  h*inner(u,v)*ds(200) + radiation*inner(u**4,v) *ds(200) \
- ( inner(f,v) *dx + (rho*c)/dt[0] * inner(u_n, v) * dx +  h * Tm * v *ds(200) +  radiation * (Tm**4)* v *ds(200) )


for i in list(range(1,19)):
     F +=  - k * dot( grad(u)* v, n_vector) *ds(10*i) - inner(g[0], v) *ds(10*i)

problem = NonlinearProblem(F, u, bcs=[bc])

## 7: Using petsc4py to create a linear solver
solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-6
solver.report = True

ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "cg"
opts[f"{option_prefix}pc_type"] = "gamg"
opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
ksp.setFromOptions()

log.set_log_level(log.LogLevel.INFO)
n, converged = solver.solve(u)
assert (converged)


## 8:Visualization of time dependent problem using pyvista
import matplotlib as mpl
pyvista.start_xvfb()
grid = pyvista.UnstructuredGrid(*plot.vtk_mesh(V))
plotter = pyvista.Plotter()

gif_name = "T-s-{}-d-{}-{}-c-{}-e-{}.gif".format(num_steps, angular_r, mesh_filename2,c_contact,total_elements)

plotter.open_gif(gif_name, fps=30)
grid.point_data["Temperature"] = u.x.array
warped = grid.warp_by_scalar("Temperature", factor=0)
viridis = mpl.colormaps.get_cmap("viridis").resampled(25)
sargs = dict(title_font_size=25, label_font_size=20,  color="black",
             position_x=0.1, position_y=0.8, width=0.8, height=0.1)
renderer = plotter.add_mesh(warped, show_edges=True, lighting=False,
                            cmap=viridis, scalar_bar_args=sargs,
                            #clim=[0, max(uh.x.array)])
                            clim=[0,  200])
# Out:
# 2024-05-01 23:20:14.459 (   4.841s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:14.557 (   4.939s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:14.645 (   5.027s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.135452 (tol = 1e-10) r (rel) = 2.17722e-05(tol = 1e-06)
# 2024-05-01 23:20:14.673 (   5.056s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:14.739 (   5.122s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 4.65815e-07 (tol = 1e-10) r (rel) = 7.48738e-11(tol = 1e-06)
# 2024-05-01 23:20:14.740 (   5.122s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 14 linear solver iterations.

# %% [markdown]
# ## 5: Solution

# %%
T_array = [(0, [Ti for _ in range( len(u.x.array))] )]
total_degree = 0

for i in range(num_steps):
    t += dt[i] 
 
    x_co, y_co = rub_rotation (x_co, y_co, angular_r)   # update the location
    total_degree += angular_r  # Incrementing degree by 10 in each step
    
    sys.stdout.write('\r1: Rotation has applied for {} degree. '.format(total_degree))
    sys.stdout.write('2: Current time is ' + str(round(t,1)) + " s. ")
    sys.stdout.write('3: Completion is '  + str(round (100*(t/t_brake),1) )+ " %. ")
    sys.stdout.flush()
    
    common_indices3,facet_markers3,sorted_indices3 = target_facets(domain,x_co,y_co,S_rub_circle)      
    facet_tag = meshtags(domain, fdim, common_indices3[sorted_indices3], facet_markers3[sorted_indices3])
    ds = Measure('ds', domain=domain, subdomain_data=facet_tag) 

    F = (rho*c)/dt[i]*inner(u,v)*dx + k*inner(grad(u),grad(v))*dx+  h*inner(u,v)*ds(200) + radiation*inner(u**4,v) *ds(200) \
    - ( inner(f,v) *dx + (rho*c)/dt[i] * inner(u_n, v) * dx +  h * 25* v *ds(200) +  radiation * (25**4)* v *ds(200) )

    for j in list(range(1,19)):
         F +=  - k * dot( grad(u)* v, n_vector) *ds(10*j) - inner(g[i], v) *ds(10*j)

    problem = NonlinearProblem(F, u, bcs=[bc])

    ## 7: Using petsc4py to create a linear solver
    solver = NewtonSolver(MPI.COMM_WORLD, problem)
    solver.convergence_criterion = "incremental"
    solver.rtol = 1e-6
    
    ksp = solver.krylov_solver
    opts = PETSc.Options()
    option_prefix = ksp.getOptionsPrefix()
    opts[f"{option_prefix}ksp_type"] = "cg"
    opts[f"{option_prefix}pc_type"] = "gamg"
    opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
    ksp.setFromOptions()

    sys.stdout.write('1: Completion is '  + str(round (100*(t/t_brake),1) )+ " %. ")
    sys.stdout.flush()

    solver.solve(u)
    u.x.scatter_forward()

    # Update solution at previous time step (u_n)
    u_n.x.array[:] = u.x.array
    
    T_array.append( (t, u.x.array.copy() ) )
    # Write solution to file
    xdmf.write_function(u, t)
    # Update plot
    #warped = grid.warp_by_scalar("uh", factor=0)
    plotter.update_coordinates(warped.points.copy(), render=False)
    plotter.update_scalars(u.x.array, render=False)
    plotter.write_frame()
    
plotter.close() 
xdmf.close()
print()

csv_name = "Result_T-s-{}-d-{}-{}-c-{}-e-{}.csv".format(num_steps, angular_r, mesh_filename2,c_contact,total_elements)
save_t_T(csv_name,T_array)
# Out:
# 1: Rotation has applied for 151800 degree. 2: Current time is 27.4 s. 3: Completion is 56.0 %.
# 2024-05-01 23:20:17.972 (   8.354s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.972 (   8.355s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.972 (   8.355s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.973 (   8.355s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.973 (   8.356s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.973 (   8.356s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.974 (   8.356s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.974 (   8.357s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.974 (   8.357s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.975 (   8.357s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.981 (   8.364s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.983 (   8.366s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.986 (   8.369s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.986 (   8.369s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.986 (   8.369s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.986 (   8.369s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.988 (   8.371s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.988 (   8.371s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.989 (   8.371s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.989 (   8.372s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.989 (   8.372s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.989 (   8.372s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.989 (   8.372s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.989 (   8.372s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.990 (   8.372s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.990 (   8.373s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.990 (   8.373s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.990 (   8.373s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.992 (   8.375s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.992 (   8.375s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.992 (   8.375s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.993 (   8.375s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.993 (   8.375s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.993 (   8.375s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.993 (   8.376s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.993 (   8.376s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.993 (   8.376s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.994 (   8.376s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.994 (   8.376s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.994 (   8.377s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.997 (   8.379s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.997 (   8.379s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.997 (   8.380s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.997 (   8.380s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.997 (   8.380s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.997 (   8.380s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.998 (   8.380s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.998 (   8.380s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.998 (   8.381s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.998 (   8.381s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.998 (   8.381s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:17.998 (   8.381s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.999 (   8.381s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:17.999 (   8.381s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:18.001 (   8.384s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:18.001 (   8.384s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:18.001 (   8.384s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 2
# 2024-05-01 23:20:18.004 (   8.387s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 0 - 3
# 2024-05-01 23:20:18.004 (   8.387s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:18.008 (   8.391s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:18.008 (   8.391s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:18.009 (   8.391s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:19.315 (   9.703s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:19.320 (   9.703s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-05-01 23:20:19.322 (   9.704s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:19.322 (   9.704s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 1: Completion is 56.0 %.
# 2024-05-01 23:20:20.660 (  11.044s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:20.662 (  11.045s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-05-01 23:20:20.665 (  11.048s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:20.665 (  11.048s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-05-01 23:20:20.669 (  11.052s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:20.690 (  11.073s) [main            ]    SparsityPattern.cpp:384   INFO| Column ghost size increased from 0 to 0
# 2024-05-01 23:20:20.744 (  11.127s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:20.848 (  11.230s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:20.908 (  11.291s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.000545691 (tol = 1e-10) r (rel) = 5.91662e-06(tol = 1e-06)
# 2024-05-01 23:20:20.945 (  11.327s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:21.009 (  11.392s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1.93284e-09 (tol = 1e-10) r (rel) = 2.09567e-11(tol = 1e-06)
# 2024-05-01 23:20:21.009 (  11.392s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 15 linear solver iterations.
# 2024-05-01 23:20:21.010 (  11.392s) [main            ]      xdmf_function.cpp:51    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# WARNING:py.warnings:/home/yanjun/.local/lib/python3.10/site-packages/pyvista/plotting/plotter.py:4722: PyVistaDeprecationWarning: This method is deprecated and will be removed in a future version of PyVista. Directly modify the points of a mesh in-place instead.
#   warnings.warn(
#
# WARNING:py.warnings:/home/yanjun/.local/lib/python3.10/site-packages/pyvista/plotting/plotter.py:4644: PyVistaDeprecationWarning: This method is deprecated and will be removed in a future version of PyVista. Directly modify the scalars of a mesh in-place instead.
#   warnings.warn(
# 1: Rotation has applied for 303600 degree. 2: Current time is 89.7 s. 3: Completion is 183.0 %.
# 2024-05-01 23:20:21.336 (  11.719s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.337 (  11.719s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.337 (  11.719s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.337 (  11.720s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.337 (  11.720s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.337 (  11.720s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.337 (  11.720s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.338 (  11.720s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.338 (  11.720s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.338 (  11.721s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.338 (  11.721s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.338 (  11.721s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.338 (  11.721s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.339 (  11.721s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.339 (  11.722s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.339 (  11.722s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.340 (  11.722s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.340 (  11.722s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.340 (  11.723s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.340 (  11.723s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.340 (  11.723s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.340 (  11.723s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.341 (  11.724s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.341 (  11.724s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.342 (  11.724s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.342 (  11.725s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.342 (  11.725s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.342 (  11.725s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.342 (  11.725s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.342 (  11.725s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.343 (  11.725s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.344 (  11.726s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.344 (  11.726s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.344 (  11.726s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.345 (  11.727s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.345 (  11.727s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.345 (  11.728s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.345 (  11.728s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.345 (  11.728s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.345 (  11.728s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.346 (  11.728s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.346 (  11.729s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.346 (  11.729s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.346 (  11.729s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.346 (  11.729s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.347 (  11.729s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.347 (  11.730s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.347 (  11.730s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.348 (  11.730s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.348 (  11.731s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.348 (  11.731s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.348 (  11.731s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.348 (  11.731s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.348 (  11.731s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.349 (  11.732s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:21.349 (  11.732s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:21.349 (  11.732s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 2
# 2024-05-01 23:20:21.352 (  11.734s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 0 - 3
# 2024-05-01 23:20:21.352 (  11.735s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.362 (  11.744s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.362 (  11.745s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:21.362 (  11.745s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:22.300 (  12.682s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:22.300 (  12.682s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-05-01 23:20:22.301 (  12.684s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:22.301 (  12.684s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 1: Completion is 183.0 %.
# 2024-05-01 23:20:23.491 (  13.874s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:23.491 (  13.874s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-05-01 23:20:23.493 (  13.875s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:23.493 (  13.875s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-05-01 23:20:23.498 (  13.881s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:23.521 (  13.904s) [main            ]    SparsityPattern.cpp:384   INFO| Column ghost size increased from 0 to 0
# 2024-05-01 23:20:23.563 (  13.946s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:23.803 (  14.185s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:23.946 (  14.329s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 1618.25 (tol = 1e-10) r (rel) = 0.0738608(tol = 1e-06)
# 2024-05-01 23:20:23.974 (  14.357s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:24.064 (  14.447s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 61.5869 (tol = 1e-10) r (rel) = 0.00281098(tol = 1e-06)
# 2024-05-01 23:20:24.093 (  14.476s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:24.196 (  14.579s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 0.0914697 (tol = 1e-10) r (rel) = 4.1749e-06(tol = 1e-06)
# 2024-05-01 23:20:24.225 (  14.608s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:24.291 (  14.674s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 5: r (abs) = 1.08563e-06 (tol = 1e-10) r (rel) = 4.95508e-11(tol = 1e-06)
# 2024-05-01 23:20:24.291 (  14.674s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 5 iterations and 113 linear solver iterations.
# 2024-05-01 23:20:24.292 (  14.674s) [main            ]      xdmf_function.cpp:51    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 1: Rotation has applied for 455400 degree. 2: Current time is 56.7 s. 3: Completion is 115.6 %.
# 2024-05-01 23:20:24.415 (  14.798s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.416 (  14.799s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.416 (  14.799s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.426 (  14.809s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.427 (  14.809s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.427 (  14.810s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.428 (  14.811s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.428 (  14.811s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.429 (  14.811s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.429 (  14.812s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.429 (  14.812s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.429 (  14.812s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.430 (  14.812s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.430 (  14.813s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.430 (  14.813s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.431 (  14.813s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.432 (  14.815s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.432 (  14.815s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.433 (  14.815s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.433 (  14.816s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.433 (  14.816s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.434 (  14.817s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.435 (  14.817s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.435 (  14.817s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.435 (  14.818s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.436 (  14.819s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.436 (  14.819s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.436 (  14.819s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.437 (  14.819s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.437 (  14.819s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.437 (  14.820s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.437 (  14.820s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.437 (  14.820s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.438 (  14.821s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.438 (  14.821s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.438 (  14.821s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.439 (  14.821s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.439 (  14.822s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.439 (  14.822s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.440 (  14.822s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.440 (  14.823s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.440 (  14.823s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.441 (  14.823s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.441 (  14.824s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.441 (  14.824s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.441 (  14.824s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.442 (  14.825s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.442 (  14.825s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.443 (  14.826s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.443 (  14.826s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.444 (  14.826s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.444 (  14.827s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.444 (  14.827s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.444 (  14.827s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.445 (  14.828s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:24.445 (  14.828s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:24.445 (  14.828s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 2
# 2024-05-01 23:20:24.449 (  14.832s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 0 - 3
# 2024-05-01 23:20:24.449 (  14.832s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.458 (  14.840s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.458 (  14.841s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-05-01 23:20:24.458 (  14.841s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-05-01 23:20:25.547 (  15.929s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:25.553 (  15.936s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-05-01 23:20:25.554 (  15.937s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:25.554 (  15.937s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 1: Completion is 115.6 %.
# 2024-05-01 23:20:26.650 (  17.033s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:26.650 (  17.033s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-05-01 23:20:26.654 (  17.037s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:26.654 (  17.037s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-05-01 23:20:26.663 (  17.046s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-05-01 23:20:26.696 (  17.079s) [main            ]    SparsityPattern.cpp:384   INFO| Column ghost size increased from 0 to 0
# 2024-05-01 23:20:26.752 (  17.135s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:26.853 (  17.236s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:26.939 (  17.322s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 2433.76 (tol = 1e-10) r (rel) = 0.166211(tol = 1e-06)
# 2024-05-01 23:20:26.978 (  17.361s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:27.040 (  17.423s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1130.25 (tol = 1e-10) r (rel) = 0.0771894(tol = 1e-06)
# 2024-05-01 23:20:27.071 (  17.454s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:27.142 (  17.524s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 269.328 (tol = 1e-10) r (rel) = 0.0183935(tol = 1e-06)
# 2024-05-01 23:20:27.168 (  17.551s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:27.222 (  17.605s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 5: r (abs) = 18.9402 (tol = 1e-10) r (rel) = 0.0012935(tol = 1e-06)
# 2024-05-01 23:20:27.255 (  17.638s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:27.308 (  17.691s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 6: r (abs) = 0.676123 (tol = 1e-10) r (rel) = 4.61751e-05(tol = 1e-06)
# 2024-05-01 23:20:27.337 (  17.720s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:27.390 (  17.773s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 7: r (abs) = 0.0225541 (tol = 1e-10) r (rel) = 1.54031e-06(tol = 1e-06)
# 2024-05-01 23:20:27.426 (  17.809s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-05-01 23:20:27.481 (  17.864s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 8: r (abs) = 0.000750467 (tol = 1e-10) r (rel) = 5.12524e-08(tol = 1e-06)
# 2024-05-01 23:20:27.481 (  17.864s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 8 iterations and 38 linear solver iterations.
# 2024-05-01 23:20:27.481 (  17.864s) [main            ]      xdmf_function.cpp:51    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# t and T have been successfully saved as Result_T-s-3-d-151800-m-3-10-c-1-e-43604.csv

# %% [markdown]
# # 6: Post process

# %%
# Display the GIF
from IPython.display import display, Image
display( Image(gif_name) )

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time1 = round(elapsed_time, 0)

formatted_start_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(start_time))
formatted_end_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(end_time))
txt_name = "T-s-{}-d-{}-{}-c-{}-e-{}.txt".format(num_steps, angular_r, mesh_filename2,c_contact,total_elements)
with open(txt_name, "w") as file:
   original_print = print
   print = lambda *args, **kwargs: original_print(*args, **kwargs, file=file)
    
   print("1: Start at:", formatted_start_time)
   print('2: End at', formatted_end_time)
    
   if elapsed_time1 >= 60:
      min = elapsed_time1/60
      hours = min/60
      print("3: Simulation time is",round(hours), 'hours', round(min),'minutes')
   else:
      print("3: Simulation time is",elapsed_time1, 'second')

   print('1: First time step dt is ', round(dt[0],5),'s')
   r_disc = 0.25

   print('2: Convection heat transfer coefficient is',h, ' W/mm2 K')
   print('3: Radiation is ', round(radiation,14), ' W/mm2 K-4')
   print('4: Each rotation degree is ', round(angular_r,1), ' per time step', 'or ', round(angular_r/360,1),' circle')
   print('5: The first rotation degree is ', round(v_angular[0] * r_disc * dt[0] *1000, 1) )
   print('6: The mid rotation degree is ', round(v_angular[ round(num_steps/2) ] * r_disc * dt[ round(len(dt)/2) ] *1000, 1) )
   print('7: The last rotation degree is ', round(v_angular[num_steps-1] * r_disc * dt[-1] *1000, 1) )
   print('9: Total contact area of 18 rubbing element is', round(S_total/100,1), 'cm2')
   print('10: The mesh element size is between ',mesh_min, '-',mesh_max, 'mm' )
   #print('11: Total elements number is ',total_elements )    

print = original_print 
with open(txt_name, "r") as file1:
   print( file1.read() )

#### move files
# Define the source directory
source_dir = "/home/yanjun/Documents/FEniCSx/Practice/Concise"
# Define the destination directory
destination_dir = "/home/yanjun/Documents/FEM_results"

# Create the new folder in the destination directory
new_folder_name = f"s-{num_steps}-d-{angular_r}-m-{mesh_min}-{mesh_max}-c-{c_contact}-e-{total_elements}"
destination_dir = os.path.join(destination_dir, new_folder_name)
os.makedirs(destination_dir, exist_ok=True)

# List of files to move
files_to_move = [
                 gif_name,
                 h5_name,
                 xdmf_name,
                 txt_name,
                 csv_name
                           ]
# Move each file to the destination directory
for filename in files_to_move:
    source_file_path = os.path.join(source_dir, filename)
    destination_file_path = os.path.join(destination_dir, filename)
    shutil.move(source_file_path, destination_file_path)
print('Move files successfully')
# Out:
# 1: Start at: 2024-05-01 23:20:09
# 2: End at 2024-05-01 23:20:27
# 3: Simulation time is 18.0 second
# 1: First time step dt is  27.42139 s
# 2: Convection heat transfer coefficient is 7.75e-05  W/mm2 K
# 3: Radiation is  3.6e-13  W/mm2 K-4
# 4: Each rotation degree is  151800  per time step or  421.7  circle
# 5: The first rotation degree is  662352.5
# 6: The mid rotation degree is  662352.5
# 7: The last rotation degree is  662352.5
# 9: Total contact area of 18 rubbing element is 199.9 cm2
# 10: The mesh element size is between  3 - 10 mm
#
# Move files successfully

# %%
## get t and temperature T form T_array matrix
t, T = [], []
for value in T_array:
    t.append(value[0])
    T.append(value[1])

## get nodes which only in friction surface
filename = mesh_filename1
nodes,node_tag = read_msh_file(filename)
print("Total nodes extracted:", len(nodes))  # Check the total number of nodes extracted

## get T_all with only friction surface
T_friction = []
T_all = []
for i in range(len(T)):
    T_friction = []
    for tag in node_tag:
       T_friction.append(T[i][tag-1])
    T_all.append(T_friction)
    
## get T_max in friciton surface

T_max = []
for i in range(len(T_all)):
    T_max.append( max(T_all[i]) )
      
plt.plot(t,T_max)
# Out:
# Total nodes extracted: 10751

# %%
from brake_disc_functions import *
lables = find_3_coord(mesh_filename1)

t, T = [], []
for value in T_array:
    t.append(value[0])
    T.append(value[1])

T_3_ave = []
for i in range(len(T)):
    T_3_all =  T[i][ lables[0] ] + T[i][ lables[1] ] + T[i][ lables[2] ]   
    T_3_ave.append ( T_3_all / 3 )

plt.plot(t,T_3_ave)
# Out:
# Lables already exists, for mesh m-3-10.msh is  [3157, 7018, 2141]

# %%
lables = find_3_coord(mesh_filename1)
#T_3_labels = 3157, 7018, 2141
#for i in range(len(T)):
 #   print( T[i][T_3_labels[1]] )
# Out:
# Lables already exists, for mesh m-3-10.msh is  [3157, 7018, 2141]
