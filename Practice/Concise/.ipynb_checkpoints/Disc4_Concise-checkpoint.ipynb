# %% [markdown]
# Author: yanjun zhang
#
# ## Concise
# ## 1: Start
#
# Source from
# book "Abali - 2017 - Computational Reality" P119
#
# import dolfinx
# print(f"DOLFINx version: {dolfinx.__version__}   \
# based on GIT commit:  \
# {dolfinx.git_commit_hash} of https://github.com/FEniCS/dolfinx/")

# %%
# import basic
import pyvista
import ufl
import dolfinx
import time
import sys
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt

# import speciail library
from dolfinx.fem.petsc import LinearProblem, assemble_vector, assemble_matrix, create_vector, apply_lifting, set_bc
from dolfinx           import fem, mesh, io, plot, default_scalar_type, nls, log
from dolfinx.fem       import Constant, dirichletbc, Function, FunctionSpace,form,locate_dofs_topological
from dolfinx.io        import XDMFFile, gmshio
from dolfinx.mesh      import locate_entities,locate_entities_boundary,meshtags
from ufl               import SpatialCoordinate, TestFunction, TrialFunction, dx, grad, inner, Measure, dot, FacetNormal
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from petsc4py          import PETSc
from mpi4py            import MPI

# import own functions
from brake_disc_functions import *

# calculate how long time the simulation it is 
start_time = time.time()

# mesh-size, contact area coefficient
mesh_min = 1
mesh_max = 15
c_contact = 1

# Each time step rotation angular, and acc during lag, 1 is full acc, 0 is no acc. 
angular_r = 35987
v_vehicle = 160 
c_acc = 1

# calling local functions to get all parameters
dt,P,g,num_steps,h,radiation,v_angular,Ti,Tm,S_rub_circle,t,rho,c,k,t_brake,S_total \
                = vehicle_initial (angular_r, v_vehicle, c_contact, c_acc)

print('1: Total tims is ', round(sum(dt),2), 's')
print('2: Total numb steps is ', num_steps)
plt.plot(P)
# Out:
# /home/yanjun/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# 1: Total tims is  26.3 s
# 2: Total numb steps is  6

# %% [markdown]
# ## 2: Mesh

# %%
######################################  mesh  ###################################3
mesh_name = f"{mesh_min}-{mesh_max}"
mesh_filename1 = "m-{}.msh".format(mesh_name)  
mesh_filename2 = "m-{}".format(mesh_name)  

if os.path.exists(mesh_filename1):
    # Run this command if the file exists
    print(f"The file '{mesh_filename1}' exists, start creat now:")
    domain, cell_markers, facet_markers = gmshio.read_from_msh(mesh_filename1, MPI.COMM_WORLD, 0, gdim=3)

else:
    # Run this command if the file does not exist
    print(f"The file '{mesh_filename1}' does not exist.")
    mesh_brake_disc(mesh_min, mesh_max,mesh_filename2)
    domain, cell_markers, facet_markers = gmshio.read_from_msh(mesh_filename1, MPI.COMM_WORLD, 0, gdim=3)

# Define variational problem, Here Lagrange changes to CG, what is CG?
V = fem.FunctionSpace(domain, ('CG', 1))

# initialization
def project(function, space):
    u = TrialFunction(space)
    v = TestFunction(space)
    a = inner(u, v) * dx
    L = inner(function, v) * dx
    problem = LinearProblem(a, L, bcs = [])
    return problem.solve()
    
# u_n is for initial condition and uh is the solver result.
# variable, need to be projected form Q onto V
Q = FunctionSpace(domain, ("DG", 0))
T_init = Function(Q)
T_init.name = "u_n"
T_init.x.array[:] = np.full_like(1, Ti, dtype=default_scalar_type)
u_n = project(T_init,V)
u_n.name = "u_n"

fdim = domain.topology.dim - 1
## bc_disc is zero, no any dirichlete boundary condition
bc_disc = mesh.locate_entities_boundary(
    domain, fdim , lambda x:  np.isclose(x[2], 50) )
bc = fem.dirichletbc(PETSc.ScalarType(Tm), fem.locate_dofs_topological(V, fdim, bc_disc), V)
np.set_printoptions(threshold=np.inf)

import meshio
mesh1= meshio.read(mesh_filename1)
total_elements = sum( len(cells.data) for cells in mesh1.cells )
# Out:
# The file 'm-1-15.msh' exists, start creat now:
# Info    : Reading 'm-1-15.msh'...
# Info    : 168 entities
# Info    : 4281 nodes
# Info    : 14875 elements
# Info    : Done reading 'm-1-15.msh'

# %% [markdown]
# ## 3: Setup

# %%
xdmf_name = "T-s-{}-d-{}-{}-c-{}-e-{}.xdmf".format(num_steps, angular_r, mesh_filename2,c_contact,total_elements)
h5_name = "T-s-{}-d-{}-{}-c-{}-e-{}.h5".format(num_steps, angular_r, mesh_filename2,c_contact,total_elements)
xdmf = io.XDMFFile(domain.comm, xdmf_name, "w")
xdmf.write_mesh(domain)

# Create boundary condition

x_co, y_co = get_rub_coordinate()

common_indices3,facet_markers3,sorted_indices3 = target_facets(domain,x_co,y_co,S_rub_circle)
      
facet_tag = meshtags(domain, fdim, common_indices3[sorted_indices3], facet_markers3[sorted_indices3])
ds = Measure('ds', domain=domain, subdomain_data=facet_tag)

# %%
print(common_indices3)
# Out:
# [ 6774  6800  7047  7115  7117  7153  7163  7747  7748  7836  7879  7884
#   8259  8361  8486  8491  8617  8627  8715  8730  8950  8956  8957  8973
#   9099  9101  9115  9120  9235  9402  9527  9529  9546  9637  9660  9806
#   9978  9981  9982 10297 10437 10609 10612 10697 10702 10709 10930 11083
#  11179 11181 11186 11442 11454 11633 11637 11737 11898 11902 12122 12139
#  12141 12193 12197 12544 12722 12866 12872 12896 12909 12918 13123 13224
#  13411 13417 13420 13641 13650 13678 13736 13758 13962 14257 14771    92
#     93    94    95    96    97   110   111   112   113   119   122   131
#    135   136   138   148   151   152   173   177   180   181   190   191
#    230   236   239   240   266   297   303   304   307   308   309   310
#    327   331   334   335   341   344   356   358   374   378   393   395
#    397   399   405   426   428   445   446   451   466   470   471   494
#    500   505   525   529   534   563   564   567   574   578   581   586
#    607   612   614   624   625   643   645   692   695   696   718   719
#    720   766   770   771   798   802   805   808   809   817   818   853
#    856   859   868   871   876   877   883   884   886   887   892   893
#    898   899   906   907   911   918   923   931   937   948   954   970
#    975   978   991   993  1003  1008  1010  1012  1015  1032  1052  1053
#   1063  1064  1069  1076  1091  1092  1102  1106  1109  1133  1134  1136
#   1138  1140  1165  1167  1185  1188  1246  1248  1255  1256  1262  1264
#   1303  1304  1307  1313  1320  1342  1351  1353  1359  1363  1364  1366
#   1367  1372  1374  1378  1379  1380  1381  1382  1387  1389  1398  1400
#   1404  1406  1413  1414  1426  1428  1442  1451  1454  1475  1476  1499
#   1505  1530  1536  1538  1541  1543  1550  1553  1559  1565  1569  1571
#   1603  1605  1609  1631  1634  1636  1653  1659  1662  1687  1690  1713
#   1731  1744  1753  1754  1756  1757  1758  1762  1763  1765  1768  1780
#   1782  1817  1819  1853  1858  1865  1867  1870  1871  1872  1874  1901
#   1902  1904  1918  1923  1927  1929  1934  1943  1947  1952  1972  1978
#   1982  1990  1992  1999  2000  2002  2004  2023  2024  2052  2057  2065
#   2066  2107  2113  2116  2126  2127  2130  2136  2150  2153  2168  2169
#   2198  2203  2217  2219  2231  2233  2238  2239  2250  2251  2252  2254
#   2260  2265  2271  2274  2296  2299  2304  2363  2366  2376  2377  2380
#   2390  2394  2398  2401  2406  2411  2418  2422  2428  2435  2451  2452
#   2455  2460  2469  2474  2499  2506  2509  2512  2524  2532  2533  2535
#   2536  2541  2545  2549  2554  2570  2573  2598  2601  2637  2664  2666
#   2681  2683  2695  2696  2704  2707  2710  2719  2720  2721  2724  2725
#   2751  2753  2758  2763  2768  2780  2781  2782  2817  2820  2821  2853
#   2855  2888  2890  2898  2903  2939  2955  2956  2957  2961  2996  3001
#   3004  3006  3008  3024  3025  3026  3027  3052  3058  3059  3060  3062
#   3064  3065  3066  3067  3077  3090  3093  3104  3105  3107  3109  3112
#   3113  3114  3118  3121  3135  3136  3140  3142  3167  3173  3180  3232
#   3233  3239  3257  3258  3283  3287  3305  3306  3310  3314  3321  3323
#   3326  3338  3342  3350  3352  3359  3361  3366  3386  3396  3401  3402
#   3407  3408  3409  3420  3421  3439  3472  3473  3477  3478  3479  3493
#   3494  3499  3503  3504  3524  3528  3551  3603  3604  3606  3611  3613
#   3633  3635  3644  3646  3647  3654  3662  3663  3665  3690  3694  3695
#   3722  3724  3725  3729  3736  3740  3747  3749  3754  3763  3778  3779
#   3783  3784  3796  3799  3805  3810  3821  3823  3827  3828  3834  3839
#   3841  3849  3861  3862  3879  3890  3937  3939  3942  3950  3951  3973
#   3975  3982  3986  3994  3999  4014  4023  4025  4032  4036  4042  4051
#   4055  4078  4082  4083  4085  4097  4099  4117  4121  4129  4131  4136
#   4154  4155  4192  4194  4201  4208  4210  4218  4226  4237  4238  4252
#   4256  4276  4280  4294  4296  4299  4302  4337  4362  4366  4369  4371
#   4373  4384  4385  4406  4410  4411  4412  4425  4434  4436  4458  4459
#   4469  4470  4473  4487  4489  4491  4493  4499  4504  4505  4508  4535
#   4540  4553  4555  4558  4562  4583  4584  4605  4606  4636  4637  4655
#   4658  4679  4681  4686  4705  4708  4709  4741  4744  4750  4754  4755
#   4778  4779  4786  4788  4793  4803  4805  4817  4822  4833  4836  4837
#   4838  4839  4841  4846  4850  4854  4861  4870  4877  4885  4890  4904
#   4906  4912  4917  4924  4941  4943  4955  4960  4966  4971  4983  4984
#   4999  5053  5061  5062  5067  5069  5125  5127  5131  5163  5165  5170
#   5172  5177  5179  5185  5187  5203  5206  5211  5213  5226  5229  5247
#   5254  5259  5261  5262  5265  5267  5271  5272  5278  5300  5304  5308
#   5309  5310  5311  5313  5316  5326  5328  5345  5346  5359  5397  5410
#   5416  5420  5443  5445  5452  5484  5495  5500  5502  5507  5515  5516
#   5518  5520  5525  5527  5532  5537  5545  5548  5551  5557  5566  5569
#   5572  5575  5578  5584  5589  5594  5599  5605  5606  5627  5648  5649
#   5654  5676  5677  5696  5723  5725  5728  5743  5744  5762  5764  5775
#   5776  5803  5805  5829  5849  5851  5854  5855  5857  5860  5865  5870
#   5890  5895  5903  5906  5911  5912  5924  5926  5928  5932  5941  5943
#   5947  5950  5967  5989  5996  6000  6003  6007  6008  6028  6032  6047
#   6056  6057  6059  6083  6084  6085  6087  6108  6116  6119  6122  6128
#   6132  6138  6148  6154  6160  6190  6191  6196  6213  6214  6222  6223
#   6225  6231  6232  6257  6259  6264  6273  6274  6278  6289  6293  6294
#   6323  6347  6349  6360  6367  6369  6378  6380  6418  6424  6426  6429
#   6442  6448  6455  6456  6469  6473  6478  6496  6502  6507  6510  6520
#   6530  6533  6539  6545  6557  6559  6564  6569  6574  6576  6586  6589
#   6590  6601  6602  6604  6640  6642  6658  6661  6690  6696  6698  6700
#   6705  6706  6718  6720  6760  6763  6767  6768  6775  6799  6808  6826
#   6831  6832  6874  6876  6883  6884  6887  6895  6899  6905  6915  6918
#   6919  6920  6941  6947  6951  6954  6962  6964  6983  6987  6989  7004
#   7018  7019  7021  7046  7061  7062  7063  7068  7073  7078  7086  7096
#   7098  7104  7127  7130  7132  7142  7143  7145  7149  7156  7161  7168
#   7176  7220  7221  7231  7232  7233  7235  7241  7265  7266  7294  7295
#   7306  7312  7318  7322  7342  7346  7353  7355  7357  7361  7374  7375
#   7412  7418  7421  7432  7434  7442  7443  7447  7464  7465  7467  7483
#   7485  7496  7497  7499  7502  7506  7509  7514  7516  7521  7523  7568
#   7575  7580  7587  7597  7627  7632  7647  7648  7661  7664  7666  7679
#   7683  7698  7703  7713  7715  7719  7724  7734  7735  7738  7746  7768
#   7777  7784  7785  7789  7823  7826  7832  7839  7857  7859  7872  7876
#   7886  7901  7904  7924  7925  7972  7984  7985  7987  7992  8003  8004
#   8006  8011  8013  8020  8038  8039  8041  8057  8058  8059  8061  8063
#   8065  8066  8067  8068  8070  8083  8117  8119  8122  8130  8131  8145
#   8147  8150  8154  8156  8176  8178  8194  8226  8228  8231  8233  8240
#   8243  8247  8248  8262  8265  8277  8278  8320  8323  8332  8334  8351
#   8354  8356  8363  8368  8370  8376  8378  8401  8402  8418  8422  8425
#   8429  8438  8452  8455  8460  8484  8514  8516  8517  8518  8523  8525
#   8530  8534  8540  8543  8553  8555  8569  8581  8594  8599  8601  8621
#   8630  8632  8651  8653  8654  8686  8688  8719  8740  8745  8747  8752
#   8769  8772  8781  8785  8788  8794  8816  8819  8832  8834  8839  8846
#   8848  8867  8889  8898  8902  8915  8921  8922  8924  8927  8930  8948
#   8972  8975  8993  9009  9011  9017  9024  9026  9035  9036  9042  9059
#   9062  9067  9094  9095  9160  9162  9164  9193  9194  9198  9204  9206
#   9208  9221  9230  9236  9240  9243  9247  9250  9269  9272  9274  9277
#   9279  9286  9288  9290  9298  9308  9310  9315  9323  9358  9361  9364
#   9370  9373  9385  9389  9392  9405  9419  9421  9428  9436  9440  9442
#   9445  9463  9470  9479  9484  9548  9574  9577  9578  9612  9613  9624
#   9630  9633  9635  9642  9644  9651  9668  9671  9680  9687  9689  9695
#   9697  9704  9705  9713  9716  9725  9726  9744  9775  9779  9782  9794
#   9795  9799  9809  9850  9851  9852  9880  9881  9883  9935  9948  9951
#   9961 10021 10023 10027 10031 10035 10041 10044 10051 10060 10062 10081
#  10083 10088 10089 10100 10102 10108 10112 10120 10121 10128 10129 10132
#  10143 10145 10156 10158 10176 10183 10190 10197 10226 10231 10233 10245
#  10246 10247 10258 10262 10284 10286 10288 10292 10293 10299 10305 10314
#  10315 10324 10330 10331 10343 10350 10367 10371 10374 10380 10441 10448
#  10451 10479 10481 10507 10509 10512 10517 10518 10545 10551 10552 10561
#  10566 10570 10582 10597 10599 10623 10626 10635 10640 10645 10647 10690
#  10708 10727 10729 10746 10753 10758 10773 10782 10785 10810 10843 10845
#  10852 10874 10875 10912 10916 10919 10927 10944 10945 10950 10981 10982
#  10983 10994 10995 10997 10998 11000 11007 11009 11015 11016 11031 11034
#  11047 11050 11069 11073 11074 11085 11099 11100 11128 11131 11133 11135
#  11136 11137 11140 11143 11160 11162 11170 11174 11177 11190 11193 11232
#  11237 11238 11241 11255 11258 11262 11279 11283 11284 11292 11295 11312
#  11319 11324 11349 11350 11352 11360 11363 11384 11387 11406 11410 11425
#  11428 11437 11439 11445 11448 11462 11469 11483 11485 11487 11490 11498
#  11503 11506 11535 11538 11571 11572 11635 11643 11649 11660 11662 11673
#  11675 11677 11682 11683 11687 11693 11697 11735 11736 11750 11762 11763
#  11766 11774 11775 11781 11782 11808 11810 11811 11815 11816 11831 11832
#  11861 11865 11877 11884 11887 11888 11889 11900 11988 11989 11990 12006
#  12010 12012 12026 12051 12053 12057 12065 12073 12086 12092 12102 12105
#  12112 12117 12126 12159 12162 12163 12168 12169 12170 12171 12173 12186
#  12203 12212 12218 12221 12243 12257 12259 12265 12268 12275 12282 12284
#  12287 12290 12293 12301 12306 12317 12320 12332 12334 12338 12348 12351
#  12353 12379 12385 12389 12411 12414 12415 12429 12431 12435 12439 12446
#  12456 12459 12465 12466 12486 12496 12497 12500 12520 12522 12543 12564
#  12570 12599 12602 12605 12651 12652 12668 12670 12673 12683 12697 12702
#  12706 12717 12718 12724 12728 12729 12737 12754 12758 12760 12777 12780
#  12783 12819 12821 12879 12884 12892 12906 12913 12922 12923 12951 12955
#  12958 12974 12979 12981 12988 12989 12999 13004 13007 13010 13013 13014
#  13030 13032 13039 13040 13042 13065 13066 13100 13107 13112 13119 13149
#  13151 13156 13160 13173 13174 13178 13179 13193 13194 13197 13202 13213
#  13216 13219 13223 13241 13245 13248 13254 13271 13278 13280 13284 13293
#  13303 13308 13359 13361 13375 13379 13423 13437 13438 13454 13457 13460
#  13473 13474 13481 13482 13483 13487 13492 13507 13509 13515 13517 13554
#  13556 13565 13570 13571 13572 13580 13605 13609 13611 13639 13659 13664
#  13680 13683 13686 13687 13688 13689 13700 13702 13709 13713 13734 13753
#  13767 13769 13796 13804 13805 13806 13857 13867 13869 13870 13873 13915
#  13920 13921 13941 13945 13950 13951 13954 13956 13968 13988 13991 13993
#  14001 14003 14025 14027 14037 14038 14047 14049 14053 14054 14057 14060
#  14061 14069 14071 14093 14098 14136 14138 14151 14152 14159 14167 14169
#  14175 14177 14179 14194 14201 14203 14219 14220 14254 14258 14269 14271
#  14274 14276 14279 14286 14288 14294 14297 14300 14310 14321 14323 14326
#  14328 14331 14339 14342 14352 14354 14374 14381 14382 14388 14404 14407
#  14434 14466 14480 14486 14499 14502 14545 14548 14551 14554 14574 14575
#  14578 14579 14580 14581 14582 14583 14587 14589 14637 14639 14649 14651
#  14661 14666 14674 14680 14682 14685 14687 14698 14701 14706 14746 14748
#  14752 14754 14759 14762 14773 14777 14784 14792 14795 14796 14797 14799
#  14801 14814 14824 14827 14828 14829 14844 14849 14853 14860 14866 14867
#  14889 14892 14908 14911 14921 14926 14929 14936 14942 14944 14958 14963
#  14996 14997 14999 15002 15012 15019 15021 15028 15031 15044 15045 15046
#  15047 15065 15066 15077 15079 15083 15096 15130 15133 15135 15138 15196
#  15198 15210 15213 15215 15240 15241 15251 15253 15264 15266 15274 15277
#  15293 15298 15301 15313 15315 15329 15330 15331 15332 15333 15335 15338
#  15346 15347 15348 15355 15356 15364 15367 15387 15391 15399 15400 15413
#  15431 15432 15439 15460 15468 15473 15475 15490 15492 15497 15522 15523
#  15525 15548 15551 15562 15563 15566 15574 15576 15579 15620 15643 15644
#  15645 15646 15648 15650 15663 15664 15666 15672 15681 15688 15694 15695
#  15722 15729 15736 15738 15741 15745 15767 15768 15778 15779 15794 15795
#  15809 15816 15821 15824 15834 15835 15864 15876 15878 15887 15890 15891
#  15917 15921 15932 15938 15939 15940 15945 15950 15951 15974 15986 15989
#  15996 16003 16006 16021 16022 16027 16030 16031 16038 16048 16054 16060
#  16066 16074 16077 16089 16092 16120 16124 16126 16129 16134 16157 16159
#  16173 16175 16184 16191 16201 16221 16223 16250 16267 16270 16272 16274
#  16283 16284 16285 16291 16292 16312 16314 16326 16329 16332 16359 16361
#  16371 16426 16431 16432 16446 16449 16456 16463 16464 16466 16467 16476
#  16477 16481 16499 16508 16513 16519 16525 16533 16541 16543 16568 16569
#  16570 16585 16588 16596 16597 16598 16603 16604 16623 16625 16626 16681
#  16696 16698 16714 16716 16723 16726 16738 16739 16755 16761 16764 16765
#  16770 16772 16777 16778 16799 16800 16805 16806 16809 16824 16826 16842
#  16845 16855 16857 16859 16864 16867 16874 16900 16901 16915 16925 16927
#  16943 16948 16950 16951 16970 16973 16975 17003 17007 17012 17062 17065
#  17074 17076 17078 17088 17096 17098 17113 17114 17116 17119 17121 17129
#  17132 17137 17140 17148 17173 17175 17180 17181 17182 17187 17189 17204
#  17207 17208 17237 17238 17271 17295 17297 17300 17302 17308 17309 17318
#  17323 17328 17331 17335 17338 17339 17347 17348 17349 17371 17377 17380
#  17381 17398 17399 17422 17423 17432 17436 17437 17447 17449 17469 17472
#  17503 17504 17508 17518 17521 17523 17543 17546 17552 17553 17565 17567
#  17571 17581 17583 17647 17668 17669 17673 17677 17679 17692 17697 17706
#  17707 17712 17732 17739 17752 17754 17763 17765 17767 17771 17773 17775
#  17776 17779 17782 17783 17784 17788 17792 17801 17809 17814 17833 17834
#  17849 17890 17893 17899 17907 17909 17919 17921 17948 17952 17959 17965
#  17978 17981 17986 18003 18006 18012 18016 18019 18039 18042 18051 18053
#  18058 18060 18062 18072 18076 18077 18088 18094 18095 18097 18098 18113
#  18116 18129 18132 18145 18167 18187 18192 18197 18199 18201 18204 18208
#  18209 18215 18217 18250 18252 18260 18262 18264 18292 18294 18296 18326
#  18328 18331 18332 18334 18343 18366 18371 18375 18380 18385 18394 18403
#  18409 18414 18422 18424 18437 18444 18449 18455 18500 18502 18504 18520
#  18521 18528 18540 18541 18542 18560 18565 18584 18587 18590 18620 18621
#  18624 18629 18630 18635 18664 18666 18667 18673 18676 18700 18709 18711
#  18714 18719 18726 18730 18735 18746 18748 18793 18797 18802 18809 18810
#  18811 18830 18837 18839 18845 18847 18853 18855 18857 18868 18869 18873
#  18878 18881 18932 18933 18987 18990 18991 19009 19010 19016 19021 19030
#  19032 19035 19037 19039 19041 19045 19046 19052 19058 19063 19076 19078
#  19101 19108 19110 19122 19124 19127 19136 19138 19144 19148 19157 19215
#  19230 19244 19257 19259 19262 19267 19273 20150 20151 20152 20153 20154
#  20155 20156 20160 20161 20273 20277 20278 20281 20365 21141 21142 21143
#  21144 21145 21146 21147 21149 21152 21450 21451 21452 21453 21456 21556
#  21557 21558 21559 21560 21561 21573 21576 21577 21787 21788 21972 21974
#  21976 22162 22163 22164 22165 22166 22177 22178 22179 22180 22469 22471
#  22472 22481 22482 22677 22678 22679 22680 22681 22691 22692 22696 22697
#  22698 22699 22702 22703 22704 22708 22709 22710 22711 22845 22846 22847
#  22848 22862 22986 22989 22991 22998 23001 23559 23560 23561 23562 23563
#  23577 23578 23579 23580 23769 23771 23772 23781 23782 23940 23941 23944
#  23945 23946 23950 23951 23952 23953 23972 23973 23976 23977 23978 23982
#  23983 23984 23985 24150 24152 24155 24158 24196 24199 24201 24208 24211
#  24221 25225 25226 25227 25228 25229 25390 25394 25395 25397 25407 25411
#  25412 25413 25451 25452 25453 25454 25455 25456 25457 25458 25459 25528
#  25591 25593 25594 25597 25662 25663 25664 25665 25666 25667 25668 25671
#  25674 25678 25944 25945 25988 26111 26114 26590 26591 26592 26593 26594
#  26693 26697 26698 26700 26713 26717 26718 26719 26943 26959 26960 26961
#  26962 26963 26967 26968 26969 26970 26993 26997 26998 27000 27012 27013
#  27014 27015 27016 27124 27128 27129 27130 27131 27137 27140 27142 27184
#  27314 27870 27871 27872 27873 27874 27878 27879 27880 27881 28020 28021
#  28022 28023 28024 28028 28029 28030 28031 28056 28058 28061 28064 28081
#  28178 28182 28183 28184 28191 28390 28391 28392 28393 28394 28395 28396
#  28397 28398 28412 28416 28417 28419 28443]

# %% [markdown]
# ## 4: Variational equation

# %%
uh = fem.Function(V)
uh.name = "uh"
uh = project(T_init,V)
t = 0
xdmf.write_function(uh, t)

#u = ufl.TrialFunction(V)
u = fem.Function(V)

v = ufl.TestFunction(V)
f = fem.Constant(domain, PETSc.ScalarType(0))
n_vector = FacetNormal(domain)

F = (rho*c)/dt[0]*inner(u,v)*dx + k*inner(grad(u),grad(v))*dx+  h*inner(u,v)*ds(200) + radiation*inner(u**4,v) *ds(200) \
- ( inner(f,v) *dx + (rho*c)/dt[0] * inner(u_n, v) * dx +  h * Tm * v *ds(200) +  radiation * (Tm**4)* v *ds(200) )


for i in list(range(1,19)):
     F +=  - k * dot( grad(u)* v, n_vector) *ds(10*i) - inner(g[0], v) *ds(10*i)

problem = NonlinearProblem(F, u, bcs=[bc])

## 7: Using petsc4py to create a linear solver
solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-6
solver.report = True

ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "cg"
opts[f"{option_prefix}pc_type"] = "gamg"
opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
ksp.setFromOptions()

log.set_log_level(log.LogLevel.INFO)
n, converged = solver.solve(u)
assert (converged)


## 8:Visualization of time dependent problem using pyvista
import matplotlib as mpl
pyvista.start_xvfb()
grid = pyvista.UnstructuredGrid(*plot.vtk_mesh(V))
plotter = pyvista.Plotter()

gif_name = "T-s-{}-d-{}-{}-c-{}-e-{}.gif".format(num_steps, angular_r, mesh_filename2,c_contact,total_elements)

plotter.open_gif(gif_name, fps=30)
grid.point_data["Temperature"] = u.x.array
warped = grid.warp_by_scalar("Temperature", factor=0)
viridis = mpl.colormaps.get_cmap("viridis").resampled(25)
sargs = dict(title_font_size=25, label_font_size=20,  color="black",
             position_x=0.1, position_y=0.8, width=0.8, height=0.1)
renderer = plotter.add_mesh(warped, show_edges=True, lighting=False,
                            cmap=viridis, scalar_bar_args=sargs,
                            #clim=[0, max(uh.x.array)])
                            clim=[0,  200])
# Out:
# 2024-04-30 15:44:15.022 (   3.334s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:15.049 (   3.361s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:15.067 (   3.379s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0442053 (tol = 1e-10) r (rel) = 1.12603e-05(tol = 1e-06)
# 2024-04-30 15:44:15.074 (   3.386s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:15.092 (   3.404s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 1.37817e-07 (tol = 1e-10) r (rel) = 3.51057e-11(tol = 1e-06)
# 2024-04-30 15:44:15.093 (   3.405s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 14 linear solver iterations.

# %% [markdown]
# ## 5: Solution

# %%
T_array = []
total_degree = 0
for i in range(num_steps):
    t += dt[i] 
 
    x_co, y_co = rub_rotation (x_co, y_co, angular_r)   # update the location
    total_degree += angular_r  # Incrementing degree by 10 in each step
    
    sys.stdout.write('\r1: Rotation has applied for {} degree. '.format(total_degree))
    sys.stdout.write('2: Current time is ' + str(round(t,1)) + " s. ")
    sys.stdout.write('3: Completion is '  + str(round (100*(t/t_brake),1) )+ " %. ")
    sys.stdout.flush()
    
    common_indices3,facet_markers3,sorted_indices3 = target_facets(domain,x_co,y_co,S_rub_circle)      
    facet_tag = meshtags(domain, fdim, common_indices3[sorted_indices3], facet_markers3[sorted_indices3])
    ds = Measure('ds', domain=domain, subdomain_data=facet_tag) 

    F = (rho*c)/dt[i]*inner(u,v)*dx + k*inner(grad(u),grad(v))*dx+  h*inner(u,v)*ds(200) + radiation*inner(u**4,v) *ds(200) \
    - ( inner(f,v) *dx + (rho*c)/dt[i] * inner(u_n, v) * dx +  h * 25* v *ds(200) +  radiation * (25**4)* v *ds(200) )

    for j in list(range(1,19)):
         F +=  - k * dot( grad(u)* v, n_vector) *ds(10*j) - inner(g[i], v) *ds(10*j)

    problem = NonlinearProblem(F, u, bcs=[bc])

    ## 7: Using petsc4py to create a linear solver
    solver = NewtonSolver(MPI.COMM_WORLD, problem)
    solver.convergence_criterion = "incremental"
    solver.rtol = 1e-6
    
    ksp = solver.krylov_solver
    opts = PETSc.Options()
    option_prefix = ksp.getOptionsPrefix()
    opts[f"{option_prefix}ksp_type"] = "cg"
    opts[f"{option_prefix}pc_type"] = "gamg"
    opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
    ksp.setFromOptions()

    sys.stdout.write('1: Completion is '  + str(round (100*(t/t_brake),1) )+ " %. ")
    sys.stdout.flush()

    solver.solve(u)
    u.x.scatter_forward()

    # Update solution at previous time step (u_n)
    u_n.x.array[:] = u.x.array

    T_array.append( (t,u.x.array) )
    # Write solution to file
    xdmf.write_function(u, t)
    # Update plot
    #warped = grid.warp_by_scalar("uh", factor=0)
    plotter.update_coordinates(warped.points.copy(), render=False)
    plotter.update_scalars(u.x.array, render=False)
    plotter.write_frame()
    
plotter.close() 
xdmf.close()
print()
# Out:
# 1: Rotation has applied for 35987 degree. 2: Current time is 6.5 s. 3: Completion is 13.3 %.
# 2024-04-30 15:44:18.430 (   6.742s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.430 (   6.742s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.430 (   6.742s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.430 (   6.742s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.430 (   6.742s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.431 (   6.742s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.431 (   6.743s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.432 (   6.744s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.432 (   6.744s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.432 (   6.744s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.432 (   6.744s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.433 (   6.744s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.433 (   6.744s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.433 (   6.745s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.433 (   6.745s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.433 (   6.745s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.433 (   6.745s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.433 (   6.745s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.433 (   6.745s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.434 (   6.745s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.434 (   6.745s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.434 (   6.746s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.434 (   6.746s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.434 (   6.746s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.434 (   6.746s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.434 (   6.746s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.434 (   6.746s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.434 (   6.746s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.435 (   6.746s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.435 (   6.746s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.435 (   6.747s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.435 (   6.747s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.435 (   6.747s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.435 (   6.747s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.435 (   6.747s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.435 (   6.747s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.435 (   6.747s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.436 (   6.747s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.436 (   6.747s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.437 (   6.749s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.439 (   6.751s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.439 (   6.751s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.439 (   6.751s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.439 (   6.751s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.439 (   6.751s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.439 (   6.751s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.439 (   6.751s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.439 (   6.751s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.439 (   6.751s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.443 (   6.755s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.443 (   6.755s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.443 (   6.755s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.443 (   6.755s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.443 (   6.755s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.446 (   6.758s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:18.447 (   6.758s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.447 (   6.758s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 2
# 2024-04-30 15:44:18.447 (   6.759s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 0 - 3
# 2024-04-30 15:44:18.447 (   6.759s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.454 (   6.766s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.455 (   6.767s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:18.455 (   6.767s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:18.842 (   7.154s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:18.843 (   7.155s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:18.843 (   7.155s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:18.843 (   7.155s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 1: Completion is 13.3 %.
# 2024-04-30 15:44:19.139 (   7.451s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:19.158 (   7.470s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:19.158 (   7.470s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:19.158 (   7.470s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:19.165 (   7.477s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:19.170 (   7.482s) [main            ]    SparsityPattern.cpp:384   INFO| Column ghost size increased from 0 to 0
# 2024-04-30 15:44:19.185 (   7.497s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:19.231 (   7.543s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:19.254 (   7.566s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 3.82006e-05 (tol = 1e-10) r (rel) = 2.10112e-06(tol = 1e-06)
# 2024-04-30 15:44:19.263 (   7.575s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# WARNING:py.warnings:/home/yanjun/.local/lib/python3.10/site-packages/pyvista/plotting/plotter.py:4716: PyVistaDeprecationWarning: This method is deprecated and will be removed in a future version of PyVista. Directly modify the points of a mesh in-place instead.
#   warnings.warn(
#
# 2024-04-30 15:44:19.287 (   7.598s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 9.59612e-11 (tol = 1e-10) r (rel) = 5.2781e-12(tol = 1e-06)
# 2024-04-30 15:44:19.287 (   7.598s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 15 linear solver iterations.
# 2024-04-30 15:44:19.287 (   7.599s) [main            ]      xdmf_function.cpp:51    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# WARNING:py.warnings:/home/yanjun/.local/lib/python3.10/site-packages/pyvista/plotting/plotter.py:4638: PyVistaDeprecationWarning: This method is deprecated and will be removed in a future version of PyVista. Directly modify the scalars of a mesh in-place instead.
#   warnings.warn(
# 1: Rotation has applied for 71974 degree. 2: Current time is 14.0 s. 3: Completion is 28.6 %.
# 2024-04-30 15:44:19.565 (   7.877s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.565 (   7.877s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.565 (   7.877s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.565 (   7.877s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.566 (   7.878s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.566 (   7.878s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.566 (   7.878s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.566 (   7.878s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.566 (   7.878s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.566 (   7.878s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.566 (   7.878s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.566 (   7.878s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.566 (   7.878s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.567 (   7.878s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.567 (   7.878s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.567 (   7.879s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.567 (   7.879s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.567 (   7.879s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.567 (   7.879s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.567 (   7.879s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.567 (   7.879s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.567 (   7.879s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.567 (   7.879s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.567 (   7.879s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.568 (   7.879s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.568 (   7.879s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.568 (   7.880s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.569 (   7.881s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.569 (   7.881s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.569 (   7.881s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.570 (   7.881s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.570 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.570 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.570 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.570 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.570 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.570 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.570 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.570 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.570 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.571 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.571 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.571 (   7.882s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.571 (   7.883s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.571 (   7.883s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.571 (   7.883s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.571 (   7.883s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.571 (   7.883s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.571 (   7.883s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.571 (   7.883s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.571 (   7.883s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.571 (   7.883s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.572 (   7.883s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.572 (   7.883s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.573 (   7.885s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:19.573 (   7.885s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.573 (   7.885s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 2
# 2024-04-30 15:44:19.574 (   7.886s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 0 - 3
# 2024-04-30 15:44:19.574 (   7.886s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.577 (   7.889s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.577 (   7.889s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:19.577 (   7.889s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:19.959 (   8.270s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:19.959 (   8.270s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:19.959 (   8.271s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:19.959 (   8.271s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 1: Rotation has applied for 107961 degree. 2: Current time is 23.1 s. 3: Completion is 47.1 %.
# 2024-04-30 15:44:20.235 (   8.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:20.236 (   8.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:20.238 (   8.550s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:20.239 (   8.550s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:20.241 (   8.553s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:20.247 (   8.559s) [main            ]    SparsityPattern.cpp:384   INFO| Column ghost size increased from 0 to 0
# 2024-04-30 15:44:20.262 (   8.574s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:20.288 (   8.600s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:20.306 (   8.617s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 2.78712 (tol = 1e-10) r (rel) = 0.000816033(tol = 1e-06)
# 2024-04-30 15:44:20.311 (   8.623s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:20.330 (   8.642s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 2.97339e-05 (tol = 1e-10) r (rel) = 8.70573e-09(tol = 1e-06)
# 2024-04-30 15:44:20.330 (   8.642s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 3 iterations and 15 linear solver iterations.
# 2024-04-30 15:44:20.330 (   8.642s) [main            ]      xdmf_function.cpp:51    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 2024-04-30 15:44:20.376 (   8.688s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.376 (   8.688s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.376 (   8.688s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.376 (   8.688s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.377 (   8.688s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.377 (   8.688s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.377 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.377 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.377 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.377 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.377 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.377 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.377 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.377 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.377 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.377 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.378 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.378 (   8.689s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.378 (   8.690s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.378 (   8.690s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.378 (   8.690s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.378 (   8.690s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.378 (   8.690s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.378 (   8.690s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.378 (   8.690s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.378 (   8.690s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.378 (   8.690s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.379 (   8.690s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.379 (   8.690s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.379 (   8.691s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.379 (   8.691s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.379 (   8.691s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.379 (   8.691s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.379 (   8.691s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.379 (   8.691s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.379 (   8.691s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.379 (   8.691s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.379 (   8.691s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.380 (   8.691s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.380 (   8.691s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.381 (   8.693s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.382 (   8.694s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.382 (   8.694s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.382 (   8.694s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.382 (   8.694s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.382 (   8.694s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.382 (   8.694s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.382 (   8.694s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.382 (   8.694s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.383 (   8.694s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.383 (   8.694s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.383 (   8.695s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.383 (   8.695s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.383 (   8.695s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.383 (   8.695s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:20.383 (   8.695s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.383 (   8.695s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 2
# 2024-04-30 15:44:20.385 (   8.697s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 0 - 3
# 2024-04-30 15:44:20.385 (   8.697s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.386 (   8.698s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.387 (   8.698s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:20.387 (   8.698s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:20.696 (   9.008s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:20.697 (   9.008s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:20.697 (   9.009s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:20.697 (   9.009s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 1: Completion is 47.1 %.
# 2024-04-30 15:44:20.987 (   9.298s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:20.987 (   9.299s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:20.987 (   9.299s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:20.987 (   9.299s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:20.990 (   9.301s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:20.995 (   9.307s) [main            ]    SparsityPattern.cpp:384   INFO| Column ghost size increased from 0 to 0
# 2024-04-30 15:44:21.014 (   9.326s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:21.042 (   9.354s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:21.062 (   9.374s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 43.3723 (tol = 1e-10) r (rel) = 0.00903104(tol = 1e-06)
# 2024-04-30 15:44:21.070 (   9.382s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:21.093 (   9.405s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 0.045585 (tol = 1e-10) r (rel) = 9.49177e-06(tol = 1e-06)
# 2024-04-30 15:44:21.103 (   9.414s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:21.131 (   9.443s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 1.61659e-07 (tol = 1e-10) r (rel) = 3.36608e-11(tol = 1e-06)
# 2024-04-30 15:44:21.131 (   9.443s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 22 linear solver iterations.
# 2024-04-30 15:44:21.131 (   9.443s) [main            ]      xdmf_function.cpp:51    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 1: Rotation has applied for 143948 degree. 2: Current time is 35.4 s. 3: Completion is 72.2 %.
# 2024-04-30 15:44:21.230 (   9.542s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.230 (   9.542s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.230 (   9.542s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.230 (   9.542s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.231 (   9.542s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.231 (   9.542s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.231 (   9.542s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.231 (   9.543s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.231 (   9.543s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.231 (   9.543s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.231 (   9.543s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.231 (   9.543s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.231 (   9.543s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.231 (   9.543s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.231 (   9.543s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.231 (   9.543s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.232 (   9.543s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.232 (   9.543s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.232 (   9.544s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.233 (   9.544s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.233 (   9.544s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.233 (   9.545s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.233 (   9.545s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.233 (   9.545s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.233 (   9.545s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.233 (   9.545s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.233 (   9.545s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.233 (   9.545s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.234 (   9.545s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.234 (   9.545s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.234 (   9.545s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.234 (   9.546s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.234 (   9.546s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.234 (   9.546s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.234 (   9.546s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.234 (   9.546s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.234 (   9.546s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.234 (   9.546s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.234 (   9.546s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.235 (   9.546s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.235 (   9.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.235 (   9.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.235 (   9.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.235 (   9.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.235 (   9.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.235 (   9.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.235 (   9.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.235 (   9.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.235 (   9.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.236 (   9.547s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.236 (   9.548s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.237 (   9.548s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.237 (   9.549s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.237 (   9.549s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.237 (   9.549s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:21.237 (   9.549s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.237 (   9.549s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 2
# 2024-04-30 15:44:21.238 (   9.550s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 0 - 3
# 2024-04-30 15:44:21.238 (   9.550s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.248 (   9.560s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.248 (   9.560s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:21.248 (   9.560s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:21.622 (   9.934s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:21.622 (   9.934s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:21.623 (   9.935s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:21.623 (   9.935s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 1: Rotation has applied for 179935 degree. 2: Current time is 58.8 s. 3: Completion is 120.0 %.
# 2024-04-30 15:44:22.014 (  10.325s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:22.014 (  10.326s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:22.014 (  10.326s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:22.014 (  10.326s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:22.019 (  10.331s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:22.030 (  10.342s) [main            ]    SparsityPattern.cpp:384   INFO| Column ghost size increased from 0 to 0
# 2024-04-30 15:44:22.048 (  10.360s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:22.083 (  10.395s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:22.104 (  10.416s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 428.216 (tol = 1e-10) r (rel) = 0.0835714(tol = 1e-06)
# 2024-04-30 15:44:22.111 (  10.423s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:22.130 (  10.442s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 10.358 (tol = 1e-10) r (rel) = 0.00202149(tol = 1e-06)
# 2024-04-30 15:44:22.138 (  10.450s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:22.156 (  10.468s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 0.00474622 (tol = 1e-10) r (rel) = 9.26281e-07(tol = 1e-06)
# 2024-04-30 15:44:22.156 (  10.468s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 4 iterations and 21 linear solver iterations.
# 2024-04-30 15:44:22.156 (  10.468s) [main            ]      xdmf_function.cpp:51    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 2024-04-30 15:44:22.207 (  10.519s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.207 (  10.519s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.207 (  10.519s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.208 (  10.519s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.211 (  10.523s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.211 (  10.523s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.212 (  10.523s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.212 (  10.524s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.212 (  10.524s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.212 (  10.524s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.212 (  10.524s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.212 (  10.524s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.212 (  10.524s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.212 (  10.524s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.213 (  10.524s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.213 (  10.524s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.213 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.213 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.213 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.213 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.213 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.213 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.213 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.213 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.213 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.213 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.214 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.214 (  10.525s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.214 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.214 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.214 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.214 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.214 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.214 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.214 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.214 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.214 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.214 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.215 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.215 (  10.526s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.215 (  10.527s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.215 (  10.527s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.215 (  10.527s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.215 (  10.527s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.215 (  10.527s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.215 (  10.527s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.215 (  10.527s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.215 (  10.527s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.215 (  10.527s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.216 (  10.527s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.216 (  10.528s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.216 (  10.528s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.216 (  10.528s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.216 (  10.528s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.216 (  10.528s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:22.216 (  10.528s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:22.216 (  10.528s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 2
# 2024-04-30 15:44:22.217 (  10.529s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 0 - 3
# 2024-04-30 15:44:22.217 (  10.529s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.218 (  10.530s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:22.218 (  10.530s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# ...
# 2024-04-30 15:44:23.155 (  11.467s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:23.158 (  11.470s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:23.159 (  11.470s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-30 15:44:23.159 (  11.470s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-30 15:44:23.542 (  11.855s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:23.543 (  11.855s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:23.545 (  11.857s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:23.545 (  11.857s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 1: Completion is 53.7 %.
# 2024-04-30 15:44:23.885 (  12.197s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:23.885 (  12.197s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:23.886 (  12.198s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:23.886 (  12.198s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-30 15:44:23.888 (  12.200s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-30 15:44:23.893 (  12.205s) [main            ]    SparsityPattern.cpp:384   INFO| Column ghost size increased from 0 to 0
# 2024-04-30 15:44:23.910 (  12.221s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:23.946 (  12.258s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:23.964 (  12.276s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 283.59 (tol = 1e-10) r (rel) = 0.612422(tol = 1e-06)
# 2024-04-30 15:44:23.973 (  12.285s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:23.991 (  12.303s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 3: r (abs) = 173.351 (tol = 1e-10) r (rel) = 0.374357(tol = 1e-06)
# 2024-04-30 15:44:24.002 (  12.314s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.019 (  12.331s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 4: r (abs) = 109.335 (tol = 1e-10) r (rel) = 0.236112(tol = 1e-06)
# 2024-04-30 15:44:24.030 (  12.342s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.047 (  12.359s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 5: r (abs) = 70.6137 (tol = 1e-10) r (rel) = 0.152493(tol = 1e-06)
# 2024-04-30 15:44:24.060 (  12.372s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.076 (  12.388s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 6: r (abs) = 47.6894 (tol = 1e-10) r (rel) = 0.102987(tol = 1e-06)
# 2024-04-30 15:44:24.085 (  12.396s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.100 (  12.412s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 7: r (abs) = 33.2543 (tol = 1e-10) r (rel) = 0.0718139(tol = 1e-06)
# 2024-04-30 15:44:24.111 (  12.423s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.135 (  12.447s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 8: r (abs) = 23.6891 (tol = 1e-10) r (rel) = 0.0511575(tol = 1e-06)
# 2024-04-30 15:44:24.152 (  12.464s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.169 (  12.481s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 9: r (abs) = 17.2241 (tol = 1e-10) r (rel) = 0.0371961(tol = 1e-06)
# 2024-04-30 15:44:24.179 (  12.491s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.198 (  12.509s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 10: r (abs) = 12.5887 (tol = 1e-10) r (rel) = 0.0271858(tol = 1e-06)
# 2024-04-30 15:44:24.208 (  12.520s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.226 (  12.538s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 11: r (abs) = 9.29058 (tol = 1e-10) r (rel) = 0.0200633(tol = 1e-06)
# 2024-04-30 15:44:24.237 (  12.549s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.256 (  12.567s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 12: r (abs) = 6.85678 (tol = 1e-10) r (rel) = 0.0148074(tol = 1e-06)
# 2024-04-30 15:44:24.266 (  12.578s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.283 (  12.595s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 13: r (abs) = 5.08253 (tol = 1e-10) r (rel) = 0.0109759(tol = 1e-06)
# 2024-04-30 15:44:24.293 (  12.605s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.310 (  12.622s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 14: r (abs) = 3.76404 (tol = 1e-10) r (rel) = 0.00812857(tol = 1e-06)
# 2024-04-30 15:44:24.317 (  12.629s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.340 (  12.651s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 15: r (abs) = 2.79316 (tol = 1e-10) r (rel) = 0.00603193(tol = 1e-06)
# 2024-04-30 15:44:24.351 (  12.662s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.371 (  12.683s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 16: r (abs) = 2.07114 (tol = 1e-10) r (rel) = 0.00447269(tol = 1e-06)
# 2024-04-30 15:44:24.382 (  12.694s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.400 (  12.712s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 17: r (abs) = 1.53724 (tol = 1e-10) r (rel) = 0.00331973(tol = 1e-06)
# 2024-04-30 15:44:24.411 (  12.723s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.430 (  12.742s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 18: r (abs) = 1.14041 (tol = 1e-10) r (rel) = 0.00246274(tol = 1e-06)
# 2024-04-30 15:44:24.438 (  12.750s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.452 (  12.765s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 19: r (abs) = 0.846429 (tol = 1e-10) r (rel) = 0.00182789(tol = 1e-06)
# 2024-04-30 15:44:24.459 (  12.771s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.476 (  12.787s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 20: r (abs) = 0.628047 (tol = 1e-10) r (rel) = 0.00135629(tol = 1e-06)
# 2024-04-30 15:44:24.484 (  12.796s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.500 (  12.812s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 21: r (abs) = 0.466129 (tol = 1e-10) r (rel) = 0.00100662(tol = 1e-06)
# 2024-04-30 15:44:24.508 (  12.819s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.522 (  12.834s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 22: r (abs) = 0.345896 (tol = 1e-10) r (rel) = 0.000746974(tol = 1e-06)
# 2024-04-30 15:44:24.530 (  12.842s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.551 (  12.863s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 23: r (abs) = 0.256711 (tol = 1e-10) r (rel) = 0.000554377(tol = 1e-06)
# 2024-04-30 15:44:24.562 (  12.874s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.581 (  12.893s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 24: r (abs) = 0.190503 (tol = 1e-10) r (rel) = 0.000411399(tol = 1e-06)
# 2024-04-30 15:44:24.592 (  12.904s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.614 (  12.926s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 25: r (abs) = 0.141382 (tol = 1e-10) r (rel) = 0.000305319(tol = 1e-06)
# 2024-04-30 15:44:24.630 (  12.942s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.651 (  12.963s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 26: r (abs) = 0.10492 (tol = 1e-10) r (rel) = 0.000226579(tol = 1e-06)
# 2024-04-30 15:44:24.661 (  12.973s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.682 (  12.994s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 27: r (abs) = 0.0778655 (tol = 1e-10) r (rel) = 0.000168153(tol = 1e-06)
# 2024-04-30 15:44:24.699 (  13.011s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.717 (  13.029s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 28: r (abs) = 0.0577852 (tol = 1e-10) r (rel) = 0.000124789(tol = 1e-06)
# 2024-04-30 15:44:24.727 (  13.039s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.748 (  13.060s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 29: r (abs) = 0.0428843 (tol = 1e-10) r (rel) = 9.26101e-05(tol = 1e-06)
# 2024-04-30 15:44:24.761 (  13.072s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.782 (  13.093s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 30: r (abs) = 0.0318253 (tol = 1e-10) r (rel) = 6.87278e-05(tol = 1e-06)
# 2024-04-30 15:44:24.791 (  13.103s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.816 (  13.128s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 31: r (abs) = 0.0236185 (tol = 1e-10) r (rel) = 5.10049e-05(tol = 1e-06)
# 2024-04-30 15:44:24.829 (  13.141s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.897 (  13.209s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 32: r (abs) = 0.0175278 (tol = 1e-10) r (rel) = 3.78519e-05(tol = 1e-06)
# 2024-04-30 15:44:24.910 (  13.222s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.931 (  13.242s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 33: r (abs) = 0.0130079 (tol = 1e-10) r (rel) = 2.8091e-05(tol = 1e-06)
# 2024-04-30 15:44:24.942 (  13.254s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:24.974 (  13.286s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 34: r (abs) = 0.00965347 (tol = 1e-10) r (rel) = 2.0847e-05(tol = 1e-06)
# 2024-04-30 15:44:24.983 (  13.295s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:25.005 (  13.317s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 35: r (abs) = 0.0071641 (tol = 1e-10) r (rel) = 1.54711e-05(tol = 1e-06)
# 2024-04-30 15:44:25.015 (  13.327s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:25.038 (  13.350s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 36: r (abs) = 0.00531665 (tol = 1e-10) r (rel) = 1.14815e-05(tol = 1e-06)
# 2024-04-30 15:44:25.050 (  13.362s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:25.073 (  13.385s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 37: r (abs) = 0.00394563 (tol = 1e-10) r (rel) = 8.52072e-06(tol = 1e-06)
# 2024-04-30 15:44:25.085 (  13.397s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:25.106 (  13.418s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 38: r (abs) = 0.00292815 (tol = 1e-10) r (rel) = 6.32344e-06(tol = 1e-06)
# 2024-04-30 15:44:25.115 (  13.427s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:25.135 (  13.447s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 39: r (abs) = 0.00217306 (tol = 1e-10) r (rel) = 4.69279e-06(tol = 1e-06)
# 2024-04-30 15:44:25.165 (  13.477s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:25.193 (  13.504s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 40: r (abs) = 0.00161268 (tol = 1e-10) r (rel) = 3.48264e-06(tol = 1e-06)
# 2024-04-30 15:44:25.205 (  13.516s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:25.222 (  13.534s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 41: r (abs) = 0.00119681 (tol = 1e-10) r (rel) = 2.58456e-06(tol = 1e-06)
# 2024-04-30 15:44:25.231 (  13.543s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:25.266 (  13.577s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 42: r (abs) = 0.000888185 (tol = 1e-10) r (rel) = 1.91807e-06(tol = 1e-06)
# 2024-04-30 15:44:25.275 (  13.587s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:25.294 (  13.606s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 43: r (abs) = 0.000659145 (tol = 1e-10) r (rel) = 1.42345e-06(tol = 1e-06)
# 2024-04-30 15:44:25.303 (  13.615s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:25.326 (  13.638s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 44: r (abs) = 0.000489168 (tol = 1e-10) r (rel) = 1.05638e-06(tol = 1e-06)
# 2024-04-30 15:44:25.337 (  13.648s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-30 15:44:25.360 (  13.672s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 45: r (abs) = 0.000363024 (tol = 1e-10) r (rel) = 7.83964e-07(tol = 1e-06)
# 2024-04-30 15:44:25.360 (  13.672s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 45 iterations and 90 linear solver iterations.
# 2024-04-30 15:44:25.360 (  13.672s) [main            ]      xdmf_function.cpp:51    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"

# %% [markdown]
# # 6: Post process

# %%
# Display the GIF
from IPython.display import display, Image
display( Image(gif_name) )

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time1 = round(elapsed_time, 0)

formatted_start_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(start_time))
formatted_end_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(end_time))
txt_name = "T-s-{}-d-{}-{}-c-{}-e-{}.txt".format(num_steps, angular_r, mesh_filename2,c_contact,total_elements)
with open(txt_name, "w") as file:
   original_print = print
   print = lambda *args, **kwargs: original_print(*args, **kwargs, file=file)
    
   print("1: Start at:", formatted_start_time)
   print('2: End at', formatted_end_time)
    
   if elapsed_time1 >= 60:
      min = elapsed_time1/60
      hours = min/60
      print("3: Simulation time is",round(hours), 'hours', round(min),'minutes')
   else:
      print("3: Simulation time is",elapsed_time1, 'second')

   print('1: First time step dt is ', round(dt[0],5),'s')
   r_disc = 0.25

   print('2: Convection heat transfer coefficient is',h, ' W/mm2 K')
   print('3: Radiation is ', round(radiation,14), ' W/mm2 K-4')
   print('4: Each rotation degree is ', round(angular_r,1), ' per time step', 'or ', round(angular_r/360,1),' circle')
   print('5: The first rotation degree is ', round(v_angular[0] * r_disc * dt[0] *1000, 1) )
   print('6: The mid rotation degree is ', round(v_angular[ round(num_steps/2) ] * r_disc * dt[ round(len(dt)/2) ] *1000, 1) )
   print('7: The last rotation degree is ', round(v_angular[num_steps-1] * r_disc * dt[-1] *1000, 1) )
   print('9: Total contact area of 18 rubbing element is', round(S_total/100,1), 'cm2')
   print('10: The mesh element size is between ',mesh_min, '-',mesh_max, 'mm' )
   #print('11: Total elements number is ',total_elements )    

print = original_print 

with open(txt_name, "r") as file1:
   # Read the content of the file
   content = file1.read()
   # Print the content
   print(content)
# Out:
# 1: Start at: 2024-04-30 15:44:11
# 2: End at 2024-04-30 15:44:25
# 3: Simulation time is 14.0 second
# 1: First time step dt is  6.50075 s
# 2: Convection heat transfer coefficient is 7.75e-05  W/mm2 K
# 3: Radiation is  3.6e-13  W/mm2 K-4
# 4: Each rotation degree is  35987  per time step or  100.0  circle
# 5: The first rotation degree is  157022.9
# 6: The mid rotation degree is  157022.9
# 7: The last rotation degree is  157022.9
# 9: Total contact area of 18 rubbing element is 199.9 cm2
# 10: The mesh element size is between  1 - 15 mm

# %%
# Define the source directory
source_dir = "/home/yanjun/Documents/FEniCSx/Practice/Concise"

# Define the destination directory
destination_dir = "/home/yanjun/Documents/FEM_results"

# Create the new folder in the destination directory
new_folder_name = f"s-{num_steps}-d-{angular_r}-m-{mesh_min}-{mesh_max}-c-{c_contact}-e-{total_elements}"
destination_dir = os.path.join(destination_dir, new_folder_name)
os.makedirs(destination_dir, exist_ok=True)

# List of files to move
files_to_move = [
                 gif_name,
                 h5_name,
                 xdmf_name,
                 txt_name
                           ]

# Move each file to the destination directory
for filename in files_to_move:
    source_file_path = os.path.join(source_dir, filename)
    destination_file_path = os.path.join(destination_dir, filename)
    shutil.move(source_file_path, destination_file_path)
print('Move files successfully')
# Out:
# Move files successfully

# %%
t1, x1 = T_array[0]
print ( len(T_array[:3]) )
#print(x1)
print(len(x1))
# Out:
# 3
# 4281

# %%
# Out:
# 26.30311396197027
