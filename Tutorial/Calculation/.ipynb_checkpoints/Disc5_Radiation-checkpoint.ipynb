# %% [markdown]
# Add Robin boundary conditions.
#
# Success!
#
# Author: yanjun zhang
#
# # ds needs define correct

# %% [markdown]
# ## 1: Start

# %% [markdown]
# Source from
# book "Abali - 2017 - Computational Reality" P119

# %%
import pyvista
import ufl
import dolfinx
import time
import numpy as np
import matplotlib.pyplot as plt
from petsc4py import PETSc
from mpi4py import MPI
import sys

from dolfinx.fem.petsc import LinearProblem,assemble_vector, assemble_matrix, create_vector, apply_lifting, set_bc
from dolfinx import fem, mesh, io, plot, default_scalar_type, nls, log
from dolfinx.fem import (Constant, dirichletbc, Function, FunctionSpace, 
                         form,  locate_dofs_topological)
from dolfinx.io import XDMFFile, gmshio
from dolfinx.mesh import  locate_entities, locate_entities_boundary,meshtags
from ufl import (SpatialCoordinate, TestFunction, TrialFunction,
                 dx, grad, inner, Measure, dot, FacetNormal)

from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver

from find_com_e import find_common_e

# Start time, Final time ,Time step
t = 0
Total_time = 1
num_steps  = 100
# time step size
dt = Total_time / num_steps  

# initial and brake pad temperature
Ti = 25
Tm = 25

# density (kg.m^-3), capacity (J/Kg.K), conductivity (W/m.K)
t_u = 1e3 # m to mm
rho = 7850 /(t_u**3)
c = 462
k = 48 / t_u

# mu, P_brake, v_angualr , r_disc , heat_distribution
mu = 0.35
P_brake = 246000
v_angualr = 48.3
r_disc = 0.25
heat_distribution = 0.88

# S_or is the original brake pad rubbing area, 200 cm2. 
S_or = 200
S_new = 200

# g is the heat source,unit is w/mm2
g = mu * P_brake * v_angualr * r_disc * heat_distribution *2 /(t_u**2)  * (S_or/S_new) *100
h = g/200  *0.0000001
radiation = 5.670*(10e-8)*0.5  *0.00000000000000001

print(v_angualr * r_disc * dt *1000)
print('heat flux g is ',g)
print('time step dt is ',dt)
print('radiation is ',radiation)
# Out:
# /home/yanjun/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# 120.75
# heat flux g is  182.97972
# time step dt is  0.01
# radiation is  2.835e-24

# %%
import dolfinx
print(f"DOLFINx version: {dolfinx.__version__}   \
based on GIT commit:  \
{dolfinx.git_commit_hash} of https://github.com/FEniCS/dolfinx/")
# Out:
# DOLFINx version: 0.7.3   based on GIT commit:  ubuntu of https://github.com/FEniCS/dolfinx/

# %% [markdown]
# ## 2: Mesh

# %%
# mesh
filename = "3-10" 
domain, cell_markers, facet_markers = gmshio.read_from_msh(filename+".msh", MPI.COMM_WORLD, 0, gdim=3)

# Define variational problem, Here Lagrange changes to CG, what is CG?
V = fem.FunctionSpace(domain, ('Lagrange', 1))

# initialization
def project(function, space):
    u = TrialFunction(space)
    v = TestFunction(space)
    a = inner(u, v) * dx
    L = inner(function, v) * dx
    problem = LinearProblem(a, L, bcs = [])
    return problem.solve()
    
# u_n is for initial condition and uh is the solver result.
# variable, need to be projected form Q onto V
Q = FunctionSpace(domain, ("DG", 0))
T_init = Function(Q)
T_init.name = "u_n"
T_init.x.array[:] = np.full_like(1, Ti, dtype=default_scalar_type)
u_n = project(T_init,V)
u_n.name = "u_n"

fdim = domain.topology.dim - 1
## bc_disc is zero, no any dirichlete boundary condition
bc_disc = mesh.locate_entities_boundary(
    domain, fdim , lambda x:  np.isclose(x[2], 50) )
bc = fem.dirichletbc(PETSc.ScalarType(Tm), fem.locate_dofs_topological(V, fdim, bc_disc), V)
# Out:
# Info    : Reading '3-10.msh'...
# Info    : 168 entities
# Info    : 10751 nodes
# Info    : 43604 elements
# Info    : Done reading '3-10.msh'

# %%
np.set_printoptions(threshold=np.inf)
print(type(PETSc.ScalarType(Tm)))
print(fem.locate_dofs_topological(V, fdim, bc_disc))
print(bc)
# Out:
# <class 'numpy.float64'>
# []
# <dolfinx.fem.bcs.DirichletBC object at 0x7a26c75dafe0>

# %% [markdown]
# ## 3: Setup output

# %%
xdmf = io.XDMFFile(domain.comm, "T4.xdmf", "w")
xdmf.write_mesh(domain)

# %% [markdown]
# boundaries = []
# for i, (x_c, y_c) in enumerate(zip(x_co, y_co), start=1):
#     vari_name = 10*i
#     boundaries.append(  (vari_name, lambda x: (x[0]-x_c)**2 + (x[1]-y_c)**2  <= 324)  )

# %%
# Create boundary condition
import sys
sys.path.append('/home/yanjun/Documents/FEniCSx/Tutorial/Mesh/')
from rub_co import get_rub_coordinate
x_co, y_co = get_rub_coordinate()

boundary1= (10, lambda x: (x[0]-x_co[0])**2 + (x[1]-y_co[0])**2 <= 324)
boundary2= (20, lambda x: (x[0]-x_co[1])**2 + (x[1]-y_co[1])**2 <= 324) 
boundary3= (30, lambda x: (x[0]-x_co[2])**2 + (x[1]-y_co[2])**2 <= 324)
boundary4= (40, lambda x: (x[0]-x_co[3])**2 + (x[1]-y_co[3])**2 <= 324) 
boundary5= (50, lambda x: (x[0]-x_co[4])**2 + (x[1]-y_co[4])**2 <= 324)
boundary6= (60, lambda x: (x[0]-x_co[5])**2 + (x[1]-y_co[5])**2 <= 324) 
boundary7= (70, lambda x: (x[0]-x_co[6])**2 + (x[1]-y_co[6])**2 <= 324)
boundary8= (80, lambda x: (x[0]-x_co[7])**2 + (x[1]-y_co[7])**2 <= 324) 
boundary9= (90, lambda x: (x[0]-x_co[8])**2 + (x[1]-y_co[8])**2 <= 324)
boundary10= (100, lambda x: (x[0]-x_co[9])**2 + (x[1]-y_co[9])**2 <= 324) 
boundary11= (110, lambda x: (x[0]-x_co[10])**2 + (x[1]-y_co[10])**2 <= 324)
boundary12= (120, lambda x: (x[0]-x_co[11])**2 + (x[1]-y_co[11])**2 <= 324) 
boundary13= (130, lambda x: (x[0]-x_co[12])**2 + (x[1]-y_co[12])**2 <= 324)
boundary14= (140, lambda x: (x[0]-x_co[13])**2 + (x[1]-y_co[13])**2 <= 324) 
boundary15= (150, lambda x: (x[0]-x_co[14])**2 + (x[1]-y_co[14])**2 <= 324)
boundary16= (160, lambda x: (x[0]-x_co[15])**2 + (x[1]-y_co[15])**2 <= 324)
boundary17= (170, lambda x: (x[0]-x_co[16])**2 + (x[1]-y_co[16])**2 <= 324) 
boundary18= (180, lambda x: (x[0]-x_co[17])**2 + (x[1]-y_co[17])**2 <= 324)

boundaries1 = [boundary1,boundary2,boundary3,boundary4,boundary5,boundary6,boundary7,boundary8,boundary9,boundary10,
              boundary11,boundary12,boundary13,boundary14,boundary15,boundary16,boundary17,boundary18]
 
facet_indices1, facet_markers1 = [], [] 
fdim = domain.topology.dim - 1  
for (marker, locator) in boundaries1:
        facets = locate_entities(domain, fdim, locator)   
        facet_indices1.append(facets)
        facet_markers1.append(np.full_like(facets, marker))
facet_indices1 = np.hstack(facet_indices1).astype(np.int32)
facet_markers1 = np.hstack(facet_markers1).astype(np.int32)
            
A1 = facet_indices1
B = facet_markers1 
C = mesh.locate_entities_boundary(domain, fdim, lambda x: np.isclose(x[2], 20) )

common_indices1 = np.intersect1d(A1,C)
D = []
for index in common_indices1:
        rows_A1 = np.where(A1 == index)
        D.append( B[rows_A1] )
facet_markers1 = np.concatenate(D)
####################################

boundary20 = (200, lambda x:  x[2] == 20)
facet_indices2, facet_markers2 = [], [] 
fdim = domain.topology.dim - 1  
for (marker, locator) in [boundary20]:
        facets = locate_entities(domain, fdim, locator)   
        facet_indices2.append(facets)
        facet_markers2.append(np.full_like(facets, marker)) 
facet_indices2 = np.hstack(facet_indices2).astype(np.int32)
facet_markers2 = np.hstack(facet_markers2).astype(np.int32)

A1 = facet_indices2
B = facet_markers2
B1 = common_indices1
common_indices2 = np.setdiff1d(A1,B1)
D = []
for index in common_indices2:
        rows_A1 = np.where(A1 == index)
        D.append( B[rows_A1] )
facet_markers2 = np.concatenate(D) 
    
common_indices3 = [common_indices1,common_indices2]
facet_markers3 = [facet_markers1,facet_markers2]
common_indices3 = np.concatenate(common_indices3)
facet_markers3 = np.concatenate(facet_markers3)
sorted_indices3 = np.argsort(common_indices3)
      
facet_tag = meshtags(domain, fdim, common_indices3[sorted_indices3], facet_markers3[sorted_indices3])
ds = Measure('ds', domain=domain, subdomain_data=facet_tag)

# %%
#print(facet_markers1)
#print(facet_markers3)

# %% [markdown]
# ## 4: Variational equation

# %%
uh = fem.Function(V)
uh.name = "uh"
uh = project(T_init,V)
xdmf.write_function(uh, t)

#u = ufl.TrialFunction(V)
uh = fem.Function(V)

v = ufl.TestFunction(V)
f = fem.Constant(domain, PETSc.ScalarType(0))
n_vector = FacetNormal(domain)

F = (rho*c)/dt*inner(uh,v)*dx + k*inner(grad(uh),grad(v))*dx+  h*inner(uh,v)*ds(200) + radiation*inner(uh**4,v) *ds(200) - ( inner(f,v) *dx + (rho*c)/dt * inner(u_n, v) * dx +  h * 25* v *ds(200) +  radiation * (25**4)* v *ds(200) )

#a = (rho*c)/dt*inner(u,v)*dx + k*inner(grad(u),grad(v))*dx+  h*inner(u,v)*ds(200) + radiation*inner(u**4,v) *ds(200)
#L = inner(f,v) *dx + (rho*c)/dt * inner(u_n, v) * dx +  h * 25* v *ds(200) +  radiation * (25**4)* v *ds(200)


for i in list(range(1,19)):
     F +=  - k * dot( grad(uh)* v, n_vector) *ds(10*i) - inner(g, v) *ds(10*i)

problem = NonlinearProblem(F, uh, bcs=[bc])

## 7: Using petsc4py to create a linear solver
solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-2
solver.report = True

ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "cg"
opts[f"{option_prefix}pc_type"] = "gamg"
opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
ksp.setFromOptions()

log.set_log_level(log.LogLevel.INFO)
n, converged = solver.solve(uh)
assert (converged)
print(f"Number of interations: {n:d}")


## 8:Visualization of time dependent problem using pyvista
import matplotlib as mpl
pyvista.start_xvfb()
grid = pyvista.UnstructuredGrid(*plot.vtk_mesh(V))
plotter = pyvista.Plotter()
plotter.open_gif("T4.gif", fps=30)
grid.point_data["Temperature"] = uh.x.array
warped = grid.warp_by_scalar("Temperature", factor=0)
viridis = mpl.colormaps.get_cmap("viridis").resampled(25)
sargs = dict(title_font_size=25, label_font_size=20,  color="black",
             position_x=0.1, position_y=0.8, width=0.8, height=0.1)
renderer = plotter.add_mesh(warped, show_edges=True, lighting=False,
                            cmap=viridis, scalar_bar_args=sargs,
                            #clim=[0, max(uh.x.array)])
                            clim=[0,  200])
# Out:
# 2024-04-14 16:51:32.351 (   0.890s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-14 16:51:32.443 (   0.982s) [main            ]              petsc.cpp:698   INFO| PETSc Krylov solver starting to solve system.
# 2024-04-14 16:51:32.499 (   1.044s) [main            ]       NewtonSolver.cpp:36    INFO| Newton iteration 2: r (abs) = 0.0330428 (tol = 1e-10) r (rel) = 8.49414e-06(tol = 0.01)
# 2024-04-14 16:51:32.505 (   1.044s) [main            ]       NewtonSolver.cpp:255   INFO| Newton solver finished in 2 iterations and 9 linear solver iterations.
# Number of interations: 2

# %% [markdown]
# ## 5: Solution

# %%
from rotation_co import rub_rotation
import numpy as np

degree = 10
total_degree = 0

for i in range(num_steps):
    t += dt
   
    boundaries1 = []
    x_co, y_co = rub_rotation (x_co, y_co, degree)   # update the location
    total_degree += degree  # Incrementing degree by 10 in each step
    
    sys.stdout.write('\r1: Rotation has applied for {} degree. '.format(total_degree))
    sys.stdout.write('2: Current time is ' + str(round(t,1)) + " s. ")
    sys.stdout.write('3: Completion is '  + str(round (100*(t/Total_time),1) )+ " %. ")
    sys.stdout.flush()
    
    boundary1= (10, lambda x: (x[0]-x_co[0])**2 + (x[1]-y_co[0])**2 <= 324)
    boundary2= (20, lambda x: (x[0]-x_co[1])**2 + (x[1]-y_co[1])**2 <= 324) 
    boundary3= (30, lambda x: (x[0]-x_co[2])**2 + (x[1]-y_co[2])**2 <= 324)
    boundary4= (40, lambda x: (x[0]-x_co[3])**2 + (x[1]-y_co[3])**2 <= 324) 
    boundary5= (50, lambda x: (x[0]-x_co[4])**2 + (x[1]-y_co[4])**2 <= 324)
    boundary6= (60, lambda x: (x[0]-x_co[5])**2 + (x[1]-y_co[5])**2 <= 324) 
    boundary7= (70, lambda x: (x[0]-x_co[6])**2 + (x[1]-y_co[6])**2 <= 324)
    boundary8= (80, lambda x: (x[0]-x_co[7])**2 + (x[1]-y_co[7])**2 <= 324) 
    boundary9= (90, lambda x: (x[0]-x_co[8])**2 + (x[1]-y_co[8])**2 <= 324)
    boundary10= (100, lambda x: (x[0]-x_co[9])**2 + (x[1]-y_co[9])**2 <= 324) 
    boundary11= (110, lambda x: (x[0]-x_co[10])**2 + (x[1]-y_co[10])**2 <= 324)
    boundary12= (120, lambda x: (x[0]-x_co[11])**2 + (x[1]-y_co[11])**2 <= 324) 
    boundary13= (130, lambda x: (x[0]-x_co[12])**2 + (x[1]-y_co[12])**2 <= 324)
    boundary14= (140, lambda x: (x[0]-x_co[13])**2 + (x[1]-y_co[13])**2 <= 324) 
    boundary15= (150, lambda x: (x[0]-x_co[14])**2 + (x[1]-y_co[14])**2 <= 324)
    boundary16= (160, lambda x: (x[0]-x_co[15])**2 + (x[1]-y_co[15])**2 <= 324)
    boundary17= (170, lambda x: (x[0]-x_co[16])**2 + (x[1]-y_co[16])**2 <= 324) 
    boundary18= (180, lambda x: (x[0]-x_co[17])**2 + (x[1]-y_co[17])**2 <= 324)
   
    boundaries1 = [boundary1,boundary2,boundary3,boundary4,boundary5,boundary6,boundary7,boundary8,boundary9,boundary10,
              boundary11,boundary12,boundary13,boundary14,boundary15,boundary16,boundary17,boundary18]
    #boundaries = boundaries+ [boundary19]
 
    facet_indices1, facet_markers1 = [], [] 
    fdim = domain.topology.dim - 1  
    for (marker, locator) in boundaries1:
        facets = locate_entities(domain, fdim, locator)   
        facet_indices1.append(facets)
        facet_markers1.append(np.full_like(facets, marker))  
    facet_indices1 = np.hstack(facet_indices1).astype(np.int32)
    facet_markers1 = np.hstack(facet_markers1).astype(np.int32)
    bc_disc = mesh.locate_entities_boundary( domain, fdim , lambda x:  np.isclose(x[2], 20) )        
    A1 = facet_indices1
    B = facet_markers1 
    C = bc_disc
    common_indices1 = np.intersect1d(A1,C)
    D = []
    for index in common_indices1:
        rows_A1 = np.where(A1 == index)
        D.append( B[rows_A1] )
    facet_markers1 = np.concatenate(D)
    ####################################

    
    boundary20 = (200, lambda x:  x[2] == 20)
    facet_indices2, facet_markers2 = [], [] 
    fdim = domain.topology.dim - 1  
    for (marker, locator) in [boundary20]:
        facets = locate_entities(domain, fdim, locator)   
        facet_indices2.append(facets)
        facet_markers2.append(np.full_like(facets, marker)) 
    facet_indices2 = np.hstack(facet_indices2).astype(np.int32)
    facet_markers2 = np.hstack(facet_markers2).astype(np.int32) 
    
    A1 = facet_indices2
    B = facet_markers2
    B1 = common_indices1
    common_indices2 = np.setdiff1d(A1,B1)
    D = []
    for index in common_indices2:
           rows_A1 = np.where(A1 == index)
           D.append( B[rows_A1] )
    facet_markers2 = np.concatenate(D) 
    
    common_indices3 = [common_indices1,common_indices2]
    facet_markers3 = [facet_markers1,facet_markers2]
    common_indices3 = np.concatenate(common_indices3)
    facet_markers3 = np.concatenate(facet_markers3)

    sorted_indices3 = np.argsort(common_indices3)
      
    facet_tag = meshtags(domain, fdim, common_indices3[sorted_indices3], facet_markers3[sorted_indices3])
    ds = Measure('ds', domain=domain, subdomain_data=facet_tag) 

    F = (rho*c)/dt*inner(uh,v)*dx + k*inner(grad(uh),grad(v))*dx+  h*inner(uh,v)*ds(200) + radiation*inner(uh**4,v) *ds(200) - ( inner(f,v) *dx + (rho*c)/dt * inner(u_n, v) * dx +  h * 25* v *ds(200) +  radiation * (25**4)* v *ds(200) )

    for i in list(range(1,19)):
         F +=  - k * dot( grad(uh)* v, n_vector) *ds(10*i) - inner(g, v) *ds(10*i)

    problem = NonlinearProblem(F, uh, bcs=[bc])

    ## 7: Using petsc4py to create a linear solver
    solver = NewtonSolver(MPI.COMM_WORLD, problem)
    solver.convergence_criterion = "incremental"
    solver.rtol = 1e-2
    
    ksp = solver.krylov_solver
    opts = PETSc.Options()
    option_prefix = ksp.getOptionsPrefix()
    opts[f"{option_prefix}ksp_type"] = "cg"
    opts[f"{option_prefix}pc_type"] = "gamg"
    opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
    ksp.setFromOptions()

    
    uh.x.scatter_forward()

    # Update solution at previous time step (u_n)
    u_n.x.array[:] = uh.x.array
    # Write solution to file
    xdmf.write_function(uh, t)
    # Update plot
    #warped = grid.warp_by_scalar("uh", factor=0)
    plotter.update_coordinates(warped.points.copy(), render=False)
    plotter.update_scalars(uh.x.array, render=False)
    plotter.write_frame()
    
plotter.close() 
xdmf.close()
print()
# Out:
# 1: Rotation has applied for 10 degree. 2: Current time is 0.0 s. 3: Completion is 1.0 %.
# 2024-04-14 16:51:35.908 (   4.447s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.909 (   4.448s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.909 (   4.448s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.909 (   4.448s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.932 (   4.471s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.932 (   4.471s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.932 (   4.471s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.933 (   4.472s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.933 (   4.472s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.933 (   4.472s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.933 (   4.472s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.933 (   4.472s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.933 (   4.472s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.934 (   4.473s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.934 (   4.473s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.934 (   4.473s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.934 (   4.473s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.934 (   4.473s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.934 (   4.473s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.935 (   4.474s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.935 (   4.474s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.935 (   4.474s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.935 (   4.474s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.935 (   4.474s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.935 (   4.474s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.936 (   4.475s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.936 (   4.475s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.936 (   4.475s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.936 (   4.475s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.936 (   4.475s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.936 (   4.475s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.936 (   4.475s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.936 (   4.475s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.937 (   4.476s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.937 (   4.476s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.937 (   4.476s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.937 (   4.476s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.937 (   4.476s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.937 (   4.476s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.938 (   4.477s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.938 (   4.477s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.938 (   4.477s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.938 (   4.477s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.939 (   4.478s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.939 (   4.478s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.939 (   4.478s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.939 (   4.478s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.939 (   4.478s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.940 (   4.479s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.940 (   4.479s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.940 (   4.479s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.940 (   4.479s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.940 (   4.479s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.940 (   4.479s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.941 (   4.480s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:35.941 (   4.480s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:35.941 (   4.480s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 2
# 2024-04-14 16:51:35.943 (   4.482s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 0 - 3
# 2024-04-14 16:51:35.943 (   4.482s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.948 (   4.487s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.948 (   4.487s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:35.949 (   4.488s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.021 (   4.560s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:36.021 (   4.560s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-14 16:51:36.022 (   4.561s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:36.022 (   4.561s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-14 16:51:36.038 (   4.577s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:36.038 (   4.577s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-14 16:51:36.039 (   4.578s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:36.039 (   4.578s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-14 16:51:36.045 (   4.584s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:36.064 (   4.603s) [main            ]    SparsityPattern.cpp:384   INFO| Column ghost size increased from 0 to 0
# 2024-04-14 16:51:36.066 (   4.605s) [main            ]      xdmf_function.cpp:51    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# WARNING:py.warnings:/home/yanjun/.local/lib/python3.10/site-packages/pyvista/plotting/plotter.py:4716: PyVistaDeprecationWarning: This method is deprecated and will be removed in a future version of PyVista. Directly modify the points of a mesh in-place instead.
#   warnings.warn(
#
# WARNING:py.warnings:/home/yanjun/.local/lib/python3.10/site-packages/pyvista/plotting/plotter.py:4638: PyVistaDeprecationWarning: This method is deprecated and will be removed in a future version of PyVista. Directly modify the scalars of a mesh in-place instead.
#   warnings.warn(
# 1: Rotation has applied for 30 degree. 2: Current time is 0.0 s. 3: Completion is 3.0 %.
# 2024-04-14 16:51:36.321 (   4.860s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.321 (   4.860s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.321 (   4.860s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.322 (   4.861s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.322 (   4.861s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.322 (   4.861s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.322 (   4.861s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.323 (   4.862s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.323 (   4.862s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.324 (   4.863s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.325 (   4.864s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.325 (   4.864s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.325 (   4.864s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.325 (   4.864s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.325 (   4.864s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.326 (   4.865s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.326 (   4.865s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.326 (   4.865s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.326 (   4.865s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.326 (   4.865s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.326 (   4.865s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.327 (   4.866s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.327 (   4.866s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.327 (   4.866s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.327 (   4.866s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.328 (   4.867s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.328 (   4.867s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.328 (   4.867s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.328 (   4.867s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.328 (   4.867s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.329 (   4.868s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.329 (   4.868s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36.329 (   4.868s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:36.329 (   4.868s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:36
) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.925 (  22.464s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.925 (  22.464s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:53.925 (  22.464s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.925 (  22.464s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.925 (  22.464s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:53.925 (  22.464s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.926 (  22.465s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.926 (  22.465s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:53.926 (  22.465s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.926 (  22.465s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.926 (  22.465s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:53.926 (  22.465s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.926 (  22.465s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.926 (  22.465s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:53.927 (  22.466s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.927 (  22.466s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.927 (  22.466s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:53.927 (  22.466s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.927 (  22.466s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.927 (  22.466s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:53.928 (  22.467s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.928 (  22.467s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.928 (  22.467s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:53.928 (  22.467s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.928 (  22.467s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.928 (  22.467s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:53.929 (  22.468s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:53.929 (  22.468s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:53.929 (  22.468s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 2
# 2024-04-14 16:51:53.931 (  22.470s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 0 - 3
# 2024-04-14 16:51:53.931 (  22.470s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.934 (  22.473s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.934 (  22.473s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:53.934 (  22.473s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:53.972 (  22.511s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:53.972 (  22.511s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-14 16:51:53.973 (  22.512s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:53.974 (  22.513s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 1: Rotation has applied for 1000 degree. 2: Current time is 1.0 s. 3: Completion is 100.0 %.
# 2024-04-14 16:51:53.997 (  22.536s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:53.998 (  22.537s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-14 16:51:53.999 (  22.538s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:53.999 (  22.538s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-14 16:51:54.009 (  22.548s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:54.030 (  22.569s) [main            ]    SparsityPattern.cpp:384   INFO| Column ghost size increased from 0 to 0
# 2024-04-14 16:51:54.034 (  22.573s) [main            ]      xdmf_function.cpp:51    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 2024-04-14 16:51:54.114 (  22.653s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.114 (  22.653s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.114 (  22.653s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.114 (  22.653s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.114 (  22.653s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.115 (  22.654s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.115 (  22.654s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.115 (  22.655s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.117 (  22.656s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.117 (  22.656s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.118 (  22.657s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.118 (  22.657s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.118 (  22.657s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.118 (  22.657s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.118 (  22.657s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.119 (  22.658s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.119 (  22.658s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.119 (  22.658s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.121 (  22.660s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.122 (  22.661s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.122 (  22.661s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.122 (  22.661s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.123 (  22.662s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.123 (  22.662s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.123 (  22.662s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.124 (  22.663s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.124 (  22.663s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.124 (  22.663s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.124 (  22.663s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.124 (  22.663s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.124 (  22.663s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.124 (  22.663s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.124 (  22.663s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.125 (  22.664s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.125 (  22.664s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.125 (  22.664s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.125 (  22.664s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.125 (  22.664s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.125 (  22.664s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.125 (  22.664s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.126 (  22.665s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.126 (  22.665s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.126 (  22.665s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.126 (  22.665s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.126 (  22.665s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.126 (  22.665s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.126 (  22.665s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.126 (  22.665s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.126 (  22.665s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.127 (  22.666s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.127 (  22.666s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.127 (  22.666s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.129 (  22.668s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.129 (  22.668s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.130 (  22.669s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:54.130 (  22.669s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.130 (  22.669s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 2
# 2024-04-14 16:51:54.132 (  22.671s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 0 - 3
# 2024-04-14 16:51:54.132 (  22.671s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.134 (  22.673s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.135 (  22.674s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 0
# 2024-04-14 16:51:54.135 (  22.674s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 0
# 2024-04-14 16:51:54.172 (  22.711s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:54.172 (  22.711s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-14 16:51:54.174 (  22.713s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:54.174 (  22.713s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-14 16:51:54.185 (  22.724s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:54.185 (  22.724s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-14 16:51:54.187 (  22.726s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:54.187 (  22.726s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 3 - 2
# 2024-04-14 16:51:54.192 (  22.731s) [main            ]topologycomputation.cpp:776   INFO| Requesting connectivity 2 - 3
# 2024-04-14 16:51:54.208 (  22.747s) [main            ]    SparsityPattern.cpp:384   INFO| Column ghost size increased from 0 to 0
# 2024-04-14 16:51:54.210 (  22.749s) [main            ]      xdmf_function.cpp:51    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"

# %%
# Display the GIF
from IPython.display import display, Image
display(Image(filename = 'T4.gif'))
