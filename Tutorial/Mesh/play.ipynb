# %%
import gmsh
import math

import sys

gmsh.initialize(sys.argv)


rp_outer = r_outer - 20 
rp_inner = r_inner + 20
angle = 80/360*3.1415926

# x (double), y (double), z (double), dx (double), dy (double), dz (double),
# r (double), tag = -1 (integer), angle = 2*pi (double)
outer_pad  = gmsh.model.occ.addCylinder(0,0,B,  0, 0, B,  rp_outer, 2, angle)
inner_pad  = gmsh.model.occ.addCylinder(0,0,B,  0, 0, B,  rp_inner, 3, angle)
#[(3, )]  3 means dimension, cut the common place
pad = gmsh.model.occ.cut([(3, outer_pad)], [(3, inner_pad)])

gmsh.model.occ.synchronize()
# Generate the mesh
gmsh.model.occ.synchronize()
gmsh.model.mesh.generate()

if '-nopopup' not in sys.argv:
    gmsh.fltk.run()

gmsh.finalize()
# Out:
# Error   : Unknown mesh format '/home/yanjun/.local/share/jupyter/runtime/kernel-243b7873-7f4d-4200-b436-b8b64a7a5698.json'
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 10 (Circle)
# Info    : [ 10%] Meshing curve 11 (Line)
# Info    : [ 20%] Meshing curve 12 (Circle)
# Info    : [ 30%] Meshing curve 13 (Line)
# Info    : [ 40%] Meshing curve 14 (Circle)
# Info    : [ 50%] Meshing curve 15 (Line)
# Info    : [ 50%] Meshing curve 16 (Circle)
# Info    : [ 60%] Meshing curve 17 (Line)
# Info    : [ 70%] Meshing curve 18 (Line)
# Info    : [ 80%] Meshing curve 19 (Line)
# Info    : [ 90%] Meshing curve 20 (Line)
# Info    : [100%] Meshing curve 21 (Line)
# Info    : Done meshing 1D (Wall 0.000652037s, CPU 0.000511s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 6 (Cylinder, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 7 (Cylinder, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 8 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 9 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 10 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 11 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00597365s, CPU 0.007742s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 1 volume with 1 connected component
# Info    : Tetrahedrizing 124 nodes...
# Info    : Done tetrahedrizing 132 nodes (Wall 0.000759313s, CPU 0.00076s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.00165859s, CPU 0.002634s)
# Info    : Found volume 2
# Info    : It. 0 - 0 nodes created - worst tet radius 0.78857 (nodes removed 0 0)
# Info    : 3D refinement terminated (124 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 298 tetrahedra created in 8.6323e-05 sec. (3452150 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 0.00380914s, CPU 0.005124s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 2
# Info    : Optimization starts (volume = 209425) with worst = 0.459553 / average = 0.741793:
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :        49 elements
# Info    : 0.60 < quality < 0.70 :        51 elements
# Info    : 0.70 < quality < 0.80 :        98 elements
# Info    : 0.80 < quality < 0.90 :        82 elements
# Info    : 0.90 < quality < 1.00 :        16 elements
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :         0 elements
# Info    : 0.40 < quality < 0.50 :         2 elements
# Info    : 0.50 < quality < 0.60 :        49 elements
# Info    : 0.60 < quality < 0.70 :        51 elements
# Info    : 0.70 < quality < 0.80 :        98 elements
# Info    : 0.80 < quality < 0.90 :        82 elements
# Info    : 0.90 < quality < 1.00 :        16 elements
# Info    : Done optimizing mesh (Wall 0.000332444s, CPU 0.000409s)
# Info    : 124 nodes 602 elements
# -------------------------------------------------------
# Version       : 4.12.2
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 20240121
# Build host    : gmsh.info
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blas[petsc] Blossom Cgns DIntegration Dlopen DomHex Eigen[contrib] Fltk Gmm[contrib] Hxt Jpeg Kbipack Lapack[petsc] LinuxJoystick MathEx[contrib] Med Mesh Metis[contrib] Mmg Mpeg Netgen ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom PETSc Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.4.0
# PETSc version : 3.14.4 (real arithmtic)
# OCC version   : 7.7.2
# MED version   : 4.1.0
# Packaged by   : geuzaine
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------
