# %% [markdown]
# # Time step analysis
# Average temperature_Tetra
# 2024-09-10 yanjun zhang

# %% [markdown]
# # Average
# only tetrahedral

# %%
import os
import shutil
import pandas as pd
import re
import sys
import matplotlib.pyplot as plt
import numpy as np

sys.path.append('/home/yanjun/documents/fenicsx/mech_disc/main_simulation/')
from disc_f import *
source_dir = '/home/yanjun/documents/sim_results/elasticity_2025/dt/'

# Collect all CSV files from the destination directory
csv_files = collect_csv_files(source_dir)
type1 = 'time_step'
csv_files.sort(key=lambda x: extract_file_labels(x,type1))

plt.figure(figsize=(10, 6))

df1 = pd.read_csv('/home/yanjun/documents/sim_results/experiment_result.csv')
T_e_ave = ( df1.iloc[:,1] + df1.iloc[:,3] + df1.iloc[:,5] ) /3
t_e = np.linspace (0, 49, len(T_e_ave) )
plt.plot(t_e, T_e_ave, label= "Experiment",marker='d',markevery=1000)

j = 0
marker_styles = ['o', 's', '^', 'v', '>', '<','d', '*', 'x', 'p'] 

for csv_file in csv_files:
    lables = find_3_coord(  extract_mesh_labels(csv_file)  )
    t,T = read_t_T ( csv_file )
    time_s = round( 49/ extract_file_labels(csv_file, type1), 2)
    #calculate average temperature
    T_3_ave = []
    for i in range(len(T)):
        T_3_all =  T[i][ lables[0] ] + T[i][ lables[1] ] + T[i][ lables[2] ]   
        T_3_ave.append ( T_3_all / 3 )
    plt.plot(t,pd.Series(T_3_ave).rolling(window=20).mean(),label= f'dt={ time_s } s',
             marker=marker_styles[j], markevery=100)
    j += 1

   
plt.xlabel('Time/ s')
plt.ylabel('Temperature/ °C')
plt.title('Average temperatures with different time steps')
plt.legend()
plt.grid(True)
plt.savefig('T_ave_dt.png')
plt.show()
# Out:
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-3-d-112000-m-3-5-c-1-e-271817/Result_T-s-3-d-112000-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-14-d-11200-m-3-5-c-1-e-271817/Result_T-s-14-d-11200-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-21-d-7168-m-3-5-c-1-e-271817/Result_T-s-21-d-7168-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-40-d-3584-m-3-5-c-1-e-271817/Result_T-s-40-d-3584-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-78-d-1792-m-3-5-c-1-e-271817/Result_T-s-78-d-1792-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-154-d-896-m-3-5-c-1-e-271817/Result_T-s-154-d-896-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-304-d-448-m-3-5-c-1-e-271817/Result_T-s-304-d-448-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-608-d-224-m-3-5-c-1-e-271817/Result_T-s-608-d-224-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-1213-d-112-m-3-5-c-1-e-271817/Result_T-s-1213-d-112-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-2424-d-56-m-3-5-c-1-e-271817/Result_T-s-2424-d-56-m-3-5-c-1-e-271817.csv

# %%
print( round( 49/ extract_file_labels(csv_file, type1), 2))
# Out:
# 0.04

# %% [markdown]
# ## Absolute error

# %%
import os
import pandas as pd
import sys
import matplotlib.pyplot as plt
import numpy as np

# Adding path for your custom functions (if needed)
sys.path.append('/home/yanjun/documents/fenicsx/mech_disc/main_simulation/')
from disc_f import *  # Assuming this file has functions like collect_csv_files, extract_file_labels, etc.

# Directory containing your simulation results
source_dir = '/home/yanjun/documents/sim_results/elasticity_2025/dt/'
csv_files = collect_csv_files(source_dir)
type1 = 'time_step'
csv_files.sort(key=lambda x: extract_file_labels(x, type1))

# Read experimental data
df1 = pd.read_csv('/home/yanjun/documents/sim_results/experiment_result.csv')
T_e_ave = (df1.iloc[:, 1] + df1.iloc[:, 3] + df1.iloc[:, 5]) / 3  # Average of experimental temperatures

# Initialize lists to store DOF and average relative errors for each case
dt_list = []
avg_relative_errors = []

# Loop over all CSV files (cases)
for csv_file in csv_files:
    labels = find_3_coord(extract_mesh_labels(csv_file))
    num_elements = extract_file_labels(csv_file, type1)
    time_s = round( (49/extract_file_labels(csv_file, type1)), 5)
    #dt = 49/ extract_file_labels(csv_file, type1)  # time steps calculation
    # Read simulated time and temperature data
    t, T = read_t_T(csv_file)
    # Calculate average temperature at the three labels
    T_3_ave = []
    for i in range(len(T)):
        T_3_all = T[i][labels[0]] + T[i][labels[1]] + T[i][labels[2]]
        T_3_ave.append(T_3_all / 3)
    import numpy as np
    # Assuming T_e_ave is larger and you want to resize it to match T_3_ave
    # Generate corresponding time arrays for interpolation
    time_T_e_ave = np.linspace(0, 49, len(T_e_ave))  # Time for T_e_ave (example)
    time_T_3_ave = np.linspace(0, 49, len(T_3_ave))  # Time for T_3_ave (example)

    # Interpolate T_e_ave to have the same length as T_3_ave
    T_e_ave_resampled = np.interp(time_T_3_ave, time_T_e_ave, T_e_ave)
    # Now you can safely calculate the relative error
    relative_error = np.abs((T_e_ave_resampled - T_3_ave) / T_e_ave_resampled)
 
    # Compute relative error between experimental (T_e_ave) and simulation (T_3_ave)
    # Store DOF and the average relative error for this case
    dt_list.append(time_s)
    avg_relative_errors.append(np.mean(relative_error))
    
marker_styles = ['o', 's', '^', 'v', '>', '<','d', '*', 'x', 'p' ] 
# Plot DOF vs Average Relative Error
fontsize_global = 20
plt.figure(figsize=(11, 6))
plt.loglog(dt_list, avg_relative_errors, marker='o', linestyle='-', color='b', label="Relative error of average temperature")

for i in range(len(avg_relative_errors)):
    plt.text(dt_list[i], avg_relative_errors[i],f'{(dt_list[i]):.2f} s', ha='left', va='bottom', fontsize=fontsize_global)


# Label the axes
plt.xlabel('Time steps/ s', fontsize=fontsize_global)
plt.ylabel('Relative Error', fontsize=fontsize_global)
#plt.title('Relative Error vs Time Step',fontsize=fontsize_global)

y_ticks = [10**i for i in range(-1, 0)]

plt.xticks(fontsize=fontsize_global)
plt.yticks(y_ticks , fontsize=fontsize_global)

# Add grid and legend
plt.grid(True, which="both", ls="--")
plt.legend(fontsize=fontsize_global)
plt.tight_layout()

# Save and display the plot
plt.savefig('relative_error_vs_dt.pdf')
plt.show()
# Out:
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/elasticity_2025/dt/s-14-d-11200-m-3-5-c-1-e-271817/Result_T-s-14-d-11200-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/elasticity_2025/dt/s-154-d-896-m-3-5-c-1-e-271817/Result_T-s-154-d-896-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/elasticity_2025/dt/s-304-d-448-m-3-5-c-1-e-271817/Result_T-s-304-d-448-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/elasticity_2025/dt/s-608-d-224-m-3-5-c-1-e-271817/Result_T-s-608-d-224-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/elasticity_2025/dt/s-1213-d-112-m-3-5-c-1-e-271817/Result_T-s-1213-d-112-m-3-5-c-1-e-271817.csv

# %% [markdown]
# ## RMSE

# %%
import os
import pandas as pd
import sys
import matplotlib.pyplot as plt
import numpy as np

# Adding path for your custom functions (if needed)
sys.path.append('/home/yanjun/documents/fenicsx/mech_disc/main_simulation/')

from disc_f import *  # Assuming this file has functions like collect_csv_files, extract_file_labels, etc.

# Directory containing your simulation results
source_dir = '/home/yanjun/documents/sim_results/elasticity_2025/dt/'

# Collect all CSV files from the directory
csv_files = collect_csv_files(source_dir)

# Sort CSV files by mesh size or other labels (e.g., 'mesh_size')
type1 = 'mesh_size'
csv_files.sort(key=lambda x: extract_file_labels(x, type1))

# Read experimental data
df1 = pd.read_csv('/home/yanjun/documents/sim_results/experiment_result.csv')
T_e_ave = (df1.iloc[:, 1] + df1.iloc[:, 3] + df1.iloc[:, 5]) / 3  # Average of experimental temperatures

# Initialize lists to store DOF and average relative errors for each case
dof_list = []
avg_rmse_errors = []

# Loop over all CSV files (cases)
for csv_file in csv_files:
    # Extract mesh information and calculate DOF (elements * 4)
    labels = find_3_coord(extract_mesh_labels(csv_file))
    num_elements = extract_file_labels(csv_file, type1)
    dof = int(num_elements) * 4  # DOF calculation

    # Read simulated time and temperature data
    t, T = read_t_T(csv_file)

    # Calculate average temperature at the three labels
    T_3_ave = []
    for i in range(len(T)):
        T_3_all = T[i][labels[0]] + T[i][labels[1]] + T[i][labels[2]]
        T_3_ave.append(T_3_all / 3)

    time_T_e_ave = np.linspace(0, 49, len(T_e_ave))  # Time for T_e_ave (example)
    time_T_3_ave = np.linspace(0, 49, len(T_3_ave))  # Time for T_3_ave (example)

    # Interpolate T_e_ave to have the same length as T_3_ave
    T_e_ave_resampled = np.interp(time_T_3_ave, time_T_e_ave, T_e_ave)

    sum = 0;
    for i in range(len(T_3_ave)):
        sum = sum + np.abs(T_3_ave[i]-T_e_ave_resampled[i])
    rmse_error = sum/ len(T);


    # Store DOF and the average relative error for this case
    dof_list.append(dof)
    avg_rmse_errors.append(rmse_error)

# Plot DOF vs Average Relative Error
plt.figure(figsize=(10, 6))
plt.loglog(dof_list, avg_rmse_errors, marker='o', linestyle='-', color='b', label="RMSE")

# Label the axes
plt.xlabel('Degrees of Freedom (DOF)')
plt.ylabel('RMSE')
plt.title('RMSE vs Degrees of Freedom')

# Add grid and legend

plt.grid(True, which="both", ls="--")
plt.legend()

# Save and display the plot
plt.savefig('RMSE_vs_dof.png')
plt.show()

# %% [markdown]
# # Max

# %%
import os
import shutil
import pandas as pd
import re
import sys
import matplotlib.pyplot as plt
import numpy as np


sys.path.append('/home/yanjun/documents/fenicsx/mech_disc/main_simulation/')
from disc_f import *
source_dir = '/home/yanjun/documents/sim_results/elasticity_2025/dt/'

# Collect all CSV files from the destination directory
csv_files = collect_csv_files(source_dir)
type1 = 'time_step'
csv_files.sort(key=lambda x: extract_file_labels(x,type1))

plt.figure(figsize=(10, 6))


df1 = pd.read_csv('/home/yanjun/documents/sim_results/experiment_result.csv')
T_e_max = np.maximum( np.maximum (df1.iloc[:,1], df1.iloc[:,3]) , df1.iloc[:,5] ) 
t_e = np.linspace (0, 49, len(T_e_max) )
plt.plot(t_e, T_e_max, label= "Experiment",marker='d',markevery=1000)

j = 0
marker_styles = ['o', 's', '^', 'v', '>', '<', 'd' , '*', 'x', 'p'] 

#####
for csv_file in csv_files[1:]:
    lables = find_3_coord(  extract_mesh_labels(csv_file)  )
    t,T = read_t_T ( csv_file )
    time_s = round( 49/ extract_file_labels(csv_file, type1), 2)
    #calculate average temperature
    T_max = []
    for i in range(len(T)):
        T_max.append( max(T[i]) )
    plt.plot(t,pd.Series(T_max).rolling(window=15).mean(),label= f'dt={ time_s } s',
             marker=marker_styles[j], markevery=100)
    j += 1


plt.xlabel('Time/ s')
plt.ylabel('Temperature/ °C')
plt.title('The maximum temperatures with different different time steps')
plt.legend()
plt.grid(True)
plt.savefig('T_max_time_step.png')
plt.show()
# Out:
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-14-d-11200-m-3-5-c-1-e-271817/Result_T-s-14-d-11200-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-21-d-7168-m-3-5-c-1-e-271817/Result_T-s-21-d-7168-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-40-d-3584-m-3-5-c-1-e-271817/Result_T-s-40-d-3584-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-78-d-1792-m-3-5-c-1-e-271817/Result_T-s-78-d-1792-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-154-d-896-m-3-5-c-1-e-271817/Result_T-s-154-d-896-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-304-d-448-m-3-5-c-1-e-271817/Result_T-s-304-d-448-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-608-d-224-m-3-5-c-1-e-271817/Result_T-s-608-d-224-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-1213-d-112-m-3-5-c-1-e-271817/Result_T-s-1213-d-112-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/implicit_dt/s-2424-d-56-m-3-5-c-1-e-271817/Result_T-s-2424-d-56-m-3-5-c-1-e-271817.csv

# %% [markdown]
# # Relative error

# %%
import os
import pandas as pd
import sys
import matplotlib.pyplot as plt
import numpy as np

# Adding path for your custom functions (if needed)
sys.path.append('/home/yanjun/documents/fenicsx/mech/')
from disc_f import *  # Assuming this file has functions like collect_csv_files, extract_file_labels, etc.

# Directory containing your simulation results
source_dir = '/home/yanjun/documents/sim_results/elasticity_2025/dt/'
csv_files = collect_csv_files(source_dir)
type1 = 'time_step'
csv_files.sort(key=lambda x: extract_file_labels(x, type1))

# Read experimental data
df1 = pd.read_csv('/home/yanjun/documents/sim_results/experiment_result.csv')
T_e_max = np.maximum( np.maximum (df1.iloc[:,1], df1.iloc[:,3]) , df1.iloc[:,5] ) 

# Initialize lists to store DOF and average relative errors for each case
dt_list = []
max_relative_errors = []

# Loop over all CSV files (cases)
for csv_file in csv_files:
    labels = find_3_coord(extract_mesh_labels(csv_file))

    time_s = round( (49/extract_file_labels(csv_file, type1)), 5)
    #dt = 49/ extract_file_labels(csv_file, type1)  # time steps calculation
    # Read simulated time and temperature data
    t, T = read_t_T(csv_file)
    # Calculate average temperature at the three labels
    T_3_max = []
    for i in range(len(T)):    
        T_3_max.append( max(T[i]) )
    
    import numpy as np
    # Assuming T_e_ave is larger and you want to resize it to match T_3_ave
    # Generate corresponding time arrays for interpolation
    time_T_e_max = np.linspace(0, 49, len(T_e_max))  # Time for T_e_ave (example)
    time_T_3_max = np.linspace(0, 49, len(T))  # Time for T_3_ave (example)

    # Interpolate T_e_ave to have the same length as T_3_ave
    T_e_max_resampled = np.interp(time_T_3_max, time_T_e_max, T_e_max)
    # Now you can safely calculate the relative error
    relative_error = np.abs((T_e_max_resampled - T_3_max) / T_e_max_resampled)
 
    # Compute relative error between experimental (T_e_ave) and simulation (T_3_ave)
    # Store DOF and the average relative error for this case
    dt_list.append(time_s)
    max_relative_errors.append(np.mean(relative_error))

for i in range(len(max_relative_errors)):
    plt.text(dt_list[i], max_relative_errors[i],f'{(dt_list[i]):.2f} s', ha='left', va='bottom', fontsize=fontsize_global)


marker_styles = ['o', 's', '^', 'v', '>', '<','d', '*', 'x', 'p' ] 
# Plot DOF vs Average Relative Error
plt.figure(figsize=(10, 6))
plt.loglog(dt_list, max_relative_errors, marker='o', linestyle='-', color='b', label="Average Relative Error")

# Label the axes
plt.xlabel('Time steps/ s')
plt.ylabel('The Max Relative Error')
plt.title('The Max Relative Error vs Time Step')

# Add grid and legend
plt.grid(True, which="both", ls="--")
plt.legend()

# Save and display the plot
plt.savefig('max_relative_error vs_dt.png')
plt.show()
# Out:
# DOLFINx version: 0.8.0
# Simulation environment setup complete.
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/elasticity_2025/dt/s-14-d-11200-m-3-5-c-1-e-271817/Result_T-s-14-d-11200-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/elasticity_2025/dt/s-154-d-896-m-3-5-c-1-e-271817/Result_T-s-154-d-896-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/elasticity_2025/dt/s-304-d-448-m-3-5-c-1-e-271817/Result_T-s-304-d-448-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/elasticity_2025/dt/s-608-d-224-m-3-5-c-1-e-271817/Result_T-s-608-d-224-m-3-5-c-1-e-271817.csv
# Lables already exists, for mesh m-3-5.msh is  [19098, 34079, 7351]
# t and T have been successfully extracted from /home/yanjun/documents/sim_results/elasticity_2025/dt/s-1213-d-112-m-3-5-c-1-e-271817/Result_T-s-1213-d-112-m-3-5-c-1-e-271817.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 55
#      52     max_relative_errors.append(np.mean(relative_error))
#      54 for i in range(len(max_relative_errors)):
# ---> 55     plt.text(dt_list[i], max_relative_errors[i],f'{(dt_list[i]):.2f} s', ha='left', va='bottom', fontsize=fontsize_global)
#      58 marker_styles = ['o', 's', '^', 'v', '>', '<','d', '*', 'x', 'p' ]
#      59 # Plot DOF vs Average Relative Error
#
# NameError: name 'fontsize_global' is not defined

# %%
from matplotlib.ticker import ScalarFormatter
plt.figure(figsize=(10, 6))
for i in range(len(max_relative_errors)):
    plt.text(dt_list[i], max_relative_errors[i],f'{(dt_list[i]):.2f} s', ha='left', va='bottom', fontsize=20)

fontsize_global = 20

marker_styles = ['o', 's', '^', 'v', '>', '<','d', '*', 'x', 'p' ] 
# Plot DOF vs Average Relative Error
#plt.figure(figsize=(10, 6))
plt.loglog(dt_list, max_relative_errors, marker='o', linestyle='-', color='b', label="Relative error of the maximum temperature")


x_tickes = [10**i for i in range(-1, 1)]
y_tickes =  [0.1,  1, 2]
plt.xticks(x_tickes, fontsize=fontsize_global)
plt.yticks(y_tickes, fontsize=fontsize_global)

plt.gca().yaxis.set_minor_formatter(ScalarFormatter())
# Label the axes
plt.xlabel('Time steps/ s',fontsize=20)
plt.ylabel('Relative Error',fontsize=20)
#plt.title('Relative error of the maximum T vs Time Step')

# Add grid and legend
plt.grid(True, which="both", ls="--")
plt.legend(fontsize=fontsize_global)
plt.tight_layout()


# Save and display the plot
plt.savefig('max_relative_error vs_dt.pdf')
plt.show()
