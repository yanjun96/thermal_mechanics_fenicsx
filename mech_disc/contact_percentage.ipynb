c8 = [0.9928705843334424, 0.9537650379009208, 0.9537650379088857, 0.9537650379090205, 0.9186216099719112, 0.943846827805282, 0.9731676740318537, 0.969302725423012, 0.9706784271628649, 1.1034828631277278, 1.0701189735896164, 1.0519086589468218, 1.0644114271169258, 1.0000304925535015, 0.9419526618960125, 0.9231360190265135, 0.955975869538971, 0.9760444499729448, 1.0184788867765702, 0.949277557997013, 0.9261158040361436, 0.9229343417473989, 0.8966151393668723, 0.878795259275346, 0.8522371902275218, 0.8653025709639743, 0.8757916911653828, 0.9063991696150544, 0.8290342988282912, 0.8138487439867989, 0.8058405116424308, 0.7969239327443057, 0.7434892527992122, 0.757639622112694, 0.7766224265760943, 0.7783072818747465, 0.707759316470202, 0.6468194521056738, 0.6244577135943558, 0.6260608044801854, 0.6418069647380351, 0.619307075338869, 0.5932343522546042, 0.6039282672472548, 0.60546321955843, 0.7000348677141826, 0.6521828221202992, 0.6289540595353114, 0.6276012036814645, 0.6335345078545062, 0.6184365149824625, 0.6240707820649513, 0.6285379658808531, 0.6601541399324578, 0.7280775671374754, 0.685229785586263, 0.6651439067243555, 0.6799553653028877, 0.7099701519724418, 0.6831439146843046, 0.7045530526405693, 0.8160483074008361]

# %% [markdown]
# # Z=0.00005, wear on

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import PercentFormatter as PF
plt.rcParams.update({'font.size':14})

def moving_average(data,window):
    return np.convolve(data, np.ones(window)/window, mode ='valid')

ave_size = 15

c61 = moving_average(c6,ave_size)
c61[0]= 0.992


x_new = np.linspace(0,49, len(moving_average(c3,ave_size)))
mark_skip= 3
labels = ["wear rate: 6.7*10-7","wear rate: 6.7*10^{-8}","wear off"]
plt.plot(x_new, moving_average(c7,ave_size), label = labels[0] , marker = "o" , markevery=mark_skip)
plt.plot(x_new, moving_average(c8,ave_size), label = labels[1] , marker = "^" , markevery=mark_skip)
plt.plot(x_new, c61,                         label = labels[2] , marker = "s" , markevery=mark_skip)

plt.gca().yaxis.set_major_formatter(PF(xmax=1))
plt.legend(fontsize  = 12)
plt.xlabel("Time /s")
plt.ylabel("Contact percentage /%")
plt.tight_layout()
#plt.savefig("new_figure.png")

# %% [markdown]
# Contact Zone

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import PercentFormatter as PF

plt.rcParams.update({'font.size':14})

def moving_average(data,window):
    return np.convolve(data, np.ones(window)/window, mode ='valid')

ave_size = 15

c61 = moving_average(c6,ave_size)
c61[0]= 0.992


x_new = np.linspace(0,49, len(moving_average(c3,ave_size)))
mark_skip= 3
labels = ["contact radius = 0.00009 mm","contact radius = 0.00005 mm","contact radius = 0.00003 mm"]
plt.plot(x_new, moving_average(c3,ave_size), label = labels[0] , marker = "o" , markevery=mark_skip)
plt.plot(x_new, moving_average(c5,ave_size), label = labels[1] , marker = "^" , markevery=mark_skip)
plt.plot(x_new, c61,                         label = labels[2] , marker = "s" , markevery=mark_skip)

plt.gca().yaxis.set_major_formatter(PF(xmax=1))
plt.legend(fontsize  = 12)
plt.xlabel("Time /s")
plt.ylabel("Contact percentage /%")
plt.tight_layout()
plt.savefig("contact_radius.png")
