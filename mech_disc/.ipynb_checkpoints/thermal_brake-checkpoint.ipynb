# %% [markdown]
# ## Concise: 1: Start
# Author: yanjun zhang, Source from book "Abali - 2017 - Computational Reality" P119

# %%
from my_imports import *

# calculate how long time the simulation it is
start_time = time.time()

# mesh-size, contact area coefficient
mesh_min = 3
mesh_max = 15
c_contact = 1

# Each time step rotation angular, and acc during lag, 1 is full acc, 0 is no acc.
angular_r = 224000/2
v_vehicle = 160
c_acc = 1

# calling local functions to get all parameters
(dt, P, g, num_steps, h, radiation, v_angular, Ti, Tm, S_rub_circle, t, rho, c, k, t_brake, 
S_total,) = vehicle_initial (angular_r, v_vehicle, c_contact, c_acc)

print("1: Total tims is ", round(sum(dt), 2), "s")
print("2: Total numb steps is ", num_steps)
# Out:
# DOLFINx version: 0.8.0
# 1: Total tims is  -119.47 s
# 2: Total numb steps is  3

# %% [markdown]
# ## 2: Mesh

# %%
domain, cell_markers, facet_amrkers, \
mesh_name, mesh_filename1, mesh_filename2 = mesh_brake_all(mesh_min,mesh_max)

# Define variational problem, CG is Lagrabge
V = fem.functionspace(domain, ("CG", 1))

# u_n is for initial condition and uh is the solver result.
# variable, need to be projected form Q onto V, DG is discontinuous Lagrange. 
Q = fem.functionspace(domain, ("DG", 0))
T_init = Function(Q)
T_init.name = "u_n"
T_init.x.array[:] = np.full_like(1, Ti, dtype=default_scalar_type)
u_n = project(T_init, V)
u_n.name = "u_n"

fdim = domain.topology.dim - 1

## bc_disc is zero, no any dirichlete boundary condition, z = 100, not exist
bc_disc = mesh.locate_entities_boundary(domain, fdim, lambda x: np.isclose(x[2], 100)) 
bc = fem.dirichletbc( PETSc.ScalarType(Tm), fem.locate_dofs_topological(V, fdim, bc_disc), V  )
np.set_printoptions(threshold=np.inf)

import meshio
mesh1 = meshio.read(mesh_filename1)
total_elements = sum(len(cells.data) for cells in mesh1.cells)

# create xdmf file, for paraview
xdmf_name = "T-s-{}-d-{}-{}-c-{}-e-{}.xdmf".format( num_steps, angular_r, mesh_filename2, c_contact, total_elements)
h5_name = "T-s-{}-d-{}-{}-c-{}-e-{}.h5".format( num_steps, angular_r, mesh_filename2, c_contact, total_elements )

xdmf = io.XDMFFile(domain.comm, xdmf_name, "w")
xdmf.write_mesh(domain)

# Create boundary condition
x_co, y_co = get_rub_coordinate()
common_indices3, facet_markers3, sorted_indices3 = target_facets (domain, x_co, y_co, S_rub_circle )
facet_tag = meshtags (domain, fdim, common_indices3[sorted_indices3], facet_markers3[sorted_indices3] )
ds = Measure("ds", domain=domain, subdomain_data=facet_tag)
# Out:
# The file 'm-3-15.msh' exists, start creat now:
# Info    : Reading 'm-3-15.msh'...
# Info    : 168 entities
# Info    : 4281 nodes
# Info    : 14875 elements
# Info    : Done reading 'm-3-15.msh'

# %% [markdown]
# ## 3: Variational equation

# %%
uh = fem.Function(V)
uh.name = "uh"
uh = project(T_init, V)  ##give temperature to all elements
t = 0
xdmf.write_function(uh, t)

# u = trial function, solution what we want to know
u = fem.Function(V)
v = ufl.TestFunction(V)
f = fem.Constant(domain, PETSc.ScalarType(0))  ## heat source is 0
n_vector = FacetNormal(domain)

F = ( (rho * c) / dt[0] * inner(u, v) * dx
    + k * inner(grad(u), grad(v)) * dx
    + h * inner(u, v) * ds(200)    #200 is the contact area, details are in function of target_facets.
    + radiation * inner(u**4, v) * ds(200)
    - ( inner(f, v) * dx
        + (rho * c) / dt[0] * inner(u_n, v) * dx
        + h * Tm * v * ds(200)
        + radiation * (Tm**4) * v * ds(200) ) )

for i in list(range(1, 19)):  # before 2024/5/16
    F += (+ inner(g[0], v) * ds(10 * i) 
          - h * inner( u, v) * ds(10 * i)  
          - radiation * inner( (u**4 - Tm**4), v) * ds(10 * i)  )

problem = NonlinearProblem(F, u, bcs=[bc])
n,converged = solver_setup_solve(problem,u);

## 8:Visualization of time dependent problem using pyvista
gif_name = "T-s-{}-d-{}-{}-c-{}-e-{}.gif".format(
    num_steps, angular_r, mesh_filename2, c_contact, total_elements)

plotter, sargs, renderer, warped, viridis, grid = plot_gif(V,u,gif_name)
# Out:
# 2024-10-17 19:32:22.220 (   1.527s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:22.267 (   1.574s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:22.278 (   1.585s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 2: r (abs) = 0.073373 (tol = 1e-10) r (rel) = 1.86658e-05(tol = 1e-06)
# 2024-10-17 19:32:22.293 (   1.600s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:22.303 (   1.610s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 3: r (abs) = 4.56148e-07 (tol = 1e-10) r (rel) = 1.16042e-10(tol = 1e-06)
# 2024-10-17 19:32:22.303 (   1.610s) [main            ]       NewtonSolver.cpp:252   INFO| Newton solver finished in 3 iterations and 16 linear solver iterations.

# %% [markdown]
# ## 4: Solution

# %%
T_array = [(0, [Ti for _ in range(len(u.x.array))])]
total_degree = 0

for i in range(num_steps):
    t += dt[i]

    x_co, y_co = rub_rotation(x_co, y_co, angular_r)  # update the location
    total_degree += angular_r  # Incrementing degree by 10 in each step

    sys.stdout.write("\r1: Rotation has applied for {} degree. ".format(total_degree))
    sys.stdout.write("2: Current time is " + str(round(t, 1)) + " s. ")
    sys.stdout.write("3: Completion is " + str(round(100 * (t / t_brake), 1)) + " %. ")
    sys.stdout.flush()

    common_indices3, facet_markers3, sorted_indices3 = target_facets(
                domain, x_co, y_co, S_rub_circle  )
    facet_tag = meshtags( domain, fdim, common_indices3[sorted_indices3], \
                         facet_markers3[sorted_indices3]  )
    ds = Measure("ds", domain=domain, subdomain_data=facet_tag)

    F = ((rho * c) / dt[i] * inner(u, v) * dx
        + k * inner(grad(u), grad(v)) * dx
        + h * inner(u, v) * ds(200)
        + radiation * inner(u**4, v) * ds(200)
        - ( inner(f, v) * dx
            + (rho * c) / dt[i] * inner(u_n, v) * dx
            + h * Tm * v * ds(200)
            + radiation * (Tm**4) * v * ds(200)) )

    for j in list(range(1, 19)):
        #F += -k * dot(grad(u) * v, n_vector) * ds(10 * j) - inner(g[i], v) * ds(10 * j)
        F += ( - inner(g[i], v) * ds(10 * j) 
               - h * inner( u, v) * ds(10 * j)  
               - radiation * inner( (u**4 - Tm**4), v) * ds(10 * j) )    

    problem = NonlinearProblem(F, u, bcs=[bc])

    ## 7: Using petsc4py to create a linear solver
    solver_setup_solve(problem,u)
    u.x.scatter_forward()

    sys.stdout.write("1: Completion is " + str(round(100 * (t / t_brake), 1)) + " %. ")
    sys.stdout.flush()     

    # Update solution at previous time step (u_n)
    u_n.x.array[:] = u.x.array
    T_array.append((t, u.x.array.copy()))
    # Write solution to file
    xdmf.write_function(u, t)
    # Update plot
    #warped = grid.warp_by_scalar("uh", factor=0)
    plotter.update_coordinates(warped.points.copy(), render=False)
    plotter.update_scalars(u.x.array, render=False)
    plotter.write_frame()

plotter.close()
xdmf.close()
print()

csv_name = "Result_T-s-{}-d-{}-{}-c-{}-e-{}.csv".format(
    num_steps, angular_r, mesh_filename2, c_contact, total_elements  )

save_t_T(csv_name, T_array)
# Out:
# 1: Rotation has applied for 112000.0 degree. 2: Current time is 20.2 s. 3: Completion is 41.3 %.
# 2024-10-17 19:32:25.519 (   4.826s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.520 (   4.827s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.520 (   4.827s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.520 (   4.827s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.521 (   4.828s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.521 (   4.828s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.521 (   4.828s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.521 (   4.828s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.521 (   4.828s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.521 (   4.828s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.522 (   4.829s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.522 (   4.829s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.522 (   4.829s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.522 (   4.829s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.522 (   4.829s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.522 (   4.829s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.523 (   4.829s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.523 (   4.829s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.523 (   4.830s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.525 (   4.832s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.525 (   4.832s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.525 (   4.832s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.525 (   4.832s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.525 (   4.832s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.525 (   4.832s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.526 (   4.833s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.526 (   4.833s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.526 (   4.833s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.526 (   4.833s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.526 (   4.833s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.526 (   4.833s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.526 (   4.833s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.526 (   4.833s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.527 (   4.834s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.527 (   4.834s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.527 (   4.834s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.527 (   4.834s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.527 (   4.834s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.527 (   4.834s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.527 (   4.834s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.834s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.834s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.528 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.529 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.529 (   4.835s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.529 (   4.836s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:25.529 (   4.836s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.529 (   4.836s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (2,0)
# 2024-10-17 19:32:25.531 (   4.838s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (0,0) - (3,0)
# 2024-10-17 19:32:25.531 (   4.838s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.534 (   4.840s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.534 (   4.841s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:25.534 (   4.841s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:25.593 (   4.900s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:25.593 (   4.900s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-10-17 19:32:25.595 (   4.902s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:25.595 (   4.902s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-10-17 19:32:25.616 (   4.923s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:25.616 (   4.923s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-10-17 19:32:25.617 (   4.924s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:25.617 (   4.924s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-10-17 19:32:25.622 (   4.928s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:25.637 (   4.944s) [main            ]    SparsityPattern.cpp:385   INFO| Column ghost size increased from 0 to 0
# 2024-10-17 19:32:25.663 (   4.970s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:25.707 (   5.014s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 1: Completion is 41.3 %.
# 2024-10-17 19:32:25.718 (   5.025s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 2: r (abs) = 2.08588e-05 (tol = 1e-10) r (rel) = 1.76606e-06(tol = 1e-06)
# 2024-10-17 19:32:25.734 (   5.041s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:25.746 (   5.053s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 3: r (abs) = 2.27773e-11 (tol = 1e-10) r (rel) = 1.9285e-12(tol = 1e-06)
# 2024-10-17 19:32:25.746 (   5.053s) [main            ]       NewtonSolver.cpp:252   INFO| Newton solver finished in 3 iterations and 18 linear solver iterations.
# 2024-10-17 19:32:25.748 (   5.055s) [main            ]      xdmf_function.cpp:50    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 1: Rotation has applied for 224000.0 degree. 2: Current time is 54.7 s. 3: Completion is 111.6 %.
# 2024-10-17 19:32:26.081 (   5.388s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.082 (   5.389s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.082 (   5.389s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.082 (   5.389s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.082 (   5.389s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.083 (   5.389s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.083 (   5.390s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.083 (   5.390s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.083 (   5.390s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.083 (   5.390s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.083 (   5.390s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.083 (   5.390s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.083 (   5.390s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.084 (   5.391s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.084 (   5.391s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.084 (   5.391s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.084 (   5.391s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.084 (   5.391s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.084 (   5.391s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.084 (   5.391s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.084 (   5.391s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.084 (   5.391s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.085 (   5.392s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.085 (   5.392s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.085 (   5.392s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.085 (   5.392s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.085 (   5.392s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.085 (   5.392s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.086 (   5.393s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.086 (   5.393s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.086 (   5.393s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.086 (   5.393s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.086 (   5.393s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.086 (   5.393s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.086 (   5.393s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.087 (   5.393s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.087 (   5.394s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.087 (   5.394s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.087 (   5.394s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.087 (   5.394s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.087 (   5.394s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.087 (   5.394s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.087 (   5.394s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.087 (   5.394s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.087 (   5.394s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.088 (   5.395s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.088 (   5.395s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.088 (   5.395s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.088 (   5.395s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.089 (   5.396s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.089 (   5.396s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.089 (   5.396s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.089 (   5.396s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.089 (   5.396s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.090 (   5.397s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:26.090 (   5.397s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:26.090 (   5.397s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (2,0)
# 2024-10-17 19:32:26.093 (   5.400s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (0,0) - (3,0)
# 2024-10-17 19:32:26.093 (   5.400s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.094 (   5.401s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.095 (   5.402s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:26.095 (   5.402s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:27.890 (   7.197s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:27.890 (   7.197s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-10-17 19:32:27.891 (   7.198s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:27.891 (   7.198s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 1: Rotation has applied for 336000.0 degree. 2: Current time is -119.5 s. 3: Completion is -243.8 %.
# 2024-10-17 19:32:29.454 (   8.761s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:29.454 (   8.761s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-10-17 19:32:29.455 (   8.762s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:29.455 (   8.762s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-10-17 19:32:29.458 (   8.765s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:29.468 (   8.775s) [main            ]    SparsityPattern.cpp:385   INFO| Column ghost size increased from 0 to 0
# 2024-10-17 19:32:29.488 (   8.795s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:29.531 (   8.837s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:29.541 (   8.848s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 2: r (abs) = 10.5333 (tol = 1e-10) r (rel) = 0.00218797(tol = 1e-06)
# 2024-10-17 19:32:29.556 (   8.863s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:29.567 (   8.874s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 3: r (abs) = 0.00108707 (tol = 1e-10) r (rel) = 2.25806e-07(tol = 1e-06)
# 2024-10-17 19:32:29.567 (   8.874s) [main            ]       NewtonSolver.cpp:252   INFO| Newton solver finished in 3 iterations and 17 linear solver iterations.
# 2024-10-17 19:32:29.568 (   8.875s) [main            ]      xdmf_function.cpp:50    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 2024-10-17 19:32:29.619 (   8.926s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.619 (   8.926s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.619 (   8.926s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.619 (   8.926s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.620 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.621 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.621 (   8.927s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.621 (   8.928s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.621 (   8.928s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.621 (   8.928s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.621 (   8.928s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.621 (   8.928s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.621 (   8.928s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.621 (   8.928s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.621 (   8.928s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.621 (   8.928s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.928s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.622 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.929s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.623 (   8.930s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.624 (   8.931s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:29.624 (   8.931s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:29.624 (   8.931s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (2,0)
# 2024-10-17 19:32:29.625 (   8.932s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (0,0) - (3,0)
# 2024-10-17 19:32:29.625 (   8.932s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.627 (   8.934s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.627 (   8.934s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:29.627 (   8.934s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:31.271 (  10.578s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:31.271 (  10.578s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-10-17 19:32:31.273 (  10.580s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:31.273 (  10.580s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 1: Completion is -243.8 %.
# 2024-10-17 19:32:33.031 (  12.338s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:33.031 (  12.338s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-10-17 19:32:33.032 (  12.339s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:33.032 (  12.339s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-10-17 19:32:33.035 (  12.342s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:33.046 (  12.353s) [main            ]    SparsityPattern.cpp:385   INFO| Column ghost size increased from 0 to 0
# 2024-10-17 19:32:33.066 (  12.373s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:33.104 (  12.411s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:33.112 (  12.419s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 2: r (abs) = 154.366 (tol = 1e-10) r (rel) = 0.0800171(tol = 1e-06)
# 2024-10-17 19:32:33.126 (  12.433s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:33.133 (  12.440s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 3: r (abs) = 5.52711 (tol = 1e-10) r (rel) = 0.00286504(tol = 1e-06)
# 2024-10-17 19:32:33.146 (  12.453s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:33.153 (  12.460s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 4: r (abs) = 0.257993 (tol = 1e-10) r (rel) = 0.000133733(tol = 1e-06)
# 2024-10-17 19:32:33.166 (  12.473s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:33.173 (  12.480s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 5: r (abs) = 0.0119592 (tol = 1e-10) r (rel) = 6.19918e-06(tol = 1e-06)
# 2024-10-17 19:32:33.186 (  12.493s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-10-17 19:32:33.193 (  12.500s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 6: r (abs) = 0.000554549 (tol = 1e-10) r (rel) = 2.87456e-07(tol = 1e-06)
# 2024-10-17 19:32:33.193 (  12.500s) [main            ]       NewtonSolver.cpp:252   INFO| Newton solver finished in 6 iterations and 12 linear solver iterations.
# 2024-10-17 19:32:33.195 (  12.501s) [main            ]      xdmf_function.cpp:50    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# t and T have been successfully saved as Result_T-s-3-d-112000.0-m-3-15-c-1-e-14875.csv

# %%
from IPython.display import display, Image
display(Image(gif_name))

# %% [markdown]
# # 6: Post process

# %%
from disc_f import *
mesh_min = 3
mesh_max = 15
domain_pad, cell_markers_pad, facet_amrkers_pad,mesh_name_pad,\
mesh_filename1_pad, mesh_filename2_pad = mesh_brake_pad1  ( mesh_min,mesh_max)
# Out:
# The file 'm-3-15-2.msh' exists, start creat now:
# Info    : Reading 'm-3-15-2.msh'...
# Info    : 153 entities
# Info    : 1374 nodes
# Info    : 4226 elements
# Info    : Done reading 'm-3-15-2.msh'
# 2024-10-17 19:32:33.563 (  12.870s) [main            ]         graphbuild.cpp:356   INFO| Build local part of mesh dual graph
# 2024-10-17 19:32:33.567 (  12.874s) [main            ]           ordering.cpp:204   INFO| GPS pseudo-diameter:(83) 3363-3652
# 2024-10-17 19:32:33.567 (  12.874s) [main            ]           Topology.cpp:1330  INFO| Create topology (single cell type)
# 2024-10-17 19:32:33.568 (  12.874s) [main            ]           Topology.cpp:1044  INFO| Create topology (generalised)
# 2024-10-17 19:32:33.568 (  12.875s) [main            ]                MPI.cpp:164   INFO| Computing communication graph edges (using NBX algorithm). Number of input edges: 1
# 2024-10-17 19:32:33.568 (  12.875s) [main            ]                MPI.cpp:235   INFO| Finished graph edge discovery using NBX algorithm. Number of discovered edges 1
# 2024-10-17 19:32:33.569 (  12.876s) [main            ]          partition.cpp:233   INFO| Compute ghost indices
# 2024-10-17 19:32:33.569 (  12.876s) [main            ]                MPI.cpp:97    INFO| Computing communication graph edges (using PCX algorithm). Number of input edges: 0
# 2024-10-17 19:32:33.569 (  12.876s) [main            ]                MPI.cpp:154   INFO| Finished graph edge discovery using PCX algorithm. Number of discovered edges 0
# 2024-10-17 19:32:33.570 (  12.877s) [main            ]                MPI.cpp:164   INFO| Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# 2024-10-17 19:32:33.570 (  12.877s) [main            ]                MPI.cpp:235   INFO| Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# 2024-10-17 19:32:33.571 (  12.878s) [main            ]                MPI.cpp:164   INFO| Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# 2024-10-17 19:32:33.571 (  12.878s) [main            ]                MPI.cpp:235   INFO| Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# 2024-10-17 19:32:33.571 (  12.878s) [main            ]                  MPI.h:377   INFO| Number of neighbourhood source ranks in distribute_to_postoffice: 0
# 2024-10-17 19:32:33.571 (  12.878s) [main            ]                MPI.cpp:164   INFO| Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# 2024-10-17 19:32:33.571 (  12.878s) [main            ]                MPI.cpp:235   INFO| Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# 2024-10-17 19:32:33.571 (  12.878s) [main            ]                  MPI.h:518   INFO| Neighbourhood destination ranks from post office in distribute_data (rank, num dests, num dests/mpi_size): 0, 0, 0
# 2024-10-17 19:32:33.571 (  12.878s) [main            ]      dofmapbuilder.cpp:166   INFO| Checking required entities per dimension
# 2024-10-17 19:32:33.571 (  12.878s) [main            ]      dofmapbuilder.cpp:264   INFO| Cell type:0, dofmap:3974x4
# 2024-10-17 19:32:33.571 (  12.878s) [main            ]      dofmapbuilder.cpp:320   INFO| Global index computation
# 2024-10-17 19:32:33.571 (  12.878s) [main            ]      dofmapbuilder.cpp:637   INFO| Got 1 index_maps
# 2024-10-17 19:32:33.571 (  12.878s) [main            ]      dofmapbuilder.cpp:644   INFO| Get global indices
# 2024-10-17 19:32:33.573 (  12.879s) [main            ]         xdmf_utils.cpp:230   INFO| XDMF distribute entity data
# 2024-10-17 19:32:33.573 (  12.880s) [main            ]                MPI.cpp:164   INFO| Computing communication graph edges (using NBX algorithm). Number of input edges: 1
# 2024-10-17 19:32:33.573 (  12.880s) [main            ]                MPI.cpp:235   INFO| Finished graph edge discovery using NBX algorithm. Number of discovered edges 1
# 2024-10-17 19:32:33.573 (  12.880s) [main            ]                MPI.cpp:164   INFO| Computing communication graph edges (using NBX algorithm). Number of input edges: 1
# 2024-10-17 19:32:33.573 (  12.880s) [main            ]                MPI.cpp:235   INFO| Finished graph edge discovery using NBX algorithm. Number of discovered edges 1
# 2024-10-17 19:32:33.573 (  12.880s) [main            ]         xdmf_utils.cpp:589   INFO| XDMF build map
# 2024-10-17 19:32:33.576 (  12.882s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:33.576 (  12.883s) [main            ]             MeshTags.h:142   INFO| Building MeshTags object from tagged entities (defined by vertices).
# 2024-10-17 19:32:33.576 (  12.883s) [main            ]           Topology.cpp:1433  INFO| Build list of mesh entity indices from the entity vertices.
# 2024-10-17 19:32:33.579 (  12.886s) [main            ]         xdmf_utils.cpp:230   INFO| XDMF distribute entity data
# 2024-10-17 19:32:33.579 (  12.886s) [main            ]                MPI.cpp:164   INFO| Computing communication graph edges (using NBX algorithm). Number of input edges: 1
# 2024-10-17 19:32:33.579 (  12.886s) [main            ]                MPI.cpp:235   INFO| Finished graph edge discovery using NBX algorithm. Number of discovered edges 1
# 2024-10-17 19:32:33.580 (  12.887s) [main            ]                MPI.cpp:164   INFO| Computing communication graph edges (using NBX algorithm). Number of input edges: 1
# 2024-10-17 19:32:33.580 (  12.887s) [main            ]                MPI.cpp:235   INFO| Finished graph edge discovery using NBX algorithm. Number of discovered edges 1
# 2024-10-17 19:32:33.580 (  12.887s) [main            ]         xdmf_utils.cpp:589   INFO| XDMF build map
# 2024-10-17 19:32:33.581 (  12.888s) [main            ]topologycomputation.cpp:748   INFO| Computing mesh entities of dimension 2
# 2024-10-17 19:32:33.582 (  12.889s) [main            ]                MPI.cpp:164   INFO| Computing communication graph edges (using NBX algorithm). Number of input edges: 0
# 2024-10-17 19:32:33.582 (  12.889s) [main            ]                MPI.cpp:235   INFO| Finished graph edge discovery using NBX algorithm. Number of discovered edges 0
# 2024-10-17 19:32:33.583 (  12.890s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:33.583 (  12.890s) [main            ]topologycomputation.cpp:870   INFO| Computing mesh connectivity 2 - 3 from transpose.
# 2024-10-17 19:32:33.583 (  12.890s) [main            ]             MeshTags.h:142   INFO| Building MeshTags object from tagged entities (defined by vertices).
# 2024-10-17 19:32:33.583 (  12.890s) [main            ]           Topology.cpp:1433  INFO| Build list of mesh entity indices from the entity vertices.

# %%
## here domain is the whole brake pad and disc, but we only need for brake pad
VT = fem.functionspace(domain_pad, ("CG", 1))              #define the finite element function space

T_, dT = ufl.TestFunction(VT), ufl.TrialFunction(VT)   # T_ is the test function, like v
Delta_T = fem.Function(VT, name="Temperature_variation")
aT = ufl.dot(ufl.grad(dT), ufl.grad(T_)) * ufl.dx      # a is grad T, grad T_, like grad u, grad v
LT = fem.Constant(domain_pad, 0.0) * T_ * ufl.dx           # L is 0, o*v, v is T_
bc_disc_T = mesh.locate_entities_boundary(domain_pad, fdim, lambda x: np.isclose(x[2], 50))

def contact(x):
    return np.isclose(x[2],50)
    
contact_dofs_T = fem.locate_dofs_geometrical(VT, contact)  
bcT= [ fem.dirichletbc( 64.0, contact_dofs_T, VT )  ]

problem = fem.petsc.LinearProblem(aT, LT, u=Delta_T, bcs=bcT)
problem.solve()
# Out:
# 2024-10-17 19:32:33.601 (  12.907s) [main            ]      dofmapbuilder.cpp:166   INFO| Checking required entities per dimension
# 2024-10-17 19:32:33.601 (  12.907s) [main            ]      dofmapbuilder.cpp:264   INFO| Cell type:0, dofmap:3974x4
# 2024-10-17 19:32:33.601 (  12.908s) [main            ]      dofmapbuilder.cpp:320   INFO| Global index computation
# 2024-10-17 19:32:33.601 (  12.908s) [main            ]      dofmapbuilder.cpp:637   INFO| Got 1 index_maps
# 2024-10-17 19:32:33.601 (  12.908s) [main            ]      dofmapbuilder.cpp:644   INFO| Get global indices
# 2024-10-17 19:32:33.604 (  12.911s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-10-17 19:32:33.604 (  12.911s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-10-17 19:32:33.604 (  12.911s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (2,0)
# 2024-10-17 19:32:33.605 (  12.912s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (0,0) - (3,0)
# 2024-10-17 19:32:33.605 (  12.912s) [main            ]topologycomputation.cpp:870   INFO| Computing mesh connectivity 0 - 3 from transpose.
# 2024-10-17 19:32:33.605 (  12.912s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-10-17 19:32:33.615 (  12.922s) [main            ]    SparsityPattern.cpp:385   INFO| Column ghost size increased from 0 to 0
# Coefficient(FunctionSpace(Mesh(blocked element (Basix element (P, tetrahedron, 1, equispaced, unset, False, float64, []), (3,)), 1), Basix element (P, tetrahedron, 1, gll_warped, unset, False, float64, [])), 5)

# %%
#######try to make domain only for brake pad.

E = fem.Constant(domain_pad, 50e3)             # Elastic module
nu = fem.Constant(domain_pad, 0.2)             # Poission ratio
gdim = domain_pad.geometry.dim

mu = E / 2 / (1 + nu)                      # Shear modulus
lmbda = E * nu / (1 + nu) / (1 - 2 * nu)   # Lame parameters
alpha = fem.Constant(domain_pad, 1e-5)         # Thermal expansion coefficient

f1 = fem.Constant(domain_pad, (0.0, 0.0, 0.0))       # O for external force

def eps(v):                                # epsilon, strain, the deforamtion, dy/y 
    return ufl.sym(ufl.grad(v))

def sigma(v, Delta_T):                     # sigmathis is sigma
    return (lmbda * ufl.tr(eps(v)) - alpha * (3 * lmbda + 2 * mu) * Delta_T 
    ) * ufl.Identity(gdim)  + 2.0 * mu * eps(v)     # here braces is important, can not be in above line

Vu = fem.functionspace(domain_pad, ("CG", 1, (gdim,))) 
du = ufl.TrialFunction(Vu)
u_ = ufl.TestFunction(Vu)

Wint = ufl.inner(sigma(du, Delta_T), eps(u_)) * ufl.dx  # here du is unkown
aM = ufl.lhs(Wint)                                      # Wint is long and lhs can help to distinguish unkown and know.
LM = ufl.rhs(Wint) + ufl.inner(f1, u_) * ufl.dx          # knows parameters are in lhs

def up_side(x):
    return np.logical_or(np.isclose(x[2], 53), np.isclose(x[2], 83))
    
up_dofs_u = fem.locate_dofs_geometrical(Vu, up_side) # lateral sides of domain
bcu = [fem.dirichletbc(np.zeros((gdim,)), up_dofs_u, Vu)]  # displacement Vu is fixed in lateral sides

u = fem.Function(Vu, name="Displacement")
problem = fem.petsc.LinearProblem(aM, LM, u=u, bcs=bcu)
problem.solve()
# Out:
# 2024-10-17 19:34:07.909 ( 107.216s) [main            ]      dofmapbuilder.cpp:166   INFO| Checking required entities per dimension
# 2024-10-17 19:34:07.909 ( 107.216s) [main            ]      dofmapbuilder.cpp:264   INFO| Cell type:0, dofmap:3974x4
# 2024-10-17 19:34:07.909 ( 107.216s) [main            ]      dofmapbuilder.cpp:320   INFO| Global index computation
# 2024-10-17 19:34:07.909 ( 107.216s) [main            ]      dofmapbuilder.cpp:637   INFO| Got 1 index_maps
# 2024-10-17 19:34:07.909 ( 107.216s) [main            ]      dofmapbuilder.cpp:644   INFO| Get global indices

# %%
u_topology, u_cell_types, u_geometry = plot.vtk_mesh(Vu)                # get mesh data
u_grid = pyvista.UnstructuredGrid(u_topology, u_cell_types, u_geometry) # plot grid
u_3D = np.zeros((u_geometry.shape[0], 3))
u_3D[:, :3] = u.x.array.reshape(-1, 3)
u_grid.point_data["Displacement_thermal"] = u_3D
u_grid.set_active_vectors("Displacement_thermal")
warped = u_grid.warp_by_vector("Displacement_thermal", factor=10000000)

plotter = pyvista.Plotter()
plotter.window_size = (800, 300)
plotter.add_mesh(warped)
edges = warped.extract_all_edges()
plotter.add_mesh(edges, color="k", line_width=1, opacity=0.5)
plotter.view_xy()
plotter.camera.elevation = 180  # Rotate the camera around the Y-axis
plotter.camera.roll= 135

plotter.zoom_camera(2)
plotter.show()
# Out:
# <PIL.Image.Image image mode=RGB size=800x300>
