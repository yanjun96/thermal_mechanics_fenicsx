# %% [markdown]
# ## Concise: 1: Start and mesh
# Author: yanjun zhang, Source from book "Abali - 2017 - Computational Reality" P119

# %%
from disc_f1 import *

# mesh-size, contact area coefficient
mesh_min, mesh_max = 3, 20
c_contact          = 1

# Each time step rotation angular, and acc during lag, 1 is full acc, 0 is no acc.
angular_r          = 2240
v_vehicle, c_acc   = 160, 1
z1,z2,z3,z4,z_all  = 20,33,30,83,8
pad_v_tag          = 32

# calling local functions to get all parameters
(dt, P, g, num_steps, h, radiation, v_angular, Ti, Tm, S_rub_circle_ini, t, rho, c, k, t_brake, 
S_total,) = vehicle_initial (angular_r, v_vehicle, c_contact, c_acc)
print("1: Total braking tims is ", round(sum(dt), 2), "s")
print("2: Total numb steps is ", num_steps)

## here use lots of abbreviation, details are in disc_f
domain, cell_markers, facet_markers, mesh_name, mesh_name1, mesh_name2 \
                       = mesh_brake_all(mesh_min,mesh_max,pad_v_tag)

V, T_init, u_n         = initial_u_n(domain, Ti)

fdim, bc, mesh_brake, all_e,xdmf, x_co, y_co, ds, b_con \
                       = mesh_setup( domain, V, mesh_name1, num_steps, \
                         angular_r, mesh_name2, c_contact, z_all, Tm, S_rub_circle_ini)
# Initialize
problem,u,v,f,n_vector = variation_initial(V, T_init, domain, rho, c, b_con,\
                          radiation, h, k, xdmf, dt, ds, u_n, Tm,g,bc);
solver_setup_solve(problem,u)

## Visualization of time dependent problem using pyvista
gif_name    = "T-s-{}-d-{}-{}-c-{}-e-{}.gif".format(num_steps, angular_r, mesh_name2, c_contact, all_e)
plotter, sargs, renderer, warped, viridis, grid = plot_gif(V,u,gif_name)
##solve
num_steps= int(num_steps)
 
###################################################################
x_co_zone   = 0.001

T_array,fraction_c, Vu = solve_heat(Ti, u, num_steps, dt, x_co, y_co, angular_r, \
               t_brake, domain, S_rub_circle_ini, fdim,\
               rho, c, v, radiation, k, h, f, Tm, g,\
               ds, xdmf, b_con, bc, plotter, warped,\
               mesh_name1, mesh_brake, pad_v_tag, z4,\
               z1, x_co_zone, u_n)  #last u should be u_n, here we set u, \
#the same with previous:solver_setup_solve(problem,u)
####################################################################

csv_name    = "Result_T-s-{}-d-{}-{}-c-{}-e-{}.csv".format(num_steps, angular_r, mesh_name2, c_contact, all_e  )
save_t_T(csv_name, T_array) # got the Temperature data

from IPython.display import display, Image
display(Image(gif_name))
# Out:
# DOLFINx version: 0.8.0
# Simulation environment setup complete.
# 1: Total braking tims is  48.05 s
# 2: Total numb steps is  62
# The file 'm-3-20.msh' does not exist, start building:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 4 (Circle)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Circle)
# Info    : [ 10%] Meshing curve 7 (Circle)
# Info    : [ 10%] Meshing curve 8 (Line)
# Info    : [ 10%] Meshing curve 9 (Circle)
# Info    : [ 10%] Meshing curve 10 (Circle)
# Info    : [ 10%] Meshing curve 11 (Line)
# Info    : [ 20%] Meshing curve 12 (Circle)
# Info    : [ 20%] Meshing curve 13 (Line)
# Info    : [ 20%] Meshing curve 14 (Line)
# Info    : [ 20%] Meshing curve 15 (Circle)
# Info    : [ 20%] Meshing curve 16 (Line)
# Info    : [ 20%] Meshing curve 17 (Line)
# Info    : [ 20%] Meshing curve 18 (Line)
# Info    : [ 30%] Meshing curve 19 (Line)
# Info    : [ 30%] Meshing curve 20 (Circle)
# Info    : [ 30%] Meshing curve 21 (Circle)
# Info    : [ 30%] Meshing curve 22 (Circle)
# Info    : [ 30%] Meshing curve 23 (Circle)
# Info    : [ 30%] Meshing curve 24 (Circle)
# Info    : [ 30%] Meshing curve 25 (Circle)
# Info    : [ 40%] Meshing curve 26 (Circle)
# Info    : [ 40%] Meshing curve 27 (Circle)
# Info    : [ 40%] Meshing curve 28 (Circle)
# Info    : [ 40%] Meshing curve 29 (Circle)
# Info    : [ 40%] Meshing curve 30 (Circle)
# Info    : [ 40%] Meshing curve 31 (Circle)
# Info    : [ 40%] Meshing curve 32 (Circle)
# Info    : [ 50%] Meshing curve 33 (Circle)
# Info    : [ 50%] Meshing curve 34 (Circle)
# Info    : [ 50%] Meshing curve 35 (Circle)
# Info    : [ 50%] Meshing curve 36 (Circle)
# Info    : [ 50%] Meshing curve 37 (Circle)
# Info    : [ 50%] Meshing curve 38 (Circle)
# Info    : [ 50%] Meshing curve 39 (Line)
# Info    : [ 50%] Meshing curve 40 (Line)
# Info    : [ 60%] Meshing curve 41 (Circle)
# Info    : [ 60%] Meshing curve 42 (Line)
# Info    : [ 60%] Meshing curve 43 (Circle)
# Info    : [ 60%] Meshing curve 44 (Line)
# Info    : [ 60%] Meshing curve 45 (Circle)
# Info    : [ 60%] Meshing curve 46 (Line)
# Info    : [ 60%] Meshing curve 47 (Circle)
# Info    : [ 70%] Meshing curve 48 (Line)
# Info    : [ 70%] Meshing curve 49 (Circle)
# Info    : [ 70%] Meshing curve 50 (Line)
# Info    : [ 70%] Meshing curve 51 (Circle)
# Info    : [ 70%] Meshing curve 52 (Line)
# Info    : [ 70%] Meshing curve 53 (Circle)
# Info    : [ 70%] Meshing curve 54 (Line)
# Info    : [ 80%] Meshing curve 55 (Circle)
# Info    : [ 80%] Meshing curve 56 (Line)
# Info    : [ 80%] Meshing curve 57 (Circle)
# Info    : [ 80%] Meshing curve 58 (Line)
# Info    : [ 80%] Meshing curve 59 (Circle)
# Info    : [ 80%] Meshing curve 60 (Line)
# Info    : [ 80%] Meshing curve 61 (Circle)
# Info    : [ 90%] Meshing curve 62 (Line)
# Info    : [ 90%] Meshing curve 63 (Circle)
# Info    : [ 90%] Meshing curve 64 (Line)
# Info    : [ 90%] Meshing curve 65 (Circle)
# Info    : [ 90%] Meshing curve 66 (Line)
# Info    : [ 90%] Meshing curve 67 (Circle)
# Info    : [ 90%] Meshing curve 68 (Line)
# Info    : [100%] Meshing curve 69 (Circle)
# Info    : [100%] Meshing curve 70 (Line)
# Info    : [100%] Meshing curve 71 (Circle)
# Info    : [100%] Meshing curve 72 (Line)
# Info    : [100%] Meshing curve 73 (Circle)
# Info    : [100%] Meshing curve 74 (Line)
# Info    : [100%] Meshing curve 75 (Circle)
# Info    : Done meshing 1D (Wall 0.0251177s, CPU 0.010532s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 4 (Cylinder, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 5 (Cylinder, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Warning : Unknown entity of dimension 3 and tag 3 in physical group 31
# Warning : Unknown entity of dimension 3 and tag 3 in physical group 32
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 21
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 1
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 2
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 3
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 4
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 5
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 6
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 7
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 8
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 9
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 10
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 11
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 12
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 13
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 14
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 15
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 16
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 17
# Warning : Unknown entity of dimension 2 and tag 2 in physical group 18
# Info    : [ 10%] Meshing surface 7 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 8 (Cylinder, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 9 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 10 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 11 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 13 (Cylinder, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 14 (Cylinder, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 15 (Cylinder, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 16 (Cylinder, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 17 (Cylinder, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 18 (Cylinder, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 19 (Cylinder, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 20 (Cylinder, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 21 (Cylinder, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 22 (Cylinder, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 23 (Cylinder, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 24 (Cylinder, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 25 (Cylinder, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 26 (Cylinder, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 27 (Cylinder, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 28 (Cylinder, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 29 (Cylinder, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 30 (Cylinder, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 31 (Cylinder, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 32 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 33 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 34 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 35 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 36 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 37 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 38 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 39 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 40 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 41 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 42 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 43 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 44 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 45 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 46 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 47 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 48 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 49 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.260197s, CPU 0.201908s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 2 volumes with 2 connected components
# Info    : Tetrahedrizing 1672 nodes...
# Info    : Done tetrahedrizing 1680 nodes (Wall 0.133758s, CPU 0.050303s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    :  - Added 6 Steiner points
# Info    : Done reconstructing mesh (Wall 0.238901s, CPU 0.104921s)
# Info    : Found volume 1
# Info    : It. 0 - 0 nodes created - worst tet radius 1.18809 (nodes removed 0 0)
# Info    : 3D refinement terminated (2484 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 0 nodes could not be inserted
# Info    :  - 4771 tetrahedra created in 0.00500214 sec. (953791 tets/s)
# Info    : 0 node relocations
# Info    : Tetrahedrizing 792 nodes...
# Info    : Done tetrahedrizing 800 nodes (Wall 0.0244239s, CPU 0.018664s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 0.0469627s, CPU 0.035588s)
# Info    : Found volume 87
# Info    : It. 0 - 0 nodes created - worst tet radius 1.24867 (nodes removed 0 0)
# Info    : 3D refinement terminated (2512 nodes total):
# Info    :  - 0 Delaunay cavities modified for star shapeness
# Info    :  - 1 nodes could not be inserted
# Info    :  - 2338 tetrahedra created in 0.01429 sec. (163610 tets/s)
# Info    : 0 node relocations
# Info    : Done meshing 3D (Wall 0.459739s, CPU 0.271378s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 1
# Info    : Optimization starts (volume = 4.50977e+06) with worst = 0.0222249 / average = 0.736826:
# Info    : 0.00 < quality < 0.10 :        55 elements
# Info    : 0.10 < quality < 0.20 :         2 elements
# Info    : 0.20 < quality < 0.30 :         4 elements
# Info    : 0.30 < quality < 0.40 :        32 elements
# Info    : 0.40 < quality < 0.50 :        52 elements
# Info    : 0.50 < quality < 0.60 :       445 elements
# Info    : 0.60 < quality < 0.70 :       473 elements
# Info    : 0.70 < quality < 0.80 :      1702 elements
# Info    : 0.80 < quality < 0.90 :      1983 elements
# Info    : 0.90 < quality < 1.00 :        23 elements
# Info    : 60 edge swaps, 1 node relocations (volume = 4.50977e+06): worst = 0.0530655 / average = 0.744336 (Wall 0.00126772s, CPU 0s)
# Info    : 62 edge swaps, 1 node relocations (volume = 4.50977e+06): worst = 0.321738 / average = 0.744628 (Wall 0.00150746s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        33 elements
# Info    : 0.40 < quality < 0.50 :        37 elements
# Info    : 0.50 < quality < 0.60 :       490 elements
# Info    : 0.60 < quality < 0.70 :       458 elements
# Info    : 0.70 < quality < 0.80 :      1702 elements
# Info    : 0.80 < quality < 0.90 :      1974 elements
# Info    : 0.90 < quality < 1.00 :        25 elements
# Info    : Optimizing volume 87
# Info    : Optimization starts (volume = 1.85925e+06) with worst = 0.0524804 / average = 0.725029:
# Info    : 0.00 < quality < 0.10 :         9 elements
# Info    : 0.10 < quality < 0.20 :        12 elements
# Info    : 0.20 < quality < 0.30 :        64 elements
# Info    : 0.30 < quality < 0.40 :        67 elements
# Info    : 0.40 < quality < 0.50 :       108 elements
# Info    : 0.50 < quality < 0.60 :       220 elements
# Info    : 0.60 < quality < 0.70 :       390 elements
# Info    : 0.70 < quality < 0.80 :       533 elements
# Info    : 0.80 < quality < 0.90 :       584 elements
# Info    : 0.90 < quality < 1.00 :       351 elements
# Info    : 74 edge swaps, 4 node relocations (volume = 1.85925e+06): worst = 0.132709 / average = 0.743585 (Wall 0.00119004s, CPU 0.001271s)
# Info    : 75 edge swaps, 5 node relocations (volume = 1.85925e+06): worst = 0.132709 / average = 0.743854 (Wall 0.0015843s, CPU 0.001764s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         2 elements
# Info    : 0.20 < quality < 0.30 :         8 elements
# Info    : 0.30 < quality < 0.40 :        77 elements
# Info    : 0.40 < quality < 0.50 :       102 elements
# Info    : 0.50 < quality < 0.60 :       210 elements
# Info    : 0.60 < quality < 0.70 :       376 elements
# Info    : 0.70 < quality < 0.80 :       545 elements
# Info    : 0.80 < quality < 0.90 :       590 elements
# Info    : 0.90 < quality < 1.00 :       360 elements
# Info    : Done optimizing mesh (Wall 0.00622963s, CPU 0.003121s)
# Info    : 2532 nodes 12670 elements
# Info    : Writing 'm-3-20.msh'...
# NOTICE:m-3-20 has been meshed successfully and saved as m-3-20.msh
# Info    : Done writing 'm-3-20.msh'
# DOLFINx version: 0.8.0
# Simulation environment setup complete.
#
# 1: Progress: 98.1%. Use time:             0 hours 4 min. Start: 2024-11-06 15:35:02.
# t and T have been successfully saved as Result_T-s-62-d-2240-m-3-20-c-1-e-8476.csv

# %%
print (max(u.x.array))
# Out:
# 1050.6000394192097

# %%
print((fraction_c))
plt.plot(fraction_c)
#plt.ylim(0.1, 0.99)
# Out:
# [0.9850243953279244, 0.9850243953436459, 0.9850250648990907, 0.5253230029704647, 0.9850244638998984, 0.9850244561210588, 0.8540889666463827, 1.3333355664087423, 0.9850244758068551, 0.985024502829749, 0.9850244827828218, 0.07434865227216986, 0.9854999904106851, 0.9850244614401195, 0.9850244470062556, 0.25787092276978274, 0.9763412644967367, 0.9850237838830768, 0.9850238724264799, 0.9850239085431363, 0.0732837224836091, 0.9852417413441351, 0.9850240540933938, 0.9850240446319789, 0.18625659934825584, 0.9852644269019482, 0.9850230609999912, 0.9850232556967591, 0.9850233825986937, 0.07328370982450123, 0.9852413540294702, 0.9850236920080586, 0.9850237283561856, 0.18625652260271283, 0.985264080133905, 0.9850227648026265, 0.9850229949483681, 0.9850231470692181, 0.07328369936692929, 0.9852411557827012, 0.9850234882062392, 0.9850235203606691, 0.18625647057933226, 0.9852637598101268, 0.9850225044159089, 0.9850227569972015, 0.985022927923401, 0.07328368725640826, 0.9852409617363256, 0.9850232349435436, 0.9850232294562601, 0.186562755724063, 0.9852632716301599, 0.9850221050005112, 0.9850224120985317, 0.9850226407013151, 0.07434860016094977, 0.9852404757688673, 0.9850226770840087, 0.9842590926977468, 0.18622552208351792, 0.9795053429981819]

# %%
################################################################
def solve_heat(Ti, u_initial, num_steps, dt, x_co, y_co, angular_r, \
               t_brake, domain, S_rub_circle, fdim,\
               rho, c, v, radiation, k, h, f, Tm, g,\
               ds, xdmf, b_con, bc, plotter, warped,\
               mesh_name1, mesh_brake, pad_v_tag, z4,\
               z1, x_co_zone, u_n ):
  
    T_array = [(0, [Ti for _ in range(len(u_initial.x.array))])]
    total_degree = 0
    t = 0
    fraction_c = []
    for i in range(num_steps):
        
         t += dt[i]

         ##################################3
         # u_do is the deformation without any contact constrain, no plenaly force, mm.
         if i == 0: 
            u.x.array[:] = np.full(len(u_initial.x.array), 60)       
             
         if i ==0:
            x_co_new = x_co
            y_co_new = y_co
         else:
            pass

         #print(f"{i :},before rotation, x_co is {x_co_new[0]}")
         x_co_new, y_co_new = rub_rotation(x_co_new, y_co_new, angular_r)  # update the location
         #print(f"{i :},after rotation, before transformation, x_co is {x_co_new[0]}")
         total_degree += angular_r  # Incrementing degree in each step  

         
         #if i != 0:
         #   print(i, ': Old one is ', u_pre_solve.x.array)
         #   print(i, ': New one is ',u.x.array)

         if i == 0:
             u_d0, Vu, aM, LM, bcu, u_, domain_pad = T_S_deformation_solve (mesh_name1, u_initial, \
                                                                            mesh_brake, pad_v_tag, z4, u)
         else:
             u_d0, Vu, aM, LM, bcu, u_, domain_pad = T_S_deformation_solve (mesh_name1, u,\
                                                                            mesh_brake, pad_v_tag, z4, u_pre_solve)
         # u_d1 is the new deformation with contact force, mm.
         u_d1 = penalty_method_contact(z1, Vu, u_d0, aM, LM, u_, bcu )
             
         # calculate new contact coordinates and contact incicies of u_d, deformation.
         deformed_co, new_c   = get_new_contact_nodes(x_co_zone, domain_pad, u_d1, Vu, z1, x_co, y_co )
         # find new contact coordinates and rub radius.
         x_co_new1, y_co_new1, r_rub_new, S_total_new, S_rub_circle_new = get_r_xco_yco (deformed_co, new_c )
         x_co_new, y_co_new = rub_rotation(x_co_new1, y_co_new1, angular_r*(i+1))
             
         S_rub_circle = S_rub_circle_new
         fraction_c.append(  S_total_new/ 200 )
         #####################################
        
         # Construct the message     
         end_time = time.time()
         elapsed_time = end_time - start_time
         elapsed_time1 = round(elapsed_time, 0)
         formatted_start_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(start_time))
         if elapsed_time1 >= 60:
            min = elapsed_time1 / 60
            hours = min / 60
            progress_message = f"1: Progress: {round(100 * (t / t_brake), 1)}%. Use time: \
            {round(hours)} hours {round(min)} min. Start: {formatted_start_time }."
         else:
            progress_message = f"1: Progress: {round(100 * (t / t_brake), 1)}%. Use time: \
            {round(elapsed_time1)} s. Start: {formatted_start_time }."
         sys.stdout.write(f"\r{progress_message.ljust(80)}")  # 80 spaces to ensure full clearing
         sys.stdout.flush()
        
         #####################################
         co_ind, fa_mar, so_ind   = target_facets( domain, x_co_new, y_co_new, S_rub_circle )
         facet_tag                = meshtags( domain, fdim, co_ind[ so_ind], fa_mar[ so_ind] )
         ds                       = Measure( "ds", domain=domain, subdomain_data=facet_tag)
         #print(co_ind)     

         F = ((rho * c) / dt[i] * inner(u, v) * dx
             + k * inner(grad(u), grad(v)) * dx
             + h * inner(u, v) * ds(b_con)
             + radiation * inner(u**4, v) * ds(b_con)
             - ( inner(f, v) * dx
                 + (rho * c) / dt[i] * inner(u_n, v) * dx  #!!!!!!!!!!!!   u_n need to double check
                 + h * Tm * v * ds(b_con)
                 + radiation * (Tm**4) * v * ds(b_con)) )

         for j in list(range(1, 19)):
             #F += -k * dot(grad(u) * v, n_vector) * ds(10 * j) - inner(g[i], v) * ds(10 * j)
             F += ( - inner(g[i], v) * ds(10 * j) 
                    - h * inner( u, v) * ds(10 * j)  
                    - radiation * inner( (u**4 - Tm**4), v) * ds(10 * j) )    

         u_pre_solve = u.copy()         

         problem = NonlinearProblem(F, u, bcs=[bc])
         ## 7: Using petsc4py to create a linear solver
         solver_setup_solve(problem, u)
        
         u.x.scatter_forward()            
       
         # Update solution at previous time step (u_n)
         u_n.x.array[:] = u.x.array
         T_array.append((t, u.x.array.copy()))
         # Write solution to file
         xdmf.write_function(u, t)
         # Update plot
         #warped = grid.warp_by_scalar("uh", factor=0)
         plotter.update_coordinates(warped.points.copy(), render=False)
         plotter.update_scalars(u.x.array, render=False)
         plotter.write_frame()      

    plotter.close()
    xdmf.close()
    print()
    return(T_array, fraction_c, Vu)

# %%
scale_factor = 1
plot_s_pad = plot_S_pad(Vu, u_d, scale_factor)
plot_s_pad.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 scale_factor = 1
# ----> 2 plot_s_pad = plot_S_pad(Vu, u_d, scale_factor)
#       3 plot_s_pad.show()
#
# NameError: name 'u_d' is not defined

# %% [markdown]
# # 2: New brake pad points, add boundary for rubbing elements

# %% [markdown]
# u_d, Vu, aM, LM, bcu, u_,  domain_pad   = T_S_deformation_solve (mesh_name1, u_n, mesh_brake, pad_v_tag, z4, u_old )
# u_d = penalty_method_contact(z1, Vu, u_d, aM, LM, u_, bcu )
# x_co_zone   = 0.002
# deformed_co, new_c = get_new_contact_nodes(x_co_zone, domain_pad, u_d,  Vu, z1, x_co, y_co )
# x_co_new, y_co_new, r_rub_new, S_total_new,S_rub_circle_new = get_r_xco_yco (deformed_co, new_c )
# fraction_c = S_total_new/ 200
#
#
# print('Total contact surface is: ', round(S_total_new, 2), " mm")
# print(f"Contact friction is {fraction_c:.2f}")
#
#
# scale_factor = 1
# plot_s_pad = plot_S_pad(Vu, u_d, scale_factor)
# plot_s_pad.show()
#
# vtk = io.VTKFile(domain_pad.comm, "pad_deformation", "w")
# vtk.write_function(u_d)
# vtk.close()

# %%
print(dx.ufl_domain)
