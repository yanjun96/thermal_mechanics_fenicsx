# %% [markdown]
# Author: yanjun zhang
# ## Concise
# ## 1: Start
#
# Source from book "Abali - 2017 - Computational Reality" P119
#
# import dolfinx
# print(f"DOLFINx version: {dolfinx.__version__}   \
# based on GIT commit:  \
# {dolfinx.git_commit_hash} of https://github.com/FEniCS/dolfinx/")

# %%
import dolfinx
print(f"DOLFINx version: {dolfinx.__version__}")
# Out:
# DOLFINx version: 0.8.0

# %%
# import basic
import pyvista
import ufl
import dolfinx
import time
import sys
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt

# import speciail library
from dolfinx.fem.petsc import (
    LinearProblem,
    assemble_vector,
    assemble_matrix,
    create_vector,
    apply_lifting,
    set_bc,
)
from dolfinx import fem, mesh, io, plot, default_scalar_type, nls, log
from dolfinx.fem import (
    Constant,
    dirichletbc,
    Function,
    FunctionSpace,
    form,
    locate_dofs_topological,
)
from dolfinx.io import XDMFFile, gmshio
from dolfinx.mesh import locate_entities, locate_entities_boundary, meshtags
from ufl import (
    SpatialCoordinate,
    TestFunction,
    TrialFunction,
    dx,
    grad,
    inner,
    Measure,
    dot,
    FacetNormal,
)
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.nls.petsc import NewtonSolver
from petsc4py import PETSc
from mpi4py import MPI

# import own functions
from brake_disc_functions import *

# calculate how long time the simulation it is
start_time = time.time()

# mesh-size, contact area coefficient
mesh_min = 1
mesh_max = 10
c_contact = 1

# Each time step rotation angular, and acc during lag, 1 is full acc, 0 is no acc.
angular_r = 112
v_vehicle = 160
c_acc = 1

# calling local functions to get all parameters
(
    dt,
    P,
    g,
    num_steps,
    h,
    radiation,
    v_angular,
    Ti,
    Tm,
    S_rub_circle,
    t,
    rho,
    c,
    k,
    t_brake,
    S_total,
) = vehicle_initial(angular_r, v_vehicle, c_contact, c_acc)

print("1: Total tims is ", round(sum(dt), 2), "s")
print("2: Total numb steps is ", num_steps)
plt.plot(P)
# Out:
# 1: Total tims is  48.6 s
# 2: Total numb steps is  1213

# %%
print(h,k,radiation,)
# Out:
# 7.75e-05 0.048 3.6287999999999996e-13

# %% [markdown]
# ## 2: Mesh

# %%
######################################  mesh  ###################################3
mesh_name = f"{mesh_min}-{mesh_max}"
mesh_filename1 = "m-{}.msh".format(mesh_name)
mesh_filename2 = "m-{}".format(mesh_name)

if os.path.exists(mesh_filename1):
    # Run this command if the file exists
    print(f"The file '{mesh_filename1}' exists, start creat now:")
    domain, cell_markers, facet_markers = gmshio.read_from_msh(
        mesh_filename1, MPI.COMM_WORLD, 0, gdim=3
    )

else:
    # Run this command if the file does not exist
    print(f"The file '{mesh_filename1}' does not exist, start building:")
    mesh_brake_disc(mesh_min, mesh_max, mesh_filename2)
    domain, cell_markers, facet_markers = gmshio.read_from_msh(
        mesh_filename1, MPI.COMM_WORLD, 0, gdim=3
    )

# Define variational problem, CG is Lagrabge
V = fem.functionspace(domain, ("CG", 1))


# initialization
def project(function, space):
    u = TrialFunction(space)
    v = TestFunction(space)
    a = inner(u, v) * dx
    L = inner(function, v) * dx
    problem = LinearProblem(a, L, bcs=[])
    return problem.solve()


# u_n is for initial condition and uh is the solver result.
# variable, need to be projected form Q onto V, DG is discontinuous Lagrange
Q = fem.functionspace(domain, ("DG", 0))
T_init = Function(Q)
T_init.name = "u_n"
T_init.x.array[:] = np.full_like(1, Ti, dtype=default_scalar_type)
u_n = project(T_init, V)
u_n.name = "u_n"

fdim = domain.topology.dim - 1
## bc_disc is zero, no any dirichlete boundary condition
bc_disc = mesh.locate_entities_boundary(domain, fdim, lambda x: np.isclose(x[2], 50))
bc = fem.dirichletbc(
    PETSc.ScalarType(Tm), fem.locate_dofs_topological(V, fdim, bc_disc), V
)
np.set_printoptions(threshold=np.inf)

import meshio

mesh1 = meshio.read(mesh_filename1)
total_elements = sum(len(cells.data) for cells in mesh1.cells)
# Out:
# The file 'm-1-10.msh' exists, start creat now:
# Info    : Reading 'm-1-10.msh'...
# Info    : 168 entities
# Info    : 10751 nodes
# Info    : 43603 elements
# Info    : Done reading 'm-1-10.msh'

# %% [markdown]
# ## 3: Setup

# %%
# create xdmf file, for paraview
xdmf_name = "T-s-{}-d-{}-{}-c-{}-e-{}.xdmf".format(
    num_steps, angular_r, mesh_filename2, c_contact, total_elements
)
h5_name = "T-s-{}-d-{}-{}-c-{}-e-{}.h5".format(
    num_steps, angular_r, mesh_filename2, c_contact, total_elements
)
xdmf = io.XDMFFile(domain.comm, xdmf_name, "w")
xdmf.write_mesh(domain)

# Create boundary condition
x_co, y_co = get_rub_coordinate()

common_indices3, facet_markers3, sorted_indices3 = target_facets(
    domain, x_co, y_co, S_rub_circle
)

facet_tag = meshtags(
    domain, fdim, common_indices3[sorted_indices3], facet_markers3[sorted_indices3]
)
ds = Measure("ds", domain=domain, subdomain_data=facet_tag)

# %% [markdown]
# ## 4: Variational equation

# %%
uh = fem.Function(V)
uh.name = "uh"
uh = project(T_init, V)
t = 0
xdmf.write_function(uh, t)

# u = trial function, solution what we want to know
u = fem.Function(V)

v = ufl.TestFunction(V)
f = fem.Constant(domain, PETSc.ScalarType(0))
n_vector = FacetNormal(domain)

F = (
    (rho * c) / dt[0] * inner(u, v) * dx
    + k * inner(grad(u), grad(v)) * dx
    + h * inner(u, v) * ds(200)
    + radiation * inner(u**4, v) * ds(200)
    - (
        inner(f, v) * dx
        + (rho * c) / dt[0] * inner(u_n, v) * dx
        + h * Tm * v * ds(200)
        + radiation * (Tm**4) * v * ds(200)
    )
)


for i in list(range(1, 19)):
    # before 2024/5/16
    #F += -k * dot(grad(u) * v, n_vector) * ds(10 * i) - inner(g[0], v) * ds(10 * i)
    ## new start 2024/5/16, friction points do not have convection heat + heat input
    F += ( 
          + inner(g[0], v) * ds(10 * i) 
          - h * inner( u, v) * ds(10 * i)  
          - radiation * inner( (u**4 - Tm**4), v) * ds(10 * i) 
         )

problem = NonlinearProblem(F, u, bcs=[bc])

## 7: Using petsc4py to create a linear solver
solver = NewtonSolver(MPI.COMM_WORLD, problem)
solver.convergence_criterion = "incremental"
solver.rtol = 1e-6
solver.report = True

ksp = solver.krylov_solver
opts = PETSc.Options()
option_prefix = ksp.getOptionsPrefix()
opts[f"{option_prefix}ksp_type"] = "cg"
opts[f"{option_prefix}pc_type"] = "gamg"
opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
ksp.setFromOptions()

log.set_log_level(log.LogLevel.INFO)
n, converged = solver.solve(u)
assert converged


## 8:Visualization of time dependent problem using pyvista
import matplotlib as mpl

pyvista.start_xvfb()
grid = pyvista.UnstructuredGrid(*plot.vtk_mesh(V))
plotter = pyvista.Plotter()

gif_name = "T-s-{}-d-{}-{}-c-{}-e-{}.gif".format(
    num_steps, angular_r, mesh_filename2, c_contact, total_elements)

plotter.open_gif(gif_name, fps=30)
grid.point_data["Temperature"] = u.x.array
warped = grid.warp_by_scalar("Temperature", factor=0)
viridis = mpl.colormaps.get_cmap("viridis").resampled(25)
sargs = dict(
    title_font_size=25,
    label_font_size=20,
    color="black",
    position_x=0.1,
    position_y=0.8,
    width=0.8,
    height=0.1,
)
renderer = plotter.add_mesh(
    warped,
    show_edges=True,
    lighting=False,
    cmap=viridis,
    scalar_bar_args=sargs,
    # clim=[0, max(uh.x.array)])
    clim=[0, 200],
)
# Out:
# 2024-07-06 20:10:40.963 (   2.069s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:41.112 (   2.219s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:41.153 (   2.260s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 2: r (abs) = 0.0266938 (tol = 1e-10) r (rel) = 4.29075e-06(tol = 1e-06)
# 2024-07-06 20:10:41.210 (   2.317s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:41.250 (   2.357s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 3: r (abs) = 1.23867e-07 (tol = 1e-10) r (rel) = 1.99103e-11(tol = 1e-06)
# 2024-07-06 20:10:41.250 (   2.357s) [main            ]       NewtonSolver.cpp:252   INFO| Newton solver finished in 3 iterations and 14 linear solver iterations.

# %% [markdown]
# ## 5: Solution

# %%
T_array = [(0, [Ti for _ in range(len(u.x.array))])]
total_degree = 0

for i in range(num_steps):
    t += dt[i]

    x_co, y_co = rub_rotation(x_co, y_co, angular_r)  # update the location
    total_degree += angular_r  # Incrementing degree by 10 in each step

    sys.stdout.write("\r1: Rotation has applied for {} degree. ".format(total_degree))
    sys.stdout.write("2: Current time is " + str(round(t, 1)) + " s. ")
    sys.stdout.write("3: Completion is " + str(round(100 * (t / t_brake), 1)) + " %. ")
    sys.stdout.flush()

    common_indices3, facet_markers3, sorted_indices3 = target_facets(
        domain, x_co, y_co, S_rub_circle
    )
    facet_tag = meshtags(
        domain, fdim, common_indices3[sorted_indices3], facet_markers3[sorted_indices3]
    )
    ds = Measure("ds", domain=domain, subdomain_data=facet_tag)

    F = (
        (rho * c) / dt[i] * inner(u, v) * dx
        + k * inner(grad(u), grad(v)) * dx
        + h * inner(u, v) * ds(200)
        + radiation * inner(u**4, v) * ds(200)
        - (
            inner(f, v) * dx
            + (rho * c) / dt[i] * inner(u_n, v) * dx
            + h * Tm * v * ds(200)
            + radiation * (Tm**4) * v * ds(200)
        )
    )

    for j in list(range(1, 19)):
        #F += -k * dot(grad(u) * v, n_vector) * ds(10 * j) - inner(g[i], v) * ds(10 * j)
        F += ( 
          - inner(g[i], v) * ds(10 * j) 
          - h * inner( u, v) * ds(10 * j)  
          - radiation * inner( (u**4 - Tm**4), v) * ds(10 * j) 
         )

        

    problem = NonlinearProblem(F, u, bcs=[bc])

    ## 7: Using petsc4py to create a linear solver
    solver = NewtonSolver(MPI.COMM_WORLD, problem)
    solver.convergence_criterion = "incremental"
    solver.rtol = 1e-6

    ksp = solver.krylov_solver
    opts = PETSc.Options()
    option_prefix = ksp.getOptionsPrefix()
    opts[f"{option_prefix}ksp_type"] = "cg"
    opts[f"{option_prefix}pc_type"] = "gamg"
    opts[f"{option_prefix}pc_factor_mat_solver_type"] = "mumps"
    ksp.setFromOptions()

    sys.stdout.write("1: Completion is " + str(round(100 * (t / t_brake), 1)) + " %. ")
    sys.stdout.flush()

    solver.solve(u)
    u.x.scatter_forward()

    # Update solution at previous time step (u_n)
    u_n.x.array[:] = u.x.array

    T_array.append((t, u.x.array.copy()))
    # Write solution to file
    xdmf.write_function(u, t)
    # Update plot
    # warped = grid.warp_by_scalar("uh", factor=0)
    plotter.update_coordinates(warped.points.copy(), render=False)
    plotter.update_scalars(u.x.array, render=False)
    plotter.write_frame()

plotter.close()
xdmf.close()
print()

csv_name = "Result_T-s-{}-d-{}-{}-c-{}-e-{}.csv".format(
    num_steps, angular_r, mesh_filename2, c_contact, total_elements
)
save_t_T(csv_name, T_array)
# Out:
# 1: Rotation has applied for 112 degree. 2: Current time is 0.0 s. 3: Completion is 0.0 %. 1: Completion is 0.0 %.
# 2024-07-06 20:10:44.483 (   5.590s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.485 (   5.592s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.485 (   5.592s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.485 (   5.592s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.486 (   5.592s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.486 (   5.592s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.486 (   5.593s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.486 (   5.593s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.486 (   5.593s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.487 (   5.593s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.487 (   5.594s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.487 (   5.594s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.487 (   5.594s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.488 (   5.595s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.488 (   5.595s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.488 (   5.595s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.489 (   5.595s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.489 (   5.595s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.489 (   5.596s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.489 (   5.596s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.489 (   5.596s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.490 (   5.596s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.490 (   5.597s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.490 (   5.597s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.490 (   5.597s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.491 (   5.597s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.491 (   5.598s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.491 (   5.598s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.492 (   5.598s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.492 (   5.598s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.492 (   5.599s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.493 (   5.600s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.493 (   5.600s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.493 (   5.600s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.494 (   5.601s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.494 (   5.601s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.494 (   5.601s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.495 (   5.601s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.495 (   5.601s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.495 (   5.602s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.495 (   5.602s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.495 (   5.602s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.496 (   5.603s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.496 (   5.603s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.496 (   5.603s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.497 (   5.603s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.497 (   5.604s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.497 (   5.604s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.497 (   5.604s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.498 (   5.604s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.498 (   5.604s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.498 (   5.605s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.498 (   5.605s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.498 (   5.605s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.499 (   5.606s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:44.499 (   5.606s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.499 (   5.606s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (2,0)
# 2024-07-06 20:10:44.503 (   5.610s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (0,0) - (3,0)
# 2024-07-06 20:10:44.503 (   5.610s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.506 (   5.613s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.507 (   5.613s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:44.507 (   5.613s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:44.571 (   5.678s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:44.571 (   5.678s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:44.574 (   5.681s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:44.574 (   5.681s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:44.592 (   5.699s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:44.592 (   5.699s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:44.594 (   5.701s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:44.594 (   5.701s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:44.602 (   5.709s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:44.638 (   5.745s) [main            ]    SparsityPattern.cpp:385   INFO| Column ghost size increased from 0 to 0
# 2024-07-06 20:10:44.694 (   5.801s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:44.851 (   5.958s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:44.893 (   6.000s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 2: r (abs) = 1.04931e-06 (tol = 1e-10) r (rel) = 4.96108e-06(tol = 1e-06)
# 2024-07-06 20:10:44.953 (   6.060s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:44.995 (   6.102s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 3: r (abs) = 7.57613e-12 (tol = 1e-10) r (rel) = 3.58196e-11(tol = 1e-06)
# 2024-07-06 20:10:44.995 (   6.102s) [main            ]       NewtonSolver.cpp:252   INFO| Newton solver finished in 3 iterations and 15 linear solver iterations.
# 2024-07-06 20:10:44.996 (   6.103s) [main            ]      xdmf_function.cpp:50    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 1: Rotation has applied for 224 degree. 2: Current time is 0.0 s. 3: Completion is 0.1 %.
# 2024-07-06 20:10:45.869 (   6.976s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.870 (   6.976s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.870 (   6.976s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.870 (   6.977s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.871 (   6.978s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.871 (   6.978s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.871 (   6.978s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.872 (   6.979s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.872 (   6.979s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.872 (   6.979s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.873 (   6.980s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.873 (   6.980s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.873 (   6.980s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.874 (   6.980s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.874 (   6.980s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.874 (   6.981s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.874 (   6.981s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.874 (   6.981s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.874 (   6.981s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.875 (   6.982s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.875 (   6.982s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.875 (   6.982s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.876 (   6.982s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.876 (   6.982s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.876 (   6.983s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.877 (   6.984s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.877 (   6.984s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.877 (   6.984s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.878 (   6.985s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.878 (   6.985s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.878 (   6.985s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.879 (   6.985s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.879 (   6.985s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.879 (   6.986s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.879 (   6.986s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.879 (   6.986s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.879 (   6.986s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.880 (   6.987s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.880 (   6.987s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.880 (   6.987s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.881 (   6.987s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.881 (   6.987s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.881 (   6.988s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.881 (   6.988s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.881 (   6.988s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.881 (   6.988s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.882 (   6.989s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.882 (   6.989s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.882 (   6.989s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.882 (   6.989s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.882 (   6.989s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.883 (   6.990s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.883 (   6.990s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.883 (   6.990s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.884 (   6.990s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:45.884 (   6.991s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:45.884 (   6.991s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (2,0)
# 2024-07-06 20:10:45.888 (   6.994s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (0,0) - (3,0)
# 2024-07-06 20:10:45.888 (   6.994s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.891 (   6.998s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.892 (   6.999s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:45.892 (   6.999s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:47.620 (   8.727s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:47.620 (   8.727s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:47.623 (   8.730s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:47.623 (   8.730s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 1: Completion is 0.1 %.
# 2024-07-06 20:10:49.082 (  10.189s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:49.082 (  10.189s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:49.085 (  10.192s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:49.085 (  10.192s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:49.093 (  10.200s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:49.125 (  10.232s) [main            ]    SparsityPattern.cpp:385   INFO| Column ghost size increased from 0 to 0
# 2024-07-06 20:10:49.183 (  10.290s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:49.338 (  10.445s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:49.380 (  10.487s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 2: r (abs) = 3.11044e-06 (tol = 1e-10) r (rel) = 5.28479e-06(tol = 1e-06)
# 2024-07-06 20:10:49.439 (  10.545s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:49.480 (  10.587s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 3: r (abs) = 2.03803e-11 (tol = 1e-10) r (rel) = 3.46273e-11(tol = 1e-06)
# 2024-07-06 20:10:49.480 (  10.587s) [main            ]       NewtonSolver.cpp:252   INFO| Newton solver finished in 3 iterations and 15 linear solver iterations.
# 2024-07-06 20:10:49.480 (  10.587s) [main            ]      xdmf_function.cpp:50    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 1: Rotation has applied for 336 degree. 2: Current time is 0.1 s. 3: Completion is 0.1 %.
# 2024-07-06 20:10:49.627 (  10.733s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.627 (  10.734s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.627 (  10.734s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.628 (  10.735s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.628 (  10.735s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.628 (  10.735s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.628 (  10.735s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.629 (  10.736s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.629 (  10.736s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.629 (  10.736s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.630 (  10.736s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.630 (  10.736s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.630 (  10.737s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.630 (  10.737s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.630 (  10.737s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.631 (  10.737s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.631 (  10.738s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.631 (  10.738s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.631 (  10.738s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.632 (  10.738s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.632 (  10.738s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.632 (  10.739s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.632 (  10.739s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.632 (  10.739s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.632 (  10.739s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.633 (  10.740s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.633 (  10.740s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.633 (  10.740s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.633 (  10.740s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.633 (  10.740s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.634 (  10.741s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.634 (  10.741s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.634 (  10.741s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.634 (  10.741s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.635 (  10.742s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.635 (  10.742s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.635 (  10.742s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.635 (  10.742s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.635 (  10.742s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.636 (  10.743s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.636 (  10.743s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.636 (  10.743s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.636 (  10.743s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.637 (  10.744s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.637 (  10.744s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.637 (  10.744s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.638 (  10.744s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.638 (  10.744s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.638 (  10.745s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.638 (  10.745s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.638 (  10.745s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.638 (  10.745s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.639 (  10.746s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.639 (  10.746s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.639 (  10.746s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:49.640 (  10.747s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:49.640 (  10.747s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (2,0)
# 2024-07-06 20:10:49.643 (  10.750s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (0,0) - (3,0)
# 2024-07-06 20:10:49.643 (  10.750s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.647 (  10.754s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.647 (  10.754s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:49.647 (  10.754s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:51.154 (  12.260s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:51.154 (  12.260s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:51.156 (  12.263s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:51.156 (  12.263s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 1: Completion is 0.1 %.
# 2024-07-06 20:10:52.532 (  13.639s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:52.532 (  13.639s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:52.534 (  13.641s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:52.534 (  13.641s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:52.539 (  13.646s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:52.560 (  13.667s) [main            ]    SparsityPattern.cpp:385   INFO| Column ghost size increased from 0 to 0
# 2024-07-06 20:10:52.600 (  13.707s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 1: Rotation has applied for 448 degree. 2: Current time is 0.1 s. 3: Completion is 0.2 %.
# 2024-07-06 20:10:52.772 (  13.879s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:52.823 (  13.930s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 2: r (abs) = 8.24702e-06 (tol = 1e-10) r (rel) = 4.81591e-06(tol = 1e-06)
# 2024-07-06 20:10:52.859 (  13.966s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:52.899 (  14.006s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 3: r (abs) = 6.1941e-11 (tol = 1e-10) r (rel) = 3.61709e-11(tol = 1e-06)
# 2024-07-06 20:10:52.899 (  14.006s) [main            ]       NewtonSolver.cpp:252   INFO| Newton solver finished in 3 iterations and 15 linear solver iterations.
# 2024-07-06 20:10:52.899 (  14.006s) [main            ]      xdmf_function.cpp:50    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 2024-07-06 20:10:53.004 (  14.111s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.004 (  14.111s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.004 (  14.111s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.005 (  14.111s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.005 (  14.112s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.005 (  14.112s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.005 (  14.112s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.006 (  14.112s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.006 (  14.112s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.006 (  14.113s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.006 (  14.113s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.006 (  14.113s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.006 (  14.113s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.007 (  14.114s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.007 (  14.114s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.007 (  14.114s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.007 (  14.114s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.007 (  14.114s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.008 (  14.114s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.008 (  14.115s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.008 (  14.115s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.008 (  14.115s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.009 (  14.115s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.009 (  14.115s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.009 (  14.116s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.009 (  14.116s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.009 (  14.116s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.009 (  14.116s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.010 (  14.116s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.010 (  14.116s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.010 (  14.117s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.010 (  14.117s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.010 (  14.117s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.010 (  14.117s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.011 (  14.117s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.011 (  14.117s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.011 (  14.118s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.011 (  14.118s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.011 (  14.118s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.011 (  14.118s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.012 (  14.118s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.012 (  14.118s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.012 (  14.119s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.012 (  14.119s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.012 (  14.119s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.012 (  14.119s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.013 (  14.120s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.013 (  14.120s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.013 (  14.120s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.013 (  14.120s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.013 (  14.120s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.014 (  14.120s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.014 (  14.121s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.014 (  14.121s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.014 (  14.121s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:53.015 (  14.121s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.015 (  14.121s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (2,0)
# 2024-07-06 20:10:53.017 (  14.123s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (0,0) - (3,0)
# 2024-07-06 20:10:53.017 (  14.123s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.019 (  14.125s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.019 (  14.126s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:53.019 (  14.126s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:53.752 (  14.859s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:53.752 (  14.859s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:53.754 (  14.861s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:53.754 (  14.861s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 1: Completion is 0.2 %.
# 2024-07-06 20:10:54.541 (  15.648s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:54.541 (  15.648s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:54.544 (  15.651s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:54.544 (  15.651s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:10:54.548 (  15.654s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:10:54.563 (  15.670s) [main            ]    SparsityPattern.cpp:385   INFO| Column ghost size increased from 0 to 0
# 2024-07-06 20:10:54.592 (  15.699s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:54.668 (  15.775s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:54.690 (  15.797s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 2: r (abs) = 8.70271e-06 (tol = 1e-10) r (rel) = 5.41921e-06(tol = 1e-06)
# 2024-07-06 20:10:54.719 (  15.826s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:10:54.740 (  15.847s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 3: r (abs) = 5.75872e-11 (tol = 1e-10) r (rel) = 3.58597e-11(tol = 1e-06)
# 2024-07-06 20:10:54.740 (  15.847s) [main            ]       NewtonSolver.cpp:252   INFO| Newton solver finished in 3 iterations and 15 linear solver iterations.
# 2024-07-06 20:10:54.740 (  15.847s) [main            ]      xdmf_function.cpp:50    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 1: Rotation has applied for 560 degree. 2: Current time is 0.1 s. 3: Completion is 0.2 %.
# 2024-07-06 20:10:54.834 (  15.941s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.834 (  15.941s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.834 (  15.941s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.835 (  15.941s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.835 (  15.942s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.835 (  15.942s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.835 (  15.942s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.835 (  15.942s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.835 (  15.942s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.836 (  15.943s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.836 (  15.943s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.836 (  15.943s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.836 (  15.943s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.837 (  15.943s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.837 (  15.943s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.837 (  15.944s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.837 (  15.944s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.837 (  15.944s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.837 (  15.944s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.838 (  15.944s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.838 (  15.944s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.838 (  15.945s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.838 (  15.945s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.838 (  15.945s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.838 (  15.945s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.839 (  15.945s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.839 (  15.945s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.839 (  15.946s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.839 (  15.946s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.839 (  15.946s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.839 (  15.946s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.840 (  15.947s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.840 (  15.947s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.840 (  15.947s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.840 (  15.947s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.840 (  15.947s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.840 (  15.947s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.841 (  15.948s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.841 (  15.948s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.841 (  15.948s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.841 (  15.948s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.841 (  15.948s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.842 (  15.948s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.842 (  15.949s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.842 (  15.949s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.842 (  15.949s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.842 (  15.949s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:10:54.842 (  15.949s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:10:54.843 (  15.950s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# ...
# 2024-07-06 20:11:05.780 (  26.887s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.780 (  26.887s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.780 (  26.887s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.780 (  26.887s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.780 (  26.887s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.781 (  26.888s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.781 (  26.888s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.781 (  26.888s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.781 (  26.888s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.781 (  26.888s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.781 (  26.888s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.782 (  26.889s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.782 (  26.889s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.782 (  26.889s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.782 (  26.889s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.782 (  26.889s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.783 (  26.889s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.783 (  26.890s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.783 (  26.890s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.783 (  26.890s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.783 (  26.890s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.783 (  26.890s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.784 (  26.890s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.784 (  26.891s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.784 (  26.891s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.784 (  26.891s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.784 (  26.891s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.784 (  26.891s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.785 (  26.891s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.785 (  26.892s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.785 (  26.892s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.785 (  26.892s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:11:05.786 (  26.892s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:05.786 (  26.892s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (2,0)
# 2024-07-06 20:11:05.787 (  26.894s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (0,0) - (3,0)
# 2024-07-06 20:11:05.787 (  26.894s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.789 (  26.895s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.789 (  26.896s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:05.789 (  26.896s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:06.507 (  27.614s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:11:06.507 (  27.614s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:11:06.509 (  27.615s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:11:06.509 (  27.615s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 1: Completion is 0.5 %.
# 2024-07-06 20:11:07.304 (  28.410s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:11:07.304 (  28.410s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:11:07.305 (  28.412s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:11:07.305 (  28.412s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:11:07.309 (  28.416s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:11:07.326 (  28.433s) [main            ]    SparsityPattern.cpp:385   INFO| Column ghost size increased from 0 to 0
# 2024-07-06 20:11:07.356 (  28.463s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:11:07.433 (  28.539s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:11:07.454 (  28.560s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 2: r (abs) = 2.77846e-05 (tol = 1e-10) r (rel) = 5.41076e-06(tol = 1e-06)
# 2024-07-06 20:11:07.483 (  28.590s) [main            ]              petsc.cpp:700   INFO| PETSc Krylov solver starting to solve system.
# 2024-07-06 20:11:07.504 (  28.610s) [main            ]       NewtonSolver.cpp:38    INFO| Newton iteration 3: r (abs) = 1.80851e-10 (tol = 1e-10) r (rel) = 3.52189e-11(tol = 1e-06)
# 2024-07-06 20:11:07.504 (  28.610s) [main            ]       NewtonSolver.cpp:252   INFO| Newton solver finished in 3 iterations and 15 linear solver iterations.
# 2024-07-06 20:11:07.504 (  28.611s) [main            ]      xdmf_function.cpp:50    INFO| Adding function to node "/Xdmf/Domain/Grid/Grid"
# 1: Rotation has applied for 1344 degree. 2: Current time is 0.2 s. 3: Completion is 0.5 %.
# 2024-07-06 20:11:07.592 (  28.699s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.593 (  28.700s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.593 (  28.700s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.593 (  28.700s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.593 (  28.700s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.593 (  28.700s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.594 (  28.701s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.594 (  28.701s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.594 (  28.701s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.594 (  28.701s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.594 (  28.701s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.594 (  28.701s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.595 (  28.701s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.595 (  28.702s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.595 (  28.702s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.595 (  28.702s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.595 (  28.702s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.595 (  28.702s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.595 (  28.702s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.596 (  28.703s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.596 (  28.703s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.596 (  28.703s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.596 (  28.703s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.596 (  28.703s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.597 (  28.704s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.597 (  28.704s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.597 (  28.704s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.597 (  28.704s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.598 (  28.704s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.598 (  28.704s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.598 (  28.705s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.598 (  28.705s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.598 (  28.705s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.598 (  28.705s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.599 (  28.705s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.599 (  28.705s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.599 (  28.706s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.599 (  28.706s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.599 (  28.706s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.599 (  28.706s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.600 (  28.707s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.600 (  28.707s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.600 (  28.707s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.600 (  28.707s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.600 (  28.707s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.600 (  28.707s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.601 (  28.708s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.601 (  28.708s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.601 (  28.708s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.601 (  28.708s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.601 (  28.708s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.601 (  28.708s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.602 (  28.709s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.602 (  28.709s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.602 (  28.709s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:11:07.602 (  28.709s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:07.602 (  28.709s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (2,0)
# 2024-07-06 20:11:07.604 (  28.711s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (0,0) - (3,0)
# 2024-07-06 20:11:07.604 (  28.711s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.606 (  28.713s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.606 (  28.713s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (0,0)
# 2024-07-06 20:11:07.606 (  28.713s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (0,0)
# 2024-07-06 20:11:08.326 (  29.433s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:11:08.326 (  29.433s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)
# 2024-07-06 20:11:08.327 (  29.434s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (2,0) - (3,0)
# 2024-07-06 20:11:08.327 (  29.434s) [main            ]topologycomputation.cpp:799   INFO| Requesting connectivity (3,0) - (2,0)

# %% [markdown]
# # 6: Post process

# %%
# Display the GIF
from IPython.display import display, Image

display(Image(gif_name))

end_time = time.time()
elapsed_time = end_time - start_time
elapsed_time1 = round(elapsed_time, 0)

formatted_start_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(start_time))
formatted_end_time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(end_time))
txt_name = "T-s-{}-d-{}-{}-c-{}-e-{}.txt".format(
    num_steps, angular_r, mesh_filename2, c_contact, total_elements
)
with open(txt_name, "w") as file:
     file.write("1: Start at: {}\n".format(formatted_start_time))
     file.write("2: End at: {}\n".format(formatted_end_time))
    
     if elapsed_time1 >= 60:
        min = elapsed_time1 / 60
        hours = min / 60
        file.write("3: Simulation time is {} hours {} minutes\n".format(round(hours), round(min)))
     else:
        file.write("3: Simulation time is {} second\n".format(elapsed_time1))
    
     file.write("4: First time step dt is {} s\n".format(round(dt[0], 5)))
     r_disc = 0.25
    
     file.write("5: Convection heat transfer coefficient is {} W/mm2 K\n".format(h))
     file.write("6: Radiation is {} W/mm2 K-4\n".format(round(radiation, 14)))
     file.write("7: Each rotation degree is {} per time step or {} circle\n".format(round(angular_r, 1), round(angular_r / 360, 1)))
     file.write("8: The first rotation degree is {}\n".format(round(v_angular[0] * r_disc * dt[0] * 1000, 1)))
     file.write("9: The mid rotation degree is {}\n".format(round(v_angular[round(num_steps / 2)] * r_disc * dt[round(len(dt) / 2)] * 1000, 1)))
     file.write("10: The last rotation degree is {}\n".format(round(v_angular[num_steps - 1] * r_disc * dt[-1] * 1000, 1)))
     file.write("11: Total contact area of 18 rubbing element is {} cm2\n".format(round(S_total / 100, 1)))
     file.write("12: The mesh element size is between {}-{} mm\n".format(mesh_min, mesh_max))
     file.write("13: Total elements number is {}\n".format(total_elements))    
   
with open(txt_name, "r") as file1:
    print(file1.read())

#### move files
# Define the source directory
source_dir = "/home/yanjun/Documents/FEniCSx/Practice/Concise"
# Define the destination directory
destination_dir = "/home/yanjun/Documents/FEM_results/python_results"

# Create the new folder in the destination directory
new_folder_name = f"s-{num_steps}-d-{angular_r}-m-{mesh_min}-{mesh_max}-c-{c_contact}-e-{total_elements}"
destination_dir = os.path.join(destination_dir, new_folder_name)
os.makedirs(destination_dir, exist_ok=True)

# List of files to move
files_to_move = [gif_name, h5_name, xdmf_name, txt_name, csv_name]
# Move each file to the destination directory
for filename in files_to_move:
    source_file_path = os.path.join(source_dir, filename)
    destination_file_path = os.path.join(destination_dir, filename)
    #shutil.move(source_file_path, destination_file_path)
print("Move files successfully")

# %%
## get t and temperature T form T_array matrix
t, T = [], []
for value in T_array:
    t.append(value[0])
    T.append(value[1])

T_max = []
for i in range(len(T)):
    T_max.append(max(T[i]))

plt.plot(t, T_max)

# %%
print(T_max)

# %%
from brake_disc_functions import *

lables = find_3_coord(mesh_filename1)

t, T = [], []
for value in T_array:
    t.append(value[0])
    T.append(value[1])

T_3_ave = []
for i in range(len(T)):
    T_3_all = T[i][lables[0]] + T[i][lables[1]] + T[i][lables[2]]
    T_3_ave.append(T_3_all / 3)

plt.plot(t, T_3_ave)

# %%
print(mesh_filename1)

# %%
lables = find_3_coord(mesh_filename1)
# T_3_labels = 333431, 308947, 18936   # 1-2 mesh
# for i in range(len(T)):
#   print( T[i][T_3_labels[1]] )
