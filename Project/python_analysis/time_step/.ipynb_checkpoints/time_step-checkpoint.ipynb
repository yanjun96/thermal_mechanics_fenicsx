# %% [markdown]
# # time step analysis

# %%
import os
import shutil
import pandas as pd
import re
import sys
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('/home/yanjun/Documents/FEniCSx/Practice/Concise')

from brake_disc_functions import *

source_dir = '/home/yanjun/Documents/FEM_results/python_results/time_step/'
destination_dir = '/home/yanjun/Documents/FEniCSx/Project/python_analysis/time_step/'

# Collect all CSV files from the destination directory
csv_files = collect_csv_files(source_dir)

for file in csv_files:
    shutil.copy(file, destination_dir)


type1 = 'time_step'
csv_files.sort(key=lambda x: extract_file_labels(x,type1))

plt.figure(figsize=(10, 6))

df1 = pd.read_csv('/home/yanjun/Documents/FEniCSx/Project/python_analysis/experiment_result.csv')
T_e_ave = ( df1.iloc[:,1] + df1.iloc[:,3] + df1.iloc[:,5] ) /3
t_e = np.linspace (0, 49, len(T_e_ave) )
plt.plot(t_e, T_e_ave, label= "Experiment",marker='d',markevery=1000)

j = 0
marker_styles = ['o', 's', '^', 'v', '>', '<','d' ] 

for csv_file in csv_files:

    lables = find_3_coord(  extract_mesh_labels(csv_file)  )
    t,T = read_t_T (os.path.basename(csv_file))
    T_3_ave = []
    for i in range(len(T)):
        T_3_all =  T[i][ lables[0] ] + T[i][ lables[1] ] + T[i][ lables[2] ]   
        T_3_ave.append ( T_3_all / 3 )
    plt.plot(t,T_3_ave,label= f'time step { extract_file_labels(csv_file, type1)  }', marker=marker_styles[j])
    j += 1

plt.xlabel('Time/ s')
plt.ylabel('Temperature/ °C')
plt.title('Average temperatures with different different time steps')
plt.legend()
plt.grid(True)
plt.savefig('T_ave_time_step.png')
plt.show()
# Out:
# /home/yanjun/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# Lables already exists, for mesh m-3-10.msh is  [3157, 7018, 2141]
# t and T have been successfully extracted from Result_T-s-4-d-61000-m-3-10-c-1-e-43604.csv
# Lables already exists, for mesh m-3-10.msh is  [3157, 7018, 2141]
# t and T have been successfully extracted from Result_T-s-8-d-22400-m-3-10-c-1-e-43604.csv
# Lables already exists, for mesh m-3-10.msh is  [3157, 7018, 2141]
# t and T have been successfully extracted from Result_T-s-14-d-11200-m-3-10-c-1-e-43604.csv

# %%
print(csv_files)
# Out:
# ['/home/yanjun/Documents/FEM_results/python_results/time_step/s-4-d-61000-m-3-10-c-1-e-43604/Result_T-s-4-d-61000-m-3-10-c-1-e-43604.csv', '/home/yanjun/Documents/FEM_results/python_results/time_step/s-8-d-22400-m-3-10-c-1-e-43604/Result_T-s-8-d-22400-m-3-10-c-1-e-43604.csv', '/home/yanjun/Documents/FEM_results/python_results/time_step/s-14-d-11200-m-3-10-c-1-e-43604/Result_T-s-14-d-11200-m-3-10-c-1-e-43604.csv']

# %%
import os
import shutil
import pandas as pd
import re
import sys
import matplotlib.pyplot as plt
import numpy as np
sys.path.append('/home/yanjun/Documents/FEniCSx/Practice/Concise')

from brake_disc_functions import *

source_dir = '/home/yanjun/Documents/FEM_results/python_results/time_step/'                

# Collect all CSV files from the destination directory
csv_files = collect_csv_files(source_dir)

type1 = 'time_step'
csv_files.sort(key=lambda x: extract_file_labels(x,type1))

plt.figure(figsize=(10, 6))

df1 = pd.read_csv('/home/yanjun/Documents/FEniCSx/Project/python_analysis/experiment_result.csv')
T_e_ave = ( df1.iloc[:,1] + df1.iloc[:,3] + df1.iloc[:,5] ) /3
t_e = np.linspace (0, 49, len(T_e_ave) )
plt.plot(t_e, T_e_ave, label= "Experiment",marker='d',markevery=1000)

j = 0
marker_styles = ['o', 's', '^', 'v', '>', '<', 'd' ] 

for csv_file in csv_files:

    #t,T = read_t_T (os.path.basename(csv_file), )
    t,T = read_t_T ( csv_file )

    T_max = []
    for i in range(len(T)):
        T_max.append( max(T[i]) )
    plt.plot(t,T_max, label= f'time step { extract_file_labels(csv_file, type1)  }', marker=marker_styles[j] )
    j += 1

plt.xlabel('Time/ s')
plt.ylabel('Temperature/ °C')
plt.title('The maximum temperatures with different different time steps')
plt.legend()
plt.grid(True)
plt.savefig('T_max_time_step.png')
plt.show()
# Out:
# t and T have been successfully extracted from /home/yanjun/Documents/FEM_results/python_results/time_step/s-4-d-61000-m-3-10-c-1-e-43604/Result_T-s-4-d-61000-m-3-10-c-1-e-43604.csv
# t and T have been successfully extracted from /home/yanjun/Documents/FEM_results/python_results/time_step/s-8-d-22400-m-3-10-c-1-e-43604/Result_T-s-8-d-22400-m-3-10-c-1-e-43604.csv
# t and T have been successfully extracted from /home/yanjun/Documents/FEM_results/python_results/time_step/s-14-d-11200-m-3-10-c-1-e-43604/Result_T-s-14-d-11200-m-3-10-c-1-e-43604.csv
